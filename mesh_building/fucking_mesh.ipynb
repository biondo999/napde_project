# %%
import numpy as np
import triangle as tr 
import matplotlib.pyplot as plt

# %%
class ref_triangle:
    def __init__(self,N):
        self.N=N
        self.h=1/(N-1)


    def print(self):
        for elem in range(0,(self.N+1)*(self.N)//2):
            self.print_single_elem(elem)
        

    def print_single_elem(self,elem):
            r,s=self.convert(elem)
            print("element number : ",elem," --> ",r,s,'-->>',self.convert_back(r,s))


    def convert(self,x):
         r=x
         n=self.N
         s=0
         while(r>=0 or n>0):
              if(r-n>=0):
                   r=r-n
                   s=s+1
                   n=n-1
              else:
                    break
              
         return r,s
    
    def convert_back(self,i,j):
        if j>0:
             return  sum(ii for ii in range(self.N-j+1,self.N+1))+i
        else:
             return i
        
              


    def get_coordinate(self,elem):
            q,r=divmod(elem, self.N) 
            x=np.float64(self.h*r)
            y=np.float64(self.h*q)
            return x,y,r,q

# %%
number=6
T=ref_triangle(number)

# %%
T.print()
# Out:
# element number :  0  -->  0 0 -->> 0
# element number :  1  -->  1 0 -->> 1
# element number :  2  -->  2 0 -->> 2
# element number :  3  -->  3 0 -->> 3
# element number :  4  -->  4 0 -->> 4
# element number :  5  -->  5 0 -->> 5
# element number :  6  -->  0 1 -->> 6
# element number :  7  -->  1 1 -->> 7
# element number :  8  -->  2 1 -->> 8
# element number :  9  -->  3 1 -->> 9
# element number :  10  -->  4 1 -->> 10
# element number :  11  -->  0 2 -->> 11
# element number :  12  -->  1 2 -->> 12
# element number :  13  -->  2 2 -->> 13
# element number :  14  -->  3 2 -->> 14
# element number :  15  -->  0 3 -->> 15
# element number :  16  -->  1 3 -->> 16
# element number :  17  -->  2 3 -->> 17
# element number :  18  -->  0 4 -->> 18
# element number :  19  -->  1 4 -->> 19
# element number :  20  -->  0 5 -->> 20

# %%
l=[]
for jj in range(0,T.N):
    for ii in range(0,T.N-jj-1):
        print(ii,jj,'triangle -->')

        temp=[]

        if(ii%2==0):
            print("even triangle")
            print(ii,jj+1)
            temp.append(T.convert_back(ii,jj+1))
            print(ii,jj)
            temp.append(T.convert_back(ii,jj))
            print(ii+1,jj)
            temp.append(T.convert_back(ii+1,jj))
        else:
            print("odd triangle")
            print(ii,jj+1)
            temp.append(T.convert_back(ii,jj+1))
            print(ii-1,jj+1)
            temp.append(T.convert_back(ii-1,jj+1))
            print(ii,jj)
            temp.append(T.convert_back(ii,jj))
        print(temp)

        l.append(temp)
# Out:
# 0 0 triangle -->
# even triangle
# 0 1
# 0 0
# 1 0
# [6, 0, 1]
# 1 0 triangle -->
# odd triangle
# 1 1
# 0 1
# 1 0
# [7, 6, 1]
# 2 0 triangle -->
# even triangle
# 2 1
# 2 0
# 3 0
# [8, 2, 3]
# 3 0 triangle -->
# odd triangle
# 3 1
# 2 1
# 3 0
# [9, 8, 3]
# 4 0 triangle -->
# even triangle
# 4 1
# 4 0
# 5 0
# [10, 4, 5]
# 0 1 triangle -->
# even triangle
# 0 2
# 0 1
# 1 1
# [11, 6, 7]
# 1 1 triangle -->
# odd triangle
# 1 2
# 0 2
# 1 1
# [12, 11, 7]
# 2 1 triangle -->
# even triangle
# 2 2
# 2 1
# 3 1
# [13, 8, 9]
# 3 1 triangle -->
# odd triangle
# 3 2
# 2 2
# 3 1
# [14, 13, 9]
# 0 2 triangle -->
# even triangle
# 0 3
# 0 2
# 1 2
# [15, 11, 12]
# 1 2 triangle -->
# odd triangle
# 1 3
# 0 3
# 1 2
# [16, 15, 12]
# 2 2 triangle -->
# even triangle
# 2 3
# 2 2
# 3 2
# [17, 13, 14]
# 0 3 triangle -->
# even triangle
# 0 4
# 0 3
# 1 3
# [18, 15, 16]
# 1 3 triangle -->
# odd triangle
# 1 4
# 0 4
# 1 3
# [19, 18, 16]
# 0 4 triangle -->
# even triangle
# 0 5
# 0 4
# 1 4
# [20, 18, 19]

# %%
print(l)
# Out:
# [[6, 0, 1], [7, 6, 1], [8, 2, 3], [9, 8, 3], [10, 4, 5], [11, 6, 7], [12, 11, 7], [13, 8, 9], [14, 13, 9], [15, 11, 12], [16, 15, 12], [17, 13, 14], [18, 15, 16], [19, 18, 16], [20, 18, 19]]

# %%
l=[]
for jj in range(0,T.N-1):
    for ii in range(0,T.N-jj-1):
        #print(ii,jj,'triangle -->')
        if (ii!=T.N-jj-2):
            print('* ',end='')
        else:
            print('o')
    print()
# Out:
# * * * * o
#
# * * * o
#
# * * o
#
# * o
#
# o

# %%
l=[]
for jj in range(0,T.N-1):
    for ii in range(0,T.N-jj-1):
        #print(ii,jj,'triangle -->')
        
        if (ii!=T.N-jj-2):
            temp=[]
            print("even triangle")
            print(ii,jj+1)
            temp.append(T.convert_back(ii,jj+1))
            print(ii,jj)
            temp.append(T.convert_back(ii,jj))
            print(ii+1,jj)
            temp.append(T.convert_back(ii+1,jj))
            l.append(temp)


            temp=[]
            print("odd triangle")
            print(ii+1,jj+1)
            temp.append(T.convert_back(ii+1,jj+1))
            print(ii,jj+1)
            temp.append(T.convert_back(ii,jj+1))
            print(ii+1,jj)
            temp.append(T.convert_back(ii+1,jj))
            l.append(temp)
        else:
            temp=[]
            print("even triangle")
            print(ii,jj+1)
            temp.append(T.convert_back(ii,jj+1))
            print(ii,jj)
            temp.append(T.convert_back(ii,jj))
            print(ii+1,jj)
            temp.append(T.convert_back(ii+1,jj))
            l.append(temp)
    print()
# Out:
# even triangle
# 0 1
# 0 0
# 1 0
# odd triangle
# 1 1
# 0 1
# 1 0
# even triangle
# 1 1
# 1 0
# 2 0
# odd triangle
# 2 1
# 1 1
# 2 0
# even triangle
# 2 1
# 2 0
# 3 0
# odd triangle
# 3 1
# 2 1
# 3 0
# even triangle
# 3 1
# 3 0
# 4 0
# odd triangle
# 4 1
# 3 1
# 4 0
# even triangle
# 4 1
# 4 0
# 5 0
#
# even triangle
# 0 2
# 0 1
# 1 1
# odd triangle
# 1 2
# 0 2
# 1 1
# even triangle
# 1 2
# 1 1
# 2 1
# odd triangle
# 2 2
# 1 2
# 2 1
# even triangle
# 2 2
# 2 1
# 3 1
# odd triangle
# 3 2
# 2 2
# 3 1
# even triangle
# 3 2
# 3 1
# 4 1
#
# even triangle
# 0 3
# 0 2
# 1 2
# odd triangle
# 1 3
# 0 3
# 1 2
# even triangle
# 1 3
# 1 2
# 2 2
# odd triangle
# 2 3
# 1 3
# 2 2
# even triangle
# 2 3
# 2 2
# 3 2
#
# even triangle
# 0 4
# 0 3
# 1 3
# odd triangle
# 1 4
# 0 4
# 1 3
# even triangle
# 1 4
# 1 3
# 2 3
#
# even triangle
# 0 5
# 0 4
# 1 4

# %%
print(l)
# Out:
# [[6, 0, 1], [7, 6, 1], [7, 1, 2], [8, 7, 2], [8, 2, 3], [9, 8, 3], [9, 3, 4], [10, 9, 4], [10, 4, 5], [11, 6, 7], [12, 11, 7], [12, 7, 8], [13, 12, 8], [13, 8, 9], [14, 13, 9], [14, 9, 10], [15, 11, 12], [16, 15, 12], [16, 12, 13], [17, 16, 13], [17, 13, 14], [18, 15, 16], [19, 18, 16], [19, 16, 17], [20, 18, 19]]

# %%
A = dict(vertices=np.array(((0, 0), (1, 0), (1, 1), (0, 1))))

B = tr.triangulate(A, 'qa0.1')

tr.compare(plt, A, B)

# %%
print(B['triangles'])
# Out:
# [[ 4 12  9]
#  [ 8  4  5]
#  [10  7  3]
#  [ 3  5 10]
#  [12  4  6]
#  [ 4  8  6]
#  [ 0  6  8]
#  [11  2  7]
#  [ 5  0  8]
#  [ 9  2 11]
#  [ 4  7 10]
#  [ 5  4 10]
#  [ 4  9 11]
#  [ 7  4 11]
#  [ 1  9 12]
#  [ 6  1 12]]

# %%
def translate(nodes: list, vertices: list):
        """
        Translates given nodes in the reference
        case ([0, 0], [1, 0], [0, 1]) to an arbritrary triangle
        """

        # print(nodes)
        # print(vertices)

        output = np.zeros(shape=np.shape(nodes))

        output[:, 0] = (
            nodes[:, 0] * (vertices[1, 0] - vertices[0, 0])
            + nodes[:, 1] * (vertices[2, 0] - vertices[0, 0])
            + vertices[0, 0]
        )

        output[:, 1] = (
            nodes[:, 0] * (vertices[1, 1] - vertices[0, 1])
            + nodes[:, 1] * (vertices[2, 1] - vertices[0, 1])
            + vertices[0, 1]
        )

        det = (vertices[1, 0] - vertices[0, 0]) * (vertices[2, 1] - vertices[0, 1]) - (
            vertices[2, 0] - vertices[0, 0]
        ) * (vertices[1, 1] - vertices[0, 1])

        return output, det

# %%
N=number
N_points=(N+1)*N//2


x = np.linspace(0, 1,N)
xx, yy = np.meshgrid(x,x)
xx = xx.flatten(); yy = yy.flatten()
filt = xx + yy <= 1
grid = np.vstack([xx[filt], yy[filt]]).transpose()
print(len(grid))
# Out:
# 21

# %%
t=tr.triangulate(dict(vertices=grid))
tr.compare(plt,t,B)
print(t['triangles'])

print(t['vertices'])
# Out:
# [[ 6  0  1]
#  [ 6  7 11]
#  [ 7  6  1]
#  [ 7  1  2]
#  [11  7 12]
#  [18 15 16]
#  [20 18 19]
#  [16 15 12]
#  [16 12 13]
#  [19 18 16]
#  [15 11 12]
#  [ 7  8 12]
#  [13 12  8]
#  [ 8  2  3]
#  [ 8  3  9]
#  [10  3  4]
#  [10  4  5]
#  [16 17 19]
#  [16 13 17]
#  [17 13 14]
#  [ 9 10 14]
#  [10  9  3]
#  [ 9 14 13]
#  [13  8  9]
#  [ 8  7  2]]
# [[0.  0. ]
#  [0.2 0. ]
#  [0.4 0. ]
#  [0.6 0. ]
#  [0.8 0. ]
#  [1.  0. ]
#  [0.  0.2]
#  [0.2 0.2]
#  [0.4 0.2]
#  [0.6 0.2]
#  [0.8 0.2]
#  [0.  0.4]
#  [0.2 0.4]
#  [0.4 0.4]
#  [0.6 0.4]
#  [0.  0.6]
#  [0.2 0.6]
#  [0.4 0.6]
#  [0.  0.8]
#  [0.2 0.8]
#  [0.  1. ]]

# %%
t=tr.triangulate(dict(vertices=grid))
t['triangles']=l
tr.compare(plt,t,B)

# %%
print(l)
# Out:
# [[6, 0, 1], [7, 6, 1], [7, 1, 2], [8, 7, 2], [8, 2, 3], [9, 8, 3], [9, 3, 4], [10, 9, 4], [10, 4, 5], [11, 6, 7], [12, 11, 7], [12, 7, 8], [13, 12, 8], [13, 8, 9], [14, 13, 9], [14, 9, 10], [15, 11, 12], [16, 15, 12], [16, 12, 13], [17, 16, 13], [17, 13, 14], [18, 15, 16], [19, 18, 16], [19, 16, 17], [20, 18, 19]]

# %%
print(t['triangles'])
# Out:
# [[6, 0, 1], [7, 6, 1], [7, 1, 2], [8, 7, 2], [8, 2, 3], [9, 8, 3], [9, 3, 4], [10, 9, 4], [10, 4, 5], [11, 6, 7], [12, 11, 7], [12, 7, 8], [13, 12, 8], [13, 8, 9], [14, 13, 9], [14, 9, 10], [15, 11, 12], [16, 15, 12], [16, 12, 13], [17, 16, 13], [17, 13, 14], [18, 15, 16], [19, 18, 16], [19, 16, 17], [20, 18, 19]]

# %%
list=[]

n=[]

A = dict(vertices=np.array(((0, 0), (1, 0), (1, 1), (0, 1))))

B = tr.triangulate(A, 'qa0.1')
tr.compare(plt, A, B)
plt.show()

for elem in range(0,len(B['triangles'])):

    v = B['vertices'][B['triangles'][elem]]



    #anticlockwise

    new, j =translate(t['vertices'],v)

    D = tr.triangulate(dict(vertices=new))
    D['triangles']=t['triangles']


    n.append(len(D['triangles']))
    list.append(D)



tr.compare(plt,B,list[0])

plt.show()

# %%
num_plots = len(list)  # Assuming your_list contains data for plots
num_columns = 2  # Number of columns in the grid of subplots
num_rows = num_plots # Calculate the number of rows

plt.figure(figsize=(12, 8))  # Adjust the figure size as needed

for i in range(num_plots):
    tr.compare(plt, B, list[i])  # Assuming tr.compare() is a function that plots data
    plt.title(f'triangle = {i}')  # Set subplot title

plt.tight_layout()  # Adjust layout to prevent overlapping of subplots
plt.show()  # Display the plots
# Out:
# /tmp/ipykernel_5951/2878102261.py:11: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()  # Adjust layout to prevent overlapping of subplots
