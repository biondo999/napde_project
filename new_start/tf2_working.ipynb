# %%
# !pip install pyDOE
# Out:
# Requirement already satisfied: pyDOE in /home/mariano/Documenti/test/base/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: numpy in /home/mariano/Documenti/test/base/lib/python3.9/site-packages (from pyDOE) (1.24.3)
# Requirement already satisfied: scipy in /home/mariano/Documenti/test/base/lib/python3.9/site-packages (from pyDOE) (1.11.1)

# %%
#you need to add a dataset with GaussJacobiQuadRule_V3 on the right 
import sys
# sys.path.insert(1, '/kaggle/input/quadrule')
from GaussJacobiQuadRule_V3 import Jacobi, DJacobi, GaussLobattoJacobiWeights, GaussJacobiWeights

#import GaussJacobiQuadRule_V3


import tensorflow as tf
print(tf.version)
#tf.disable_v2_behavior()
import pyDOE

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pyDOE import lhs
#from GaussJacobiQuadRule_V3.py import Jacobi, DJacobi, GaussLobattoJacobiWeights, GaussJacobiWeights
import time
# Out:
# 2023-09-21 18:56:27.061215: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-21 18:56:27.062927: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-21 18:56:27.098173: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-21 18:56:27.098845: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-21 18:56:27.715841: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# <module 'tensorflow._api.v2.version' from '/home/mariano/Documenti/test/base/lib/python3.9/site-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
class parameters:
    def __init__(self,LR,Opt_Niter,N_Element,N_testfcn,N_Quad,lossb_weight,a,b):
        self.LR = LR
        self.Opt_Niter = Opt_Niter + 1
        self.Opt_tresh = 2e-32
        self.var_form=2
        self.N_Element = N_Element
        self.N_testfcn = N_testfcn #number of test function
        self.N_Quad = N_Quad    #quadrature points 
        self.lossb_weight = lossb_weight #hyprparameter we may turn it up

        #params for the exact sol and boundary term
        self.omega = 8*np.pi
        self.amp = 1
        self.r1 = 80

        #ingredients for loss
        [self.x_quad, self.w_quad] = GaussLobattoJacobiWeights(N_Quad, 0, 0)
        

        self.test_quad_element = self.Test_fcn(self.N_testfcn, self.x_quad)
        self.d1test_quad_element, self.d2test_quad_element = self.dTest_fcn(self.N_testfcn, self.x_quad)


        [self.x_l, self.x_r] = [a, b]     #modify in the future if you want general (a,b) interval
        self.delta_x = (self.x_r - self.x_l)/N_Element
        self.grid = np.asarray([ self.x_l + i*self.delta_x for i in range(self.N_Element+1)])

        #build right side (it doesnt depend on the network)

        self.F_ext_total = []
        for e in range(self.N_Element):
            x_quad_element = self.grid[e] + (self.grid[e+1]-self.grid[e])/2*(self.x_quad+1)  #traslation of the element 

            jacobian = (self.grid[e+1]-self.grid[e])/2
            testfcn_element = np.asarray([ self.Test_f(n,self.x_quad)  for n in range(1, self.N_testfcn+1)])

            #this is fh calculated on the real nodal values summed over each real nodal values(which comes form CGL nodes )

            f_quad_element = self.f_ext(x_quad_element)
            F_ext_element  = jacobian*np.asarray([sum(self.w_quad*f_quad_element*testfcn_element[i]) for i in range(self.N_testfcn)])    
            F_ext_element = F_ext_element[:,None] 
            self.F_ext_total.append(F_ext_element)

        self.F_ext_total = np.asarray(self.F_ext_total)


        self.X_bound = np.asarray([a,b],dtype=np.float64)[:,None]
        self.u_bound   = self.u_exact(self.X_bound)

    def u_exact(self,x):
        utemp = 0.1*np.sin(self.omega*x) + np.tanh(self.r1*x)
        return self.amp*utemp

    def f_ext(self,x):
        gtemp =  -0.1*(self.omega**2)*np.sin(self.omega*x) - (2*self.r1**2)*(np.tanh(self.r1*x))/((np.cosh(self.r1*x))**2)
        return -self.amp*gtemp

    def Test_f(self,n,x):
        test  = Jacobi(n+1,0,0,x) - Jacobi(n-1,0,0,x)
        return test
    
    def Test_fcn(self, N_test,x):
        test_total = []
        for n in range(1,N_test+1):  
            test  = Jacobi(n+1,0,0,x) - Jacobi(n-1,0,0,x)
            test_total.append(test)
        return np.asarray(test_total)

    def dTest_fcn(self, N_test,x):  #valuete the first and second derivatives of test functions on a point x 
        d1test_total = []
        d2test_total = []
        for n in range(1,N_test+1):  
            if n==1:
                d1test = ((n+2)/2)*Jacobi(n,1,1,x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1,2,2,x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)
            elif n==2:
                d1test = ((n+2)/2)*Jacobi(n,1,1,x) - ((n)/2)*Jacobi(n-2,1,1,x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1,2,2,x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)    
            else:
                d1test = ((n+2)/2)*Jacobi(n,1,1,x) - ((n)/2)*Jacobi(n-2,1,1,x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1,2,2,x) - ((n)*(n+1)/(2*2))*Jacobi(n-3,2,2,x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)    
        return np.asarray(d1test_total), np.asarray(d2test_total)

# %%
params=parameters(0.01,5000,5,20,100,1,-1,1)
# Out:
# /home/mariano/Documenti/test/base/lib/python3.9/site-packages/scipy/special/_orthogonal.py:133: RuntimeWarning: invalid value encountered in multiply
#   np.poly1d.__init__(self, poly.coeffs * float(kn))

# %%
#the code starts from now on

# %%
tfk=tf.keras
tfkl=tf.keras.layers
input_shape=(1,)
seed=42
input_layer = tfkl.Input(shape=input_shape, name='Input')
x1 = tfkl.Dense(20, activation=tf.math.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(input_layer)
x2 = tfkl.Dense(20, activation=tf.math.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(x1)
x3 = tfkl.Dense(20, activation=tf.math.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(x2)
x3 = tfkl.Dense(20, activation=tf.math.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(x2)
output_layer = tfkl.Dense(1, activation='linear', kernel_initializer = tfk.initializers.GlorotUniform(seed))(x3)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 1)]               0
#
#  dense (Dense)               (None, 20)                40
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 901 (3.52 KB)
# Trainable params: 901 (3.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def net_du(x):
    # x=tf.Variable(tf. expand_dims(x,-1))
    with tf.GradientTape(persistent=True) as g:
        g.watch(x)
        y=model(x)
    grad=g.gradient(y,x)
    return grad

# %%
def calculate_loss():
 varloss_total = 0

 for e in range(params.N_Element):
    F_ext_element  = tf.convert_to_tensor(params.F_ext_total[e],tf.float32)
    Ntest_element  = np.shape(F_ext_element)[0] #for each element of the grid you have a vector of the focing term (suppose its n-loc),so the you can have at most quad formula n_loc
    
    x_quad_element = tf.convert_to_tensor(params.grid[e] + (params.grid[e+1]-params.grid[e])/2*(params.x_quad+1),tf.float32)
    #to change change integral to the ref segment in (-1,1)
    jacobian= (params.grid[e+1]-params.grid[e])/2

    test_quad_element =tf.convert_to_tensor(params.Test_fcn(Ntest_element, params.x_quad),tf.float32)
    d1test_quad_element, d2test_quad_element = tf.convert_to_tensor(params.dTest_fcn(Ntest_element, params.x_quad),tf.float32)

    with tf.GradientTape() as tape:
      tape.watch(x_quad_element)
      u_NN_quad_element = model(x_quad_element)
    d1u_NN_quad_element=tape.gradient(u_NN_quad_element,x_quad_element)


    U_NN_element = tf.reshape(tf.stack([tf.reduce_sum(params.w_quad*d1u_NN_quad_element*params.d1test_quad_element[i]) \
                                        for i in range(Ntest_element)]),(-1,1)) 

    

    Res_NN_element = U_NN_element - F_ext_element
    loss_element = tf.reduce_mean(tf.square(Res_NN_element))
    varloss_total = varloss_total + loss_element






 lossb = tf.reduce_mean(tf.square(model(params.X_bound) - params.u_bound))   #u_NN_pred is what your network has calc,while u_tf is the real value
 return lossb,varloss_total

# %%
epochs=5000
total_record=[]
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

start_time       = time.time()
for epoch in range(epochs+1):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        loss_valueb,loss_valuev=calculate_loss()
        loss=loss_valueb*params.lossb_weight+loss_valuev
         
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    # Print training loss for this epoch
    if (epoch) % 10 == 0:
                elapsed = time.time() - start_time
                str_print = 'It: %d, Lossb: %.3e, Lossv: %.3e, Time: %.2f'
                print(str_print % (epoch, loss_valueb, loss_valuev, elapsed))
                start_time = time.time()        
                total_record.append(np.array([epoch, loss,loss_valueb,loss_valuev]))
# Out:
# It: 0, Lossb: 1.463e-02, Lossv: 8.660e+02, Time: 0.45
# It: 10, Lossb: 2.184e-07, Lossv: 8.660e+02, Time: 1.80
# It: 20, Lossb: 7.687e-04, Lossv: 8.660e+02, Time: 1.87
# It: 30, Lossb: 1.898e-04, Lossv: 8.660e+02, Time: 1.80
# It: 40, Lossb: 1.025e-04, Lossv: 8.660e+02, Time: 1.74
# It: 50, Lossb: 1.180e-04, Lossv: 8.660e+02, Time: 1.65
# It: 60, Lossb: 1.351e-05, Lossv: 8.659e+02, Time: 1.62
# It: 70, Lossb: 1.112e-03, Lossv: 8.657e+02, Time: 1.59
# It: 80, Lossb: 8.962e-03, Lossv: 8.650e+02, Time: 1.56
# It: 90, Lossb: 1.735e-02, Lossv: 8.631e+02, Time: 1.70
# It: 100, Lossb: 4.059e-05, Lossv: 8.582e+02, Time: 1.64
# It: 110, Lossb: 1.143e-02, Lossv: 8.454e+02, Time: 1.70
# It: 120, Lossb: 1.392e-02, Lossv: 8.243e+02, Time: 1.62
# It: 130, Lossb: 1.374e-02, Lossv: 8.119e+02, Time: 1.58
# It: 140, Lossb: 3.642e-02, Lossv: 8.054e+02, Time: 1.60
# It: 150, Lossb: 7.440e-02, Lossv: 8.014e+02, Time: 1.56
# It: 160, Lossb: 1.695e-02, Lossv: 7.964e+02, Time: 1.57
# It: 170, Lossb: 3.571e-02, Lossv: 7.910e+02, Time: 1.62
# It: 180, Lossb: 9.523e-02, Lossv: 7.803e+02, Time: 1.55
# It: 190, Lossb: 2.767e-02, Lossv: 7.503e+02, Time: 1.60
# It: 200, Lossb: 9.592e-03, Lossv: 7.104e+02, Time: 1.51
# It: 210, Lossb: 1.144e-04, Lossv: 6.836e+02, Time: 1.66
# It: 220, Lossb: 3.035e-02, Lossv: 6.625e+02, Time: 1.67
# It: 230, Lossb: 3.458e-02, Lossv: 6.443e+02, Time: 1.56
# It: 240, Lossb: 5.876e-02, Lossv: 6.273e+02, Time: 1.54
# It: 250, Lossb: 2.218e-02, Lossv: 6.123e+02, Time: 1.53
# It: 260, Lossb: 2.123e-03, Lossv: 6.035e+02, Time: 1.53
# It: 270, Lossb: 2.848e-02, Lossv: 5.979e+02, Time: 1.72
# It: 280, Lossb: 4.133e-02, Lossv: 5.910e+02, Time: 1.54
# It: 290, Lossb: 4.486e-02, Lossv: 5.829e+02, Time: 1.56
# It: 300, Lossb: 4.809e-02, Lossv: 5.718e+02, Time: 1.53
# It: 310, Lossb: 6.812e-02, Lossv: 5.554e+02, Time: 1.53
# It: 320, Lossb: 1.058e-01, Lossv: 5.314e+02, Time: 1.54
# It: 330, Lossb: 1.407e-01, Lossv: 5.006e+02, Time: 1.53
# It: 340, Lossb: 1.481e-01, Lossv: 4.685e+02, Time: 1.55
# It: 350, Lossb: 6.973e-02, Lossv: 4.374e+02, Time: 1.54
# It: 360, Lossb: 1.821e-02, Lossv: 4.071e+02, Time: 1.55
# It: 370, Lossb: 4.369e-01, Lossv: 3.755e+02, Time: 1.54
# It: 380, Lossb: 7.863e-01, Lossv: 3.383e+02, Time: 1.58
# It: 390, Lossb: 5.312e-01, Lossv: 2.932e+02, Time: 1.52
# It: 400, Lossb: 6.637e-02, Lossv: 2.446e+02, Time: 1.53
# It: 410, Lossb: 7.084e-02, Lossv: 2.023e+02, Time: 1.52
# It: 420, Lossb: 3.952e-01, Lossv: 1.713e+02, Time: 1.53
# It: 430, Lossb: 4.966e-01, Lossv: 1.436e+02, Time: 1.54
# It: 440, Lossb: 3.532e-01, Lossv: 1.152e+02, Time: 1.57
# It: 450, Lossb: 1.431e-01, Lossv: 8.732e+01, Time: 1.52
# It: 460, Lossb: 2.429e-02, Lossv: 6.321e+01, Time: 1.53
# It: 470, Lossb: 1.613e-02, Lossv: 4.533e+01, Time: 1.52
# It: 480, Lossb: 5.506e-02, Lossv: 3.239e+01, Time: 1.54
# It: 490, Lossb: 5.776e-02, Lossv: 2.432e+01, Time: 1.56
# It: 500, Lossb: 2.625e-02, Lossv: 1.950e+01, Time: 1.54
# It: 510, Lossb: 3.282e-03, Lossv: 1.647e+01, Time: 1.53
# It: 520, Lossb: 1.733e-03, Lossv: 1.422e+01, Time: 1.52
# It: 530, Lossb: 1.183e-02, Lossv: 1.225e+01, Time: 1.54
# It: 540, Lossb: 2.667e-02, Lossv: 1.050e+01, Time: 1.53
# It: 550, Lossb: 4.127e-02, Lossv: 8.972e+00, Time: 1.53
# It: 560, Lossb: 5.015e-02, Lossv: 7.654e+00, Time: 1.54
# It: 570, Lossb: 5.265e-02, Lossv: 6.536e+00, Time: 1.57
# It: 580, Lossb: 5.052e-02, Lossv: 5.609e+00, Time: 1.57
# It: 590, Lossb: 4.644e-02, Lossv: 4.853e+00, Time: 1.51
# It: 600, Lossb: 4.149e-02, Lossv: 4.241e+00, Time: 1.53
# It: 610, Lossb: 3.642e-02, Lossv: 3.747e+00, Time: 1.59
# It: 620, Lossb: 3.198e-02, Lossv: 3.346e+00, Time: 1.52
# It: 630, Lossb: 2.834e-02, Lossv: 3.016e+00, Time: 1.53
# It: 640, Lossb: 2.527e-02, Lossv: 2.741e+00, Time: 1.53
# It: 650, Lossb: 2.235e-02, Lossv: 2.509e+00, Time: 1.52
# It: 660, Lossb: 1.947e-02, Lossv: 2.310e+00, Time: 1.53
# It: 670, Lossb: 1.673e-02, Lossv: 2.137e+00, Time: 1.54
# It: 680, Lossb: 1.421e-02, Lossv: 1.984e+00, Time: 1.53
# It: 690, Lossb: 1.195e-02, Lossv: 1.851e+00, Time: 1.53
# It: 700, Lossb: 1.002e-02, Lossv: 1.727e+00, Time: 1.53
# It: 710, Lossb: 8.423e-03, Lossv: 1.620e+00, Time: 1.52
# It: 720, Lossb: 7.162e-03, Lossv: 1.514e+00, Time: 1.52
# It: 730, Lossb: 6.196e-03, Lossv: 1.420e+00, Time: 1.56
# It: 740, Lossb: 5.484e-03, Lossv: 1.334e+00, Time: 1.72
# It: 750, Lossb: 4.982e-03, Lossv: 1.255e+00, Time: 1.66
# It: 760, Lossb: 4.645e-03, Lossv: 1.183e+00, Time: 1.53
# It: 770, Lossb: 4.434e-03, Lossv: 1.118e+00, Time: 1.55
# It: 780, Lossb: 4.309e-03, Lossv: 1.058e+00, Time: 1.54
# It: 790, Lossb: 4.238e-03, Lossv: 1.003e+00, Time: 1.57
# It: 800, Lossb: 4.191e-03, Lossv: 9.528e-01, Time: 1.62
# It: 810, Lossb: 4.145e-03, Lossv: 9.067e-01, Time: 1.61
# It: 820, Lossb: 4.084e-03, Lossv: 8.645e-01, Time: 1.65
# It: 830, Lossb: 3.997e-03, Lossv: 8.257e-01, Time: 1.70
# It: 840, Lossb: 3.885e-03, Lossv: 7.899e-01, Time: 1.67
# It: 850, Lossb: 3.747e-03, Lossv: 7.569e-01, Time: 1.64
# It: 860, Lossb: 3.591e-03, Lossv: 7.265e-01, Time: 1.64
# It: 870, Lossb: 3.421e-03, Lossv: 6.983e-01, Time: 1.58
# It: 880, Lossb: 3.242e-03, Lossv: 6.746e-01, Time: 1.66
# It: 890, Lossb: 3.060e-03, Lossv: 6.736e-01, Time: 1.82
# It: 900, Lossb: 2.876e-03, Lossv: 6.428e-01, Time: 1.64
# It: 910, Lossb: 2.691e-03, Lossv: 6.111e-01, Time: 1.73
# It: 920, Lossb: 2.511e-03, Lossv: 5.878e-01, Time: 1.62
# It: 930, Lossb: 2.335e-03, Lossv: 5.684e-01, Time: 1.68
# It: 940, Lossb: 2.168e-03, Lossv: 5.509e-01, Time: 1.70
# It: 950, Lossb: 2.009e-03, Lossv: 5.349e-01, Time: 1.67
# It: 960, Lossb: 1.857e-03, Lossv: 5.201e-01, Time: 1.59
# It: 970, Lossb: 1.714e-03, Lossv: 5.060e-01, Time: 1.61
# It: 980, Lossb: 1.582e-03, Lossv: 4.928e-01, Time: 1.67
# It: 990, Lossb: 1.459e-03, Lossv: 4.802e-01, Time: 1.68
# It: 1000, Lossb: 1.346e-03, Lossv: 4.682e-01, Time: 1.67
# It: 1010, Lossb: 1.243e-03, Lossv: 4.567e-01, Time: 1.65
# It: 1020, Lossb: 1.147e-03, Lossv: 4.458e-01, Time: 1.66
# It: 1030, Lossb: 1.061e-03, Lossv: 4.353e-01, Time: 1.67
# It: 1040, Lossb: 9.812e-04, Lossv: 4.252e-01, Time: 1.66
# It: 1050, Lossb: 9.087e-04, Lossv: 4.154e-01, Time: 1.70
# It: 1060, Lossb: 8.426e-04, Lossv: 4.060e-01, Time: 1.68
# It: 1070, Lossb: 7.823e-04, Lossv: 3.970e-01, Time: 1.72
# It: 1080, Lossb: 7.270e-04, Lossv: 3.882e-01, Time: 1.71
# It: 1090, Lossb: 6.763e-04, Lossv: 3.834e-01, Time: 1.66
# It: 1100, Lossb: 6.306e-04, Lossv: 3.862e-01, Time: 1.68
# It: 1110, Lossb: 5.862e-04, Lossv: 3.796e-01, Time: 1.62
# It: 1120, Lossb: 5.479e-04, Lossv: 3.619e-01, Time: 1.71
# It: 1130, Lossb: 5.106e-04, Lossv: 3.504e-01, Time: 1.68
# It: 1140, Lossb: 4.790e-04, Lossv: 3.415e-01, Time: 1.67
# It: 1150, Lossb: 4.487e-04, Lossv: 3.337e-01, Time: 1.61
# It: 1160, Lossb: 4.203e-04, Lossv: 3.266e-01, Time: 1.62
# It: 1170, Lossb: 3.938e-04, Lossv: 3.198e-01, Time: 1.65
# It: 1180, Lossb: 3.694e-04, Lossv: 3.131e-01, Time: 1.68
# It: 1190, Lossb: 3.470e-04, Lossv: 3.067e-01, Time: 1.68
# It: 1200, Lossb: 3.261e-04, Lossv: 3.003e-01, Time: 1.70
# It: 1210, Lossb: 3.068e-04, Lossv: 2.941e-01, Time: 1.73
# It: 1220, Lossb: 2.887e-04, Lossv: 2.881e-01, Time: 1.70
# It: 1230, Lossb: 2.719e-04, Lossv: 2.822e-01, Time: 1.68
# It: 1240, Lossb: 2.563e-04, Lossv: 2.765e-01, Time: 1.73
# It: 1250, Lossb: 2.418e-04, Lossv: 2.708e-01, Time: 1.66
# It: 1260, Lossb: 2.282e-04, Lossv: 2.654e-01, Time: 1.71
# It: 1270, Lossb: 2.155e-04, Lossv: 2.600e-01, Time: 1.65
# It: 1280, Lossb: 2.037e-04, Lossv: 2.548e-01, Time: 1.67
# It: 1290, Lossb: 1.926e-04, Lossv: 2.497e-01, Time: 1.63
# It: 1300, Lossb: 1.823e-04, Lossv: 2.447e-01, Time: 1.65
# It: 1310, Lossb: 1.726e-04, Lossv: 2.401e-01, Time: 1.66
# It: 1320, Lossb: 1.635e-04, Lossv: 2.939e-01, Time: 1.63
# It: 1330, Lossb: 1.563e-04, Lossv: 2.471e-01, Time: 1.61
# It: 1340, Lossb: 1.479e-04, Lossv: 2.317e-01, Time: 1.65
# It: 1350, Lossb: 1.384e-04, Lossv: 2.226e-01, Time: 1.68
# It: 1360, Lossb: 1.331e-04, Lossv: 2.175e-01, Time: 1.69
# It: 1370, Lossb: 1.262e-04, Lossv: 2.131e-01, Time: 1.77
# It: 1380, Lossb: 1.202e-04, Lossv: 2.091e-01, Time: 1.67
# It: 1390, Lossb: 1.142e-04, Lossv: 2.051e-01, Time: 1.68
# It: 1400, Lossb: 1.088e-04, Lossv: 2.012e-01, Time: 1.67
# It: 1410, Lossb: 1.038e-04, Lossv: 1.975e-01, Time: 1.67
# It: 1420, Lossb: 9.900e-05, Lossv: 1.938e-01, Time: 1.70
# It: 1430, Lossb: 9.455e-05, Lossv: 1.903e-01, Time: 1.67
# It: 1440, Lossb: 9.037e-05, Lossv: 1.869e-01, Time: 1.65
# It: 1450, Lossb: 8.639e-05, Lossv: 1.835e-01, Time: 1.63
# It: 1460, Lossb: 8.266e-05, Lossv: 1.803e-01, Time: 1.62
# It: 1470, Lossb: 7.913e-05, Lossv: 1.771e-01, Time: 1.65
# It: 1480, Lossb: 7.581e-05, Lossv: 1.741e-01, Time: 1.67
# It: 1490, Lossb: 7.265e-05, Lossv: 1.711e-01, Time: 1.65
# It: 1500, Lossb: 6.968e-05, Lossv: 1.682e-01, Time: 1.71
# It: 1510, Lossb: 6.686e-05, Lossv: 1.655e-01, Time: 1.68
# It: 1520, Lossb: 6.416e-05, Lossv: 1.627e-01, Time: 1.68
# It: 1530, Lossb: 6.164e-05, Lossv: 1.601e-01, Time: 1.68
# It: 1540, Lossb: 5.922e-05, Lossv: 1.576e-01, Time: 1.69
# It: 1550, Lossb: 5.692e-05, Lossv: 1.551e-01, Time: 1.66
# It: 1560, Lossb: 5.478e-05, Lossv: 1.530e-01, Time: 1.64
# It: 1570, Lossb: 5.349e-05, Lossv: 1.830e-01, Time: 1.66
# It: 1580, Lossb: 5.091e-05, Lossv: 1.827e-01, Time: 1.70
# It: 1590, Lossb: 4.843e-05, Lossv: 1.502e-01, Time: 1.68
# It: 1600, Lossb: 4.608e-05, Lossv: 1.439e-01, Time: 1.66
# It: 1610, Lossb: 4.525e-05, Lossv: 1.420e-01, Time: 1.71
# It: 1620, Lossb: 4.355e-05, Lossv: 1.402e-01, Time: 1.69
# It: 1630, Lossb: 4.171e-05, Lossv: 1.380e-01, Time: 1.73
# It: 1640, Lossb: 4.015e-05, Lossv: 1.359e-01, Time: 1.66
# It: 1650, Lossb: 3.861e-05, Lossv: 1.341e-01, Time: 1.62
# It: 1660, Lossb: 3.719e-05, Lossv: 1.323e-01, Time: 1.67
# It: 1670, Lossb: 3.580e-05, Lossv: 1.306e-01, Time: 1.67
# It: 1680, Lossb: 3.442e-05, Lossv: 1.290e-01, Time: 1.68
# It: 1690, Lossb: 3.311e-05, Lossv: 1.273e-01, Time: 1.63
# It: 1700, Lossb: 3.186e-05, Lossv: 1.257e-01, Time: 1.66
# It: 1710, Lossb: 3.062e-05, Lossv: 1.242e-01, Time: 1.63
# It: 1720, Lossb: 2.944e-05, Lossv: 1.227e-01, Time: 1.68
# It: 1730, Lossb: 2.832e-05, Lossv: 1.213e-01, Time: 1.66
# It: 1740, Lossb: 2.721e-05, Lossv: 1.198e-01, Time: 1.78
# It: 1750, Lossb: 2.614e-05, Lossv: 1.185e-01, Time: 1.69
# It: 1760, Lossb: 2.513e-05, Lossv: 1.171e-01, Time: 1.63
# It: 1770, Lossb: 2.415e-05, Lossv: 1.158e-01, Time: 1.69
# It: 1780, Lossb: 2.322e-05, Lossv: 1.146e-01, Time: 1.63
# It: 1790, Lossb: 2.260e-05, Lossv: 1.187e-01, Time: 1.67
# It: 1800, Lossb: 2.267e-05, Lossv: 1.294e-01, Time: 1.69
# It: 1810, Lossb: 2.152e-05, Lossv: 1.290e-01, Time: 1.68
# It: 1820, Lossb: 1.968e-05, Lossv: 1.129e-01, Time: 1.69
# It: 1830, Lossb: 1.921e-05, Lossv: 1.086e-01, Time: 1.66
# It: 1840, Lossb: 1.819e-05, Lossv: 1.077e-01, Time: 1.68
# It: 1850, Lossb: 1.736e-05, Lossv: 1.066e-01, Time: 1.65
# It: 1860, Lossb: 1.683e-05, Lossv: 1.052e-01, Time: 1.63
# It: 1870, Lossb: 1.627e-05, Lossv: 1.042e-01, Time: 1.64
# It: 1880, Lossb: 1.564e-05, Lossv: 1.031e-01, Time: 1.66
# It: 1890, Lossb: 1.501e-05, Lossv: 1.021e-01, Time: 1.71
# It: 1900, Lossb: 1.445e-05, Lossv: 1.011e-01, Time: 1.71
# It: 1910, Lossb: 1.393e-05, Lossv: 1.001e-01, Time: 1.72
# It: 1920, Lossb: 1.341e-05, Lossv: 9.915e-02, Time: 1.66
# It: 1930, Lossb: 1.292e-05, Lossv: 9.820e-02, Time: 1.66
# It: 1940, Lossb: 1.246e-05, Lossv: 9.726e-02, Time: 1.67
# It: 1950, Lossb: 1.203e-05, Lossv: 9.633e-02, Time: 1.65
# It: 1960, Lossb: 1.160e-05, Lossv: 9.542e-02, Time: 1.66
# It: 1970, Lossb: 1.121e-05, Lossv: 9.452e-02, Time: 1.67
# It: 1980, Lossb: 1.082e-05, Lossv: 9.363e-02, Time: 1.91
# It: 1990, Lossb: 1.047e-05, Lossv: 9.275e-02, Time: 1.73
# It: 2000, Lossb: 1.015e-05, Lossv: 9.190e-02, Time: 1.68
# It: 2010, Lossb: 9.989e-06, Lossv: 9.168e-02, Time: 1.71
# It: 2020, Lossb: 1.232e-05, Lossv: 1.484e-01, Time: 1.75
# It: 2030, Lossb: 7.233e-06, Lossv: 1.144e-01, Time: 1.76
# It: 2040, Lossb: 1.053e-05, Lossv: 9.569e-02, Time: 1.70
# It: 2050, Lossb: 1.130e-05, Lossv: 8.905e-02, Time: 1.70
# It: 2060, Lossb: 9.414e-06, Lossv: 8.750e-02, Time: 1.66
# It: 2070, Lossb: 8.091e-06, Lossv: 8.625e-02, Time: 1.67
# It: 2080, Lossb: 7.336e-06, Lossv: 8.541e-02, Time: 1.67
# It: 2090, Lossb: 7.468e-06, Lossv: 8.455e-02, Time: 1.70
# It: 2100, Lossb: 7.731e-06, Lossv: 8.375e-02, Time: 1.74
# It: 2110, Lossb: 7.485e-06, Lossv: 8.297e-02, Time: 1.68
# It: 2120, Lossb: 7.119e-06, Lossv: 8.221e-02, Time: 1.67
# It: 2130, Lossb: 7.054e-06, Lossv: 8.145e-02, Time: 1.68
# It: 2140, Lossb: 6.885e-06, Lossv: 8.070e-02, Time: 1.85
# It: 2150, Lossb: 6.736e-06, Lossv: 7.996e-02, Time: 1.69
# It: 2160, Lossb: 6.604e-06, Lossv: 7.922e-02, Time: 1.69
# It: 2170, Lossb: 6.452e-06, Lossv: 7.848e-02, Time: 1.68
# It: 2180, Lossb: 6.348e-06, Lossv: 7.776e-02, Time: 1.79
# It: 2190, Lossb: 6.246e-06, Lossv: 7.704e-02, Time: 1.66
# It: 2200, Lossb: 6.166e-06, Lossv: 7.632e-02, Time: 1.66
# It: 2210, Lossb: 6.283e-06, Lossv: 7.566e-02, Time: 1.70
# It: 2220, Lossb: 8.388e-06, Lossv: 7.887e-02, Time: 1.67
# It: 2230, Lossb: 6.806e-06, Lossv: 1.390e-01, Time: 1.70
# It: 2240, Lossb: 5.450e-06, Lossv: 7.372e-02, Time: 1.73
# It: 2250, Lossb: 5.627e-06, Lossv: 7.910e-02, Time: 1.72
# It: 2260, Lossb: 6.265e-06, Lossv: 7.374e-02, Time: 1.78
# It: 2270, Lossb: 5.361e-06, Lossv: 7.155e-02, Time: 1.65
# It: 2280, Lossb: 5.240e-06, Lossv: 7.113e-02, Time: 1.68
# It: 2290, Lossb: 5.321e-06, Lossv: 7.013e-02, Time: 1.66
# It: 2300, Lossb: 5.324e-06, Lossv: 6.951e-02, Time: 1.65
# It: 2310, Lossb: 5.156e-06, Lossv: 6.882e-02, Time: 1.73
# It: 2320, Lossb: 5.134e-06, Lossv: 6.816e-02, Time: 1.66
# It: 2330, Lossb: 5.117e-06, Lossv: 6.752e-02, Time: 1.66
# It: 2340, Lossb: 5.081e-06, Lossv: 6.688e-02, Time: 1.69
# It: 2350, Lossb: 5.160e-06, Lossv: 6.626e-02, Time: 1.70
# It: 2360, Lossb: 6.185e-06, Lossv: 6.645e-02, Time: 1.73
# It: 2370, Lossb: 7.877e-06, Lossv: 6.949e-02, Time: 1.71
# It: 2380, Lossb: 5.012e-06, Lossv: 6.448e-02, Time: 1.72
# It: 2390, Lossb: 3.692e-06, Lossv: 6.473e-02, Time: 1.72
# It: 2400, Lossb: 4.863e-06, Lossv: 6.350e-02, Time: 1.68
# It: 2410, Lossb: 4.924e-06, Lossv: 6.391e-02, Time: 1.69
# It: 2420, Lossb: 4.142e-06, Lossv: 7.536e-02, Time: 1.70
# It: 2430, Lossb: 4.196e-06, Lossv: 6.271e-02, Time: 1.61
# It: 2440, Lossb: 5.212e-06, Lossv: 6.257e-02, Time: 1.64
# It: 2450, Lossb: 3.873e-06, Lossv: 6.159e-02, Time: 1.70
# It: 2460, Lossb: 4.916e-06, Lossv: 6.022e-02, Time: 1.67
# It: 2470, Lossb: 4.376e-06, Lossv: 5.904e-02, Time: 1.68
# It: 2480, Lossb: 4.172e-06, Lossv: 5.865e-02, Time: 1.65
# It: 2490, Lossb: 4.245e-06, Lossv: 5.805e-02, Time: 1.63
# It: 2500, Lossb: 3.985e-06, Lossv: 5.781e-02, Time: 1.69
# It: 2510, Lossb: 3.092e-06, Lossv: 6.360e-02, Time: 1.65
# It: 2520, Lossb: 2.932e-06, Lossv: 8.102e-02, Time: 1.66
# It: 2530, Lossb: 4.944e-06, Lossv: 6.333e-02, Time: 1.65
# It: 2540, Lossb: 3.665e-06, Lossv: 5.702e-02, Time: 1.64
# It: 2550, Lossb: 4.616e-06, Lossv: 5.519e-02, Time: 1.63
# It: 2560, Lossb: 3.687e-06, Lossv: 5.443e-02, Time: 1.65
# It: 2570, Lossb: 4.378e-06, Lossv: 5.381e-02, Time: 1.57
# It: 2580, Lossb: 3.887e-06, Lossv: 5.316e-02, Time: 1.57
# It: 2590, Lossb: 3.790e-06, Lossv: 5.264e-02, Time: 1.57
# It: 2600, Lossb: 3.941e-06, Lossv: 5.212e-02, Time: 1.59
# It: 2610, Lossb: 3.997e-06, Lossv: 5.164e-02, Time: 1.62
# It: 2620, Lossb: 4.269e-06, Lossv: 5.141e-02, Time: 1.63
# It: 2630, Lossb: 6.363e-06, Lossv: 5.925e-02, Time: 1.62
# It: 2640, Lossb: 3.777e-06, Lossv: 8.375e-02, Time: 1.62
# It: 2650, Lossb: 3.562e-06, Lossv: 5.275e-02, Time: 1.66
# It: 2660, Lossb: 4.129e-06, Lossv: 5.055e-02, Time: 1.62
# It: 2670, Lossb: 3.412e-06, Lossv: 5.037e-02, Time: 1.64
# It: 2680, Lossb: 3.696e-06, Lossv: 4.855e-02, Time: 1.63
# It: 2690, Lossb: 3.436e-06, Lossv: 4.790e-02, Time: 1.60
# It: 2700, Lossb: 3.521e-06, Lossv: 4.746e-02, Time: 1.70
# It: 2710, Lossb: 3.484e-06, Lossv: 4.702e-02, Time: 1.59
# It: 2720, Lossb: 3.385e-06, Lossv: 4.658e-02, Time: 1.59
# It: 2730, Lossb: 3.360e-06, Lossv: 4.615e-02, Time: 1.58
# It: 2740, Lossb: 3.388e-06, Lossv: 4.574e-02, Time: 1.58
# It: 2750, Lossb: 3.969e-06, Lossv: 4.593e-02, Time: 1.64
# It: 2760, Lossb: 7.310e-06, Lossv: 5.886e-02, Time: 1.68
# It: 2770, Lossb: 3.635e-06, Lossv: 5.478e-02, Time: 1.59
# It: 2780, Lossb: 2.362e-06, Lossv: 4.497e-02, Time: 1.62
# It: 2790, Lossb: 2.565e-06, Lossv: 4.604e-02, Time: 1.59
# It: 2800, Lossb: 3.135e-06, Lossv: 4.336e-02, Time: 1.64
# It: 2810, Lossb: 3.292e-06, Lossv: 4.332e-02, Time: 1.61
# It: 2820, Lossb: 3.049e-06, Lossv: 4.412e-02, Time: 1.59
# It: 2830, Lossb: 3.239e-06, Lossv: 5.418e-02, Time: 1.61
# It: 2840, Lossb: 3.177e-06, Lossv: 4.382e-02, Time: 1.61
# It: 2850, Lossb: 2.476e-06, Lossv: 4.442e-02, Time: 1.78
# It: 2860, Lossb: 3.000e-06, Lossv: 4.249e-02, Time: 1.66
# It: 2870, Lossb: 2.685e-06, Lossv: 4.077e-02, Time: 1.63
# It: 2880, Lossb: 2.560e-06, Lossv: 4.072e-02, Time: 1.61
# It: 2890, Lossb: 2.565e-06, Lossv: 4.010e-02, Time: 1.59
# It: 2900, Lossb: 2.540e-06, Lossv: 3.972e-02, Time: 1.61
# It: 2910, Lossb: 2.447e-06, Lossv: 3.948e-02, Time: 1.63
# It: 2920, Lossb: 2.130e-06, Lossv: 4.274e-02, Time: 1.63
# It: 2930, Lossb: 1.249e-06, Lossv: 9.291e-02, Time: 1.61
# It: 2940, Lossb: 3.951e-06, Lossv: 4.948e-02, Time: 1.61
# It: 2950, Lossb: 2.163e-06, Lossv: 3.871e-02, Time: 1.64
# It: 2960, Lossb: 1.715e-06, Lossv: 3.986e-02, Time: 1.60
# It: 2970, Lossb: 2.591e-06, Lossv: 3.785e-02, Time: 1.58
# It: 2980, Lossb: 2.390e-06, Lossv: 3.716e-02, Time: 1.64
# It: 2990, Lossb: 2.083e-06, Lossv: 3.682e-02, Time: 1.72
# It: 3000, Lossb: 2.172e-06, Lossv: 3.650e-02, Time: 1.64
# It: 3010, Lossb: 2.109e-06, Lossv: 3.619e-02, Time: 1.58
# It: 3020, Lossb: 2.045e-06, Lossv: 3.589e-02, Time: 1.55
# It: 3030, Lossb: 2.042e-06, Lossv: 3.560e-02, Time: 1.59
# It: 3040, Lossb: 1.977e-06, Lossv: 3.530e-02, Time: 1.59
# It: 3050, Lossb: 1.935e-06, Lossv: 3.502e-02, Time: 1.59
# It: 3060, Lossb: 1.897e-06, Lossv: 3.473e-02, Time: 1.65
# It: 3070, Lossb: 1.834e-06, Lossv: 3.446e-02, Time: 1.62
# It: 3080, Lossb: 1.665e-06, Lossv: 3.482e-02, Time: 1.59
# It: 3090, Lossb: 1.039e-06, Lossv: 7.118e-02, Time: 1.57
# It: 3100, Lossb: 2.956e-06, Lossv: 5.242e-02, Time: 1.62
# It: 3110, Lossb: 8.683e-07, Lossv: 3.996e-02, Time: 1.61
# It: 3120, Lossb: 1.294e-06, Lossv: 3.542e-02, Time: 1.63
# It: 3130, Lossb: 1.964e-06, Lossv: 3.349e-02, Time: 1.62
# It: 3140, Lossb: 1.873e-06, Lossv: 3.276e-02, Time: 1.69
# It: 3150, Lossb: 1.550e-06, Lossv: 3.246e-02, Time: 1.59
# It: 3160, Lossb: 1.565e-06, Lossv: 3.204e-02, Time: 1.61
# It: 3170, Lossb: 1.558e-06, Lossv: 3.177e-02, Time: 1.62
# It: 3180, Lossb: 1.539e-06, Lossv: 3.152e-02, Time: 1.59
# It: 3190, Lossb: 1.508e-06, Lossv: 3.126e-02, Time: 1.60
# It: 3200, Lossb: 1.478e-06, Lossv: 3.101e-02, Time: 1.61
# It: 3210, Lossb: 1.434e-06, Lossv: 3.077e-02, Time: 1.60
# It: 3220, Lossb: 1.419e-06, Lossv: 3.052e-02, Time: 1.63
# It: 3230, Lossb: 1.384e-06, Lossv: 3.028e-02, Time: 1.61
# It: 3240, Lossb: 1.352e-06, Lossv: 3.004e-02, Time: 1.69
# It: 3250, Lossb: 1.322e-06, Lossv: 2.980e-02, Time: 1.61
# It: 3260, Lossb: 1.274e-06, Lossv: 2.957e-02, Time: 1.62
# It: 3270, Lossb: 1.131e-06, Lossv: 2.976e-02, Time: 1.71
# It: 3280, Lossb: 5.562e-07, Lossv: 5.895e-02, Time: 1.61
# It: 3290, Lossb: 2.417e-06, Lossv: 4.176e-02, Time: 1.58
# It: 3300, Lossb: 7.154e-07, Lossv: 3.804e-02, Time: 1.61
# It: 3310, Lossb: 9.290e-07, Lossv: 3.159e-02, Time: 1.60
# It: 3320, Lossb: 1.403e-06, Lossv: 2.856e-02, Time: 1.66
# It: 3330, Lossb: 1.330e-06, Lossv: 2.851e-02, Time: 1.60
# It: 3340, Lossb: 1.055e-06, Lossv: 2.783e-02, Time: 1.58
# It: 3350, Lossb: 1.122e-06, Lossv: 2.756e-02, Time: 1.60
# It: 3360, Lossb: 1.165e-06, Lossv: 2.734e-02, Time: 1.58
# It: 3370, Lossb: 1.088e-06, Lossv: 2.710e-02, Time: 1.61
# It: 3380, Lossb: 1.122e-06, Lossv: 2.689e-02, Time: 1.65
# It: 3390, Lossb: 1.068e-06, Lossv: 2.667e-02, Time: 1.71
# It: 3400, Lossb: 1.067e-06, Lossv: 2.646e-02, Time: 1.60
# It: 3410, Lossb: 1.041e-06, Lossv: 2.626e-02, Time: 1.60
# It: 3420, Lossb: 1.023e-06, Lossv: 2.605e-02, Time: 1.64
# It: 3430, Lossb: 1.012e-06, Lossv: 2.584e-02, Time: 1.64
# It: 3440, Lossb: 9.998e-07, Lossv: 2.564e-02, Time: 1.59
# It: 3450, Lossb: 9.943e-07, Lossv: 2.544e-02, Time: 1.58
# It: 3460, Lossb: 1.083e-06, Lossv: 2.538e-02, Time: 1.61
# It: 3470, Lossb: 2.170e-06, Lossv: 3.488e-02, Time: 1.63
# It: 3480, Lossb: 8.305e-07, Lossv: 6.957e-02, Time: 1.60
# It: 3490, Lossb: 1.215e-06, Lossv: 4.171e-02, Time: 1.59
# It: 3500, Lossb: 1.776e-06, Lossv: 2.896e-02, Time: 1.61
# It: 3510, Lossb: 8.423e-07, Lossv: 2.452e-02, Time: 1.63
# It: 3520, Lossb: 7.906e-07, Lossv: 2.460e-02, Time: 1.62
# It: 3530, Lossb: 1.103e-06, Lossv: 2.424e-02, Time: 1.60
# It: 3540, Lossb: 8.887e-07, Lossv: 2.383e-02, Time: 1.62
# It: 3550, Lossb: 9.162e-07, Lossv: 2.359e-02, Time: 1.59
# It: 3560, Lossb: 9.087e-07, Lossv: 2.337e-02, Time: 1.59
# It: 3570, Lossb: 8.788e-07, Lossv: 2.318e-02, Time: 1.63
# It: 3580, Lossb: 8.797e-07, Lossv: 2.300e-02, Time: 1.71
# It: 3590, Lossb: 8.467e-07, Lossv: 2.282e-02, Time: 1.60
# It: 3600, Lossb: 8.354e-07, Lossv: 2.264e-02, Time: 1.61
# It: 3610, Lossb: 8.265e-07, Lossv: 2.247e-02, Time: 1.59
# It: 3620, Lossb: 7.873e-07, Lossv: 2.236e-02, Time: 1.63
# It: 3630, Lossb: 6.242e-07, Lossv: 2.474e-02, Time: 1.63
# It: 3640, Lossb: 7.069e-07, Lossv: 9.221e-02, Time: 1.66
# It: 3650, Lossb: 2.465e-06, Lossv: 3.823e-02, Time: 1.61
# It: 3660, Lossb: 1.566e-06, Lossv: 2.462e-02, Time: 1.62
# It: 3670, Lossb: 6.468e-07, Lossv: 2.405e-02, Time: 1.62
# It: 3680, Lossb: 7.317e-07, Lossv: 2.142e-02, Time: 1.61
# It: 3690, Lossb: 8.065e-07, Lossv: 2.147e-02, Time: 1.61
# It: 3700, Lossb: 6.855e-07, Lossv: 2.110e-02, Time: 1.58
# It: 3710, Lossb: 8.637e-07, Lossv: 2.083e-02, Time: 1.59
# It: 3720, Lossb: 7.958e-07, Lossv: 2.066e-02, Time: 1.77
# It: 3730, Lossb: 7.388e-07, Lossv: 2.051e-02, Time: 1.65
# It: 3740, Lossb: 7.624e-07, Lossv: 2.035e-02, Time: 1.65
# It: 3750, Lossb: 7.471e-07, Lossv: 2.020e-02, Time: 1.68
# It: 3760, Lossb: 7.276e-07, Lossv: 2.004e-02, Time: 1.58
# It: 3770, Lossb: 7.265e-07, Lossv: 1.989e-02, Time: 1.64
# It: 3780, Lossb: 7.111e-07, Lossv: 1.974e-02, Time: 1.62
# It: 3790, Lossb: 6.999e-07, Lossv: 1.959e-02, Time: 1.60
# It: 3800, Lossb: 6.880e-07, Lossv: 1.944e-02, Time: 1.61
# It: 3810, Lossb: 6.711e-07, Lossv: 1.930e-02, Time: 1.60
# It: 3820, Lossb: 6.121e-07, Lossv: 1.957e-02, Time: 1.65
# It: 3830, Lossb: 2.836e-07, Lossv: 5.926e-02, Time: 1.62
# It: 3840, Lossb: 3.604e-06, Lossv: 4.599e-02, Time: 1.61
# It: 3850, Lossb: 7.134e-07, Lossv: 2.452e-02, Time: 1.71
# It: 3860, Lossb: 2.199e-07, Lossv: 2.299e-02, Time: 1.62
# It: 3870, Lossb: 3.229e-07, Lossv: 1.958e-02, Time: 1.64
# It: 3880, Lossb: 8.116e-07, Lossv: 1.875e-02, Time: 1.65
# It: 3890, Lossb: 9.978e-07, Lossv: 1.842e-02, Time: 1.61
# It: 3900, Lossb: 6.841e-07, Lossv: 1.809e-02, Time: 1.60
# It: 3910, Lossb: 5.745e-07, Lossv: 1.798e-02, Time: 1.62
# It: 3920, Lossb: 7.008e-07, Lossv: 1.781e-02, Time: 1.66
# It: 3930, Lossb: 6.615e-07, Lossv: 1.768e-02, Time: 1.61
# It: 3940, Lossb: 6.191e-07, Lossv: 1.756e-02, Time: 1.61
# It: 3950, Lossb: 6.374e-07, Lossv: 1.743e-02, Time: 1.62
# It: 3960, Lossb: 6.150e-07, Lossv: 1.730e-02, Time: 1.63
# It: 3970, Lossb: 6.068e-07, Lossv: 1.718e-02, Time: 1.68
# It: 3980, Lossb: 5.958e-07, Lossv: 1.705e-02, Time: 1.63
# It: 3990, Lossb: 5.861e-07, Lossv: 1.693e-02, Time: 1.60
# It: 4000, Lossb: 5.757e-07, Lossv: 1.681e-02, Time: 1.74
# It: 4010, Lossb: 5.646e-07, Lossv: 1.669e-02, Time: 1.60
# It: 4020, Lossb: 5.311e-07, Lossv: 1.657e-02, Time: 1.62
# It: 4030, Lossb: 2.826e-07, Lossv: 1.655e-02, Time: 1.61
# It: 4040, Lossb: 3.189e-06, Lossv: 3.212e-02, Time: 1.60
# It: 4050, Lossb: 3.743e-06, Lossv: 6.683e-02, Time: 1.60
# It: 4060, Lossb: 3.096e-06, Lossv: 3.953e-02, Time: 1.66
# It: 4070, Lossb: 1.380e-06, Lossv: 1.799e-02, Time: 1.67
# It: 4080, Lossb: 8.805e-07, Lossv: 1.778e-02, Time: 1.67
# It: 4090, Lossb: 8.218e-07, Lossv: 1.646e-02, Time: 1.58
# It: 4100, Lossb: 7.336e-07, Lossv: 1.569e-02, Time: 1.61
# It: 4110, Lossb: 6.309e-07, Lossv: 1.566e-02, Time: 1.61
# It: 4120, Lossb: 6.084e-07, Lossv: 1.551e-02, Time: 1.66
# It: 4130, Lossb: 5.596e-07, Lossv: 1.536e-02, Time: 1.67
# It: 4140, Lossb: 5.319e-07, Lossv: 1.524e-02, Time: 1.70
# It: 4150, Lossb: 5.005e-07, Lossv: 1.514e-02, Time: 1.63
# It: 4160, Lossb: 5.090e-07, Lossv: 1.504e-02, Time: 1.64
# It: 4170, Lossb: 6.640e-07, Lossv: 1.557e-02, Time: 1.63
# It: 4180, Lossb: 3.231e-06, Lossv: 4.624e-02, Time: 1.59
# It: 4190, Lossb: 9.810e-08, Lossv: 1.993e-02, Time: 1.62
# It: 4200, Lossb: 9.913e-08, Lossv: 1.957e-02, Time: 1.60
# It: 4210, Lossb: 4.240e-07, Lossv: 1.607e-02, Time: 1.60
# It: 4220, Lossb: 8.030e-07, Lossv: 1.851e-02, Time: 1.62
# It: 4230, Lossb: 8.617e-07, Lossv: 2.405e-02, Time: 1.64
# It: 4240, Lossb: 4.345e-07, Lossv: 1.433e-02, Time: 1.69
# It: 4250, Lossb: 4.124e-07, Lossv: 1.602e-02, Time: 1.61
# It: 4260, Lossb: 4.726e-07, Lossv: 1.423e-02, Time: 1.61
# It: 4270, Lossb: 4.542e-07, Lossv: 1.407e-02, Time: 1.63
# It: 4280, Lossb: 4.893e-07, Lossv: 1.460e-02, Time: 1.63
# It: 4290, Lossb: 6.718e-07, Lossv: 2.227e-02, Time: 1.74
# It: 4300, Lossb: 9.730e-07, Lossv: 2.487e-02, Time: 1.70
# It: 4310, Lossb: 2.366e-07, Lossv: 1.845e-02, Time: 1.66
# It: 4320, Lossb: 4.648e-07, Lossv: 1.533e-02, Time: 1.68
# It: 4330, Lossb: 5.014e-07, Lossv: 1.438e-02, Time: 1.65
# It: 4340, Lossb: 4.180e-07, Lossv: 1.356e-02, Time: 1.64
# It: 4350, Lossb: 3.417e-07, Lossv: 1.329e-02, Time: 1.64
# It: 4360, Lossb: 2.401e-07, Lossv: 1.348e-02, Time: 1.62
# It: 4370, Lossb: 6.607e-09, Lossv: 1.911e-02, Time: 1.67
# It: 4380, Lossb: 1.469e-07, Lossv: 1.901e-02, Time: 1.62
# It: 4390, Lossb: 1.386e-07, Lossv: 2.270e-02, Time: 1.63
# It: 4400, Lossb: 1.046e-06, Lossv: 1.534e-02, Time: 1.60
# It: 4410, Lossb: 2.504e-07, Lossv: 1.390e-02, Time: 1.59
# It: 4420, Lossb: 3.768e-07, Lossv: 1.315e-02, Time: 1.61
# It: 4430, Lossb: 3.186e-07, Lossv: 1.332e-02, Time: 1.57
# It: 4440, Lossb: 2.972e-07, Lossv: 1.380e-02, Time: 1.66
# It: 4450, Lossb: 2.217e-07, Lossv: 1.891e-02, Time: 1.60
# It: 4460, Lossb: 1.463e-07, Lossv: 2.298e-02, Time: 1.58
# It: 4470, Lossb: 2.076e-07, Lossv: 1.476e-02, Time: 1.70
# It: 4480, Lossb: 9.266e-07, Lossv: 1.287e-02, Time: 1.65
# It: 4490, Lossb: 7.557e-07, Lossv: 1.313e-02, Time: 1.58
# It: 4500, Lossb: 3.022e-07, Lossv: 1.309e-02, Time: 1.59
# It: 4510, Lossb: 2.515e-07, Lossv: 1.798e-02, Time: 1.65
# It: 4520, Lossb: 3.476e-06, Lossv: 2.530e-02, Time: 1.65
# It: 4530, Lossb: 1.851e-07, Lossv: 1.892e-02, Time: 1.63
# It: 4540, Lossb: 4.540e-07, Lossv: 1.638e-02, Time: 1.63
# It: 4550, Lossb: 5.888e-08, Lossv: 1.325e-02, Time: 1.64
# It: 4560, Lossb: 3.981e-07, Lossv: 1.174e-02, Time: 1.64
# It: 4570, Lossb: 3.038e-07, Lossv: 1.186e-02, Time: 1.65
# It: 4580, Lossb: 5.278e-07, Lossv: 1.213e-02, Time: 1.66
# It: 4590, Lossb: 3.285e-06, Lossv: 2.817e-02, Time: 1.62
# It: 4600, Lossb: 2.175e-07, Lossv: 2.935e-02, Time: 1.65
# It: 4610, Lossb: 1.372e-06, Lossv: 1.373e-02, Time: 1.63
# It: 4620, Lossb: 2.612e-07, Lossv: 1.360e-02, Time: 1.64
# It: 4630, Lossb: 7.840e-08, Lossv: 1.195e-02, Time: 1.64
# It: 4640, Lossb: 5.572e-07, Lossv: 1.162e-02, Time: 1.62
# It: 4650, Lossb: 1.641e-07, Lossv: 1.112e-02, Time: 1.60
# It: 4660, Lossb: 2.792e-07, Lossv: 1.116e-02, Time: 1.59
# It: 4670, Lossb: 1.625e-07, Lossv: 1.240e-02, Time: 1.62
# It: 4680, Lossb: 2.941e-07, Lossv: 3.385e-02, Time: 1.65
# It: 4690, Lossb: 7.429e-08, Lossv: 1.419e-02, Time: 1.61
# It: 4700, Lossb: 1.667e-06, Lossv: 1.643e-02, Time: 1.59
# It: 4710, Lossb: 3.574e-08, Lossv: 1.292e-02, Time: 1.66
# It: 4720, Lossb: 7.294e-07, Lossv: 1.151e-02, Time: 1.64
# It: 4730, Lossb: 1.136e-07, Lossv: 1.098e-02, Time: 1.72
# It: 4740, Lossb: 6.452e-07, Lossv: 1.141e-02, Time: 1.61
# It: 4750, Lossb: 1.332e-06, Lossv: 1.956e-02, Time: 1.71
# It: 4760, Lossb: 2.031e-07, Lossv: 1.144e-02, Time: 1.58
# It: 4770, Lossb: 1.834e-07, Lossv: 1.055e-02, Time: 1.63
# It: 4780, Lossb: 3.059e-07, Lossv: 1.039e-02, Time: 1.64
# It: 4790, Lossb: 9.383e-08, Lossv: 1.057e-02, Time: 1.67
# It: 4800, Lossb: 4.882e-07, Lossv: 1.451e-02, Time: 1.63
# It: 4810, Lossb: 1.551e-06, Lossv: 4.901e-02, Time: 1.58
# It: 4820, Lossb: 3.391e-07, Lossv: 1.775e-02, Time: 1.61
# It: 4830, Lossb: 1.001e-08, Lossv: 1.054e-02, Time: 1.63
# It: 4840, Lossb: 1.431e-07, Lossv: 1.102e-02, Time: 1.62
# It: 4850, Lossb: 2.584e-07, Lossv: 1.132e-02, Time: 1.60
# It: 4860, Lossb: 5.662e-08, Lossv: 1.315e-02, Time: 1.58
# It: 4870, Lossb: 4.052e-07, Lossv: 1.583e-02, Time: 1.62
# It: 4880, Lossb: 4.555e-07, Lossv: 1.069e-02, Time: 1.74
# It: 4890, Lossb: 3.612e-07, Lossv: 9.869e-03, Time: 1.61
# It: 4900, Lossb: 1.906e-08, Lossv: 1.013e-02, Time: 1.61
# It: 4910, Lossb: 1.463e-07, Lossv: 9.708e-03, Time: 1.63
# It: 4920, Lossb: 2.616e-07, Lossv: 9.661e-03, Time: 1.62
# It: 4930, Lossb: 4.334e-07, Lossv: 1.013e-02, Time: 1.65
# It: 4940, Lossb: 8.247e-07, Lossv: 1.403e-02, Time: 1.61
# It: 4950, Lossb: 1.137e-06, Lossv: 2.007e-02, Time: 1.60
# It: 4960, Lossb: 1.691e-06, Lossv: 3.736e-02, Time: 1.61
# It: 4970, Lossb: 2.301e-07, Lossv: 1.544e-02, Time: 1.59
# It: 4980, Lossb: 1.010e-07, Lossv: 1.640e-02, Time: 1.73
# It: 4990, Lossb: 3.307e-07, Lossv: 1.062e-02, Time: 1.64
# It: 5000, Lossb: 4.818e-08, Lossv: 9.447e-03, Time: 1.60

# %%
x_test=tf.convert_to_tensor(np.linspace(-1,1,100),tf.float32)
y_test=tf.convert_to_tensor(params.u_exact(x_test))


u_pred=model(x_test)
y_test=tf.expand_dims(y_test,axis=1)

fig = plt.figure(0)
gridspec.GridSpec(3,1)


# plt.savefig('Train-Quad-pnts.pdf')    
#++++++++++++++++++++++++++++

font = 24
#all loss
fig, ax = plt.subplots()
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off') 
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss \,\, values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
iteration = [total_record[i][0] for i in range(len(total_record))]
loss_his  = [total_record[i][1] for i in range(len(total_record))]
plt.plot(iteration, loss_his,'green',label="loss")
plt.legend(loc="upper right")
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# plt.savefig('loss.pdf')
#++++++++++++++++++++++++++++
#partial loss
fig, ax = plt.subplots()
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off')
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss \,\, values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
iteration = [total_record[i][0] for i in range(len(total_record))]
loss_his  = [total_record[i][1] for i in range(len(total_record))]
loss_b  = [total_record[i][2] for i in range(len(total_record))]
loss_v  = [total_record[i][3] for i in range(len(total_record))]
plt.plot(iteration, loss_his,'green',label="loss")
plt.plot(iteration, loss_b,'blue',label="boundary_loss")
plt.plot(iteration, loss_v, 'violet',label="variational_loss")
plt.legend(loc="upper right")
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()


pnt_skip = 25
fig, ax = plt.subplots()
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=8)

plt.xlabel('$x$', fontsize = font)
plt.ylabel('$u$', fontsize = font)
plt.axhline(0, linewidth=0.8, linestyle='-', color='gray')
for xc in params.grid:
    plt.axvline(x=xc, linewidth=2, ls = '--')
plt.plot(x_test, y_test, linewidth=1, color='r', label=''.join(['$exact$']))
plt.plot(x_test, u_pred, 'k*', label='$VPINN$')
plt.tick_params( labelsize = 20)
legend = plt.legend(shadow=True, loc='upper left', fontsize=18, ncol = 1)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# plt.savefig('prediction.pdf')
#++++++++++++++++++++++++++++

fig, ax = plt.subplots()
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=8)
plt.xlabel('$x$', fontsize = font)
plt.ylabel('point-wise error', fontsize = font)
plt.yscale('log')
plt.axhline(0, linewidth=0.8, linestyle='-', color='gray')
for xc in params.grid:
    plt.axvline(x=xc, linewidth=2, ls = '--')
plt.plot(x_test, abs(y_test - u_pred), 'k')
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# Out:
# /tmp/ipykernel_18498/3838810866.py:79: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.axvline(x=xc, linewidth=2, ls = '--')

# %%
x_test=tf.convert_to_tensor(np.linspace(-1,1,100),tf.float32)
y_test=params.u_exact(x_test)

plt.plot(x_test,y_test, '.', label="data")
plt.plot(x_test, model(x_test), label='Trained predictions')
plt.title('After training')
plt.legend();
