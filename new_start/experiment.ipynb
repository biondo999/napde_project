# %%
# !pip install pyDOE

#you need to add a dataset with GaussJacobiQuadRule_V3 on the right 
import sys
sys.path.insert(1, '/kaggle/input/quadrule')
from GaussJacobiQuadRule_V3 import Jacobi, DJacobi, GaussLobattoJacobiWeights, GaussJacobiWeights

#import GaussJacobiQuadRule_V3


import tensorflow as tf
print(tf.version)
#tf.disable_v2_behavior()
import pyDOE

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pyDOE import lhs
#from GaussJacobiQuadRule_V3.py import Jacobi, DJacobi, GaussLobattoJacobiWeights, GaussJacobiWeights
import time
# Out:
# Requirement already satisfied: pyDOE in /home/mariano/Documenti/test/base/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: numpy in /home/mariano/Documenti/test/base/lib/python3.9/site-packages (from pyDOE) (1.24.3)
# Requirement already satisfied: scipy in /home/mariano/Documenti/test/base/lib/python3.9/site-packages (from pyDOE) (1.11.1)
# 2023-09-21 18:47:36.283281: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-21 18:47:36.284809: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-21 18:47:36.318222: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-21 18:47:36.318837: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-21 18:47:36.902144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# <module 'tensorflow._api.v2.version' from '/home/mariano/Documenti/test/base/lib/python3.9/site-packages/tensorflow/_api/v2/version/__init__.py'>

# %%
#types
float_type_tf=tf.float32
float_type_np=np.float32
print(str(float_type_tf))
# Out:
# <dtype: 'float32'>

# %%
class parameters:
    def __init__(self,LR,Opt_Niter,N_Element,N_testfcn,N_Quad,lossb_weight,a,b):
        self.LR = LR
        self.Opt_Niter = Opt_Niter + 1
        self.Opt_tresh = 2e-32
        self.var_form=2
        self.N_Element = N_Element
        self.N_testfcn = N_testfcn #number of test function
        self.N_Quad = N_Quad    #quadrature points 
        self.lossb_weight = lossb_weight #hyprparameter we may turn it up

        #params for the exact sol and boundary term
        self.omega = 8*np.pi
        self.amp = 1
        self.r1 = 80

        #ingredients for loss
        [self.x_quad, self.w_quad] = GaussLobattoJacobiWeights(N_Quad, 0, 0)
        

        self.test_quad_element = self.Test_fcn(self.N_testfcn, self.x_quad)
        self.d1test_quad_element, self.d2test_quad_element = self.dTest_fcn(self.N_testfcn, self.x_quad)


        [self.x_l, self.x_r] = [a, b]     #modify in the future if you want general (a,b) interval
        self.delta_x = (self.x_r - self.x_l)/N_Element
        self.grid = np.asarray([ self.x_l + i*self.delta_x for i in range(self.N_Element+1)])

        #build right side (it doesnt depend on the network)

        self.F_ext_total = []
        for e in range(self.N_Element):
            x_quad_element = self.grid[e] + (self.grid[e+1]-self.grid[e])/2*(self.x_quad+1)  #traslation of the element 

            jacobian = (self.grid[e+1]-self.grid[e])/2
            testfcn_element = np.asarray([ self.Test_f(n,self.x_quad)  for n in range(1, self.N_testfcn+1)])

            #this is fh calculated on the real nodal values summed over each real nodal values(which comes form CGL nodes )

            f_quad_element = self.f_ext(x_quad_element)
            F_ext_element  = jacobian*np.asarray([sum(self.w_quad*f_quad_element*testfcn_element[i]) for i in range(self.N_testfcn)])    
            F_ext_element = F_ext_element[:,None] 
            self.F_ext_total.append(F_ext_element)

        self.F_ext_total = np.asarray(self.F_ext_total)


        self.X_bound = np.asarray([a,b],dtype=float_type_np)[:,None]
        self.u_bound   = self.u_exact(self.X_bound)

    def u_exact(self,x):
        utemp = 0.1*np.sin(self.omega*x) + np.tanh(self.r1*x)
        return self.amp*utemp

    def f_ext(self,x):
        gtemp =  -0.1*(self.omega**2)*np.sin(self.omega*x) - (2*self.r1**2)*(np.tanh(self.r1*x))/((np.cosh(self.r1*x))**2)
        return -self.amp*gtemp

    def Test_f(self,n,x):
        test  = Jacobi(n+1,0,0,x) - Jacobi(n-1,0,0,x)
        return test
    
    def Test_fcn(self, N_test,x):
        test_total = []
        for n in range(1,N_test+1):  
            test  = Jacobi(n+1,0,0,x) - Jacobi(n-1,0,0,x)
            test_total.append(test)
        return np.asarray(test_total)

    def dTest_fcn(self, N_test,x):  #valuete the first and second derivatives of test functions on a point x 
        d1test_total = []
        d2test_total = []
        for n in range(1,N_test+1):  
            if n==1:
                d1test = ((n+2)/2)*Jacobi(n,1,1,x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1,2,2,x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)
            elif n==2:
                d1test = ((n+2)/2)*Jacobi(n,1,1,x) - ((n)/2)*Jacobi(n-2,1,1,x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1,2,2,x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)    
            else:
                d1test = ((n+2)/2)*Jacobi(n,1,1,x) - ((n)/2)*Jacobi(n-2,1,1,x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1,2,2,x) - ((n)*(n+1)/(2*2))*Jacobi(n-3,2,2,x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)    
        return np.asarray(d1test_total), np.asarray(d2test_total)

# %%
params=parameters(0.001,5000,5,20,100,1,-1,1)
# Out:
# /home/mariano/Documenti/test/base/lib/python3.9/site-packages/scipy/special/_orthogonal.py:133: RuntimeWarning: invalid value encountered in multiply
#   np.poly1d.__init__(self, poly.coeffs * float(kn))

# %%
tfk=tf.keras
tfkl=tf.keras.layers
input_shape=(1,)
seed=42
input_layer = tfkl.Input(shape=input_shape, name='Input')
x1 = tfkl.Dense(20, activation=tf.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(input_layer)
x2 = tfkl.Dense(20, activation=tf.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(x1)
x3 = tfkl.Dense(20, activation=tf.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(x2)
x3 = tfkl.Dense(20, activation=tf.sin, kernel_initializer = tfk.initializers.GlorotUniform(seed))(x2)
output_layer = tfkl.Dense(1, activation='linear', kernel_initializer = tfk.initializers.GlorotUniform(seed))(x3)

# %%
model = tf.keras.Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 1)]               0
#
#  dense (Dense)               (None, 20)                40
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 901 (3.52 KB)
# Trainable params: 901 (3.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#pre training
F_ext_element=[]
Ntest_element=[]
x_quad_element=[]
jacobian=[]
x_b_element=[]
test_quad_element=[]
d1test_quad_element=[]
d2test_quad_element=[]
d1test_bound_element=[]
d2test_bound_element=[]


for e in range(params.N_Element):
    temp=tf.convert_to_tensor(params.F_ext_total[e],float_type_tf)
    F_ext_element.append(temp)
    n=np.shape(temp)[0]
    Ntest_element.append(n) #for each element of the grid you have a vector of the focing term (suppose its n-loc),so the you can have at most quad formula n_loc


    x_quad_element.append(tf.convert_to_tensor(params.grid[e] + (params.grid[e+1]-params.grid[e])/2*(params.x_quad+1),float_type_tf))

    #to change change integral to the ref segment in (-1,1)
    jacobian.append((params.grid[e+1]-params.grid[e])/2)



    temp=tf.convert_to_tensor(np.array([[params.grid[e]], [params.grid[e+1]]]),float_type_tf)
    x_b_element.append(temp)


    test_quad_element.append(tf.convert_to_tensor(params.Test_fcn(n, params.x_quad),float_type_tf))
    d1, d2 = tf.convert_to_tensor(params.dTest_fcn(n, params.x_quad),float_type_tf)
    d1test_quad_element.append(d1)
    d2test_quad_element.append(d2)


    a, b = tf.convert_to_tensor(params.dTest_fcn(n, np.array([[-1],[1]])),tf.float32)

    d1test_bound_element.append(a)
    d2test_bound_element.append(b)

tools_for_training={
"F_ext_element":F_ext_element,
"Ntest_element":Ntest_element,
"x_quad_element":x_quad_element,
"jacobian":jacobian,
"x_b_element":x_b_element,
"test_quad_element":test_quad_element,
"d1test_quad_element":d1test_quad_element,
"d2test_quad_element":d2test_quad_element,
"d1test_bound_element":d1test_bound_element,
"d2test_bound_element":d2test_bound_element
}

# %%
#make a function that prints the size of the object that i'm using for the training

def print_training_data(tools_for_training,params,model):
    print("Number of elements : ",end='')
    print(params.N_Element)
    print("Number of test functions for each element : ",end='')
    print(params.N_testfcn)
    print("Number of quadrature points for each element : ",end='')
    print(params.N_Quad)
    print("Type of elements in the tensor : ",end='')
    print(str(float_type_tf))
    
    print()

    
    print("Ingredients for training:")
    print(f"{'List of':<30}{'Size':<20}{'Type'}")
    for key in tools_for_training:
        tensor_shape = tf.shape(tools_for_training[key][0])
        print(f"{key:<30}{len(tools_for_training[key]):<20}{tensor_shape}")
    
    print()
    print("Structure of the network : ")
    print()
    
    model.summary()

# %%
def calculate_loss():
 varloss_total = 0.0

 for e in range(params.N_Element):


    with tf.GradientTape() as tape_:
          tape_.watch(x_quad_element[e])
          with tf.GradientTape() as tape:
                tape.watch(x_quad_element[e])
                u_NN_quad_element = model(x_quad_element[e])
          d1u_NN_quad_element=tape.gradient(u_NN_quad_element,x_quad_element[e])
    d2u_NN_quad_element=tape_.gradient(d1u_NN_quad_element,x_quad_element[e])



    if params.var_form == 1:
        U_NN_element = tf.reshape(tf.stack([-jacobian[e]*tf.reduce_sum(params.w_quad*d2u_NN_quad_element*test_quad_element[e][i]) \
                                        for i in range(Ntest_element[e])]),(-1,1))
    
        
    if params.var_form == 2:
        U_NN_element = tf.reshape(tf.stack([tf.reduce_sum(params.w_quad*d1u_NN_quad_element*d1test_quad_element[e][i]) \
                                        for i in range(Ntest_element[e])]),(-1,1)) 

    if params.var_form == 3:
        u_NN_bound_element=model(x_b_element[e])
        U_NN_element = tf.reshape(tf.stack([-1/jacobian[e]*tf.reduce_sum(params.wquad*u_NN_quad_element*d2test_quad_element[e][i]) \
                                            +1/jacobian[e]*tf.reduce_sum(u_NN_bound_element*np.array([-d1test_bound_element[e][i][0], d1test_bound_element[e][i][-1]]))  \
                                            for i in range(Ntest_element[e])]),(-1,1))
        
        
    Res_NN_element = U_NN_element - F_ext_element[e]
    loss_element = tf.reduce_mean(tf.square(Res_NN_element))
    varloss_total = varloss_total + loss_element






 lossb = tf.reduce_mean(tf.square(model(params.X_bound) - params.u_bound))   #u_NN_pred is what your network has calc,while u_tf is the real value
 return lossb,varloss_total

# %%
print_training_data(tools_for_training,params,model)
# Out:
# Number of elements : 5
# Number of test functions for each element : 20
# Number of quadrature points for each element : 100
# Type of elements in the tensor : <dtype: 'float32'>
#
# Ingredients for training:
# List of                       Size                Type
# F_ext_element                 5                   [20  1]
# Ntest_element                 5                   []
# x_quad_element                5                   [100]
# jacobian                      5                   []
# x_b_element                   5                   [2 1]
# test_quad_element             5                   [ 20 100]
# d1test_quad_element           5                   [ 20 100]
# d2test_quad_element           5                   [ 20 100]
# d1test_bound_element          5                   [20  2  1]
# d2test_bound_element          5                   [20  2  1]
#
# Structure of the network :
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 1)]               0
#
#  dense (Dense)               (None, 20)                40
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 901 (3.52 KB)
# Trainable params: 901 (3.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x_test=tf.convert_to_tensor(np.linspace(-1,1,100),tf.float32)
y_test=params.u_exact(x_test)

plt.plot(x_test,y_test, '.', label="data")
plt.plot(x_test, model(x_test), label='Trained predictions')
plt.title('pre training')
plt.legend();

# %%
epochs=params.Opt_Niter
total_record=[]
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

start_time       = time.time()
for epoch in range(epochs+1):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        loss_valueb,loss_valuev=calculate_loss()
        loss=loss_valueb*params.lossb_weight+loss_valuev
        
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    # Print training loss for this epoch
    if (epoch) % 10 == 0:
                elapsed = time.time() - start_time
                str_print = 'It: %d, Lossb: %.3e, Lossv: %.3e, Time: %.2f'
                print(str_print % (epoch, loss_valueb, loss_valuev, elapsed))
                start_time = time.time()        
                total_record.append(np.array([epoch, loss,loss_valueb,loss_valuev]))
# Out:
# It: 0, Lossb: 1.463e-02, Lossv: 8.660e+02, Time: 0.18
# It: 10, Lossb: 2.339e-07, Lossv: 8.660e+02, Time: 1.01
# It: 20, Lossb: 7.686e-04, Lossv: 8.660e+02, Time: 1.00
# It: 30, Lossb: 1.898e-04, Lossv: 8.660e+02, Time: 0.89
# It: 40, Lossb: 1.026e-04, Lossv: 8.660e+02, Time: 0.95
# It: 50, Lossb: 1.180e-04, Lossv: 8.660e+02, Time: 0.89
# It: 60, Lossb: 1.351e-05, Lossv: 8.659e+02, Time: 0.92
# It: 70, Lossb: 1.111e-03, Lossv: 8.657e+02, Time: 0.92
# It: 80, Lossb: 8.962e-03, Lossv: 8.650e+02, Time: 0.99
# It: 90, Lossb: 1.735e-02, Lossv: 8.631e+02, Time: 0.97
# It: 100, Lossb: 4.080e-05, Lossv: 8.582e+02, Time: 0.90
# It: 110, Lossb: 1.143e-02, Lossv: 8.454e+02, Time: 0.90
# It: 120, Lossb: 1.392e-02, Lossv: 8.243e+02, Time: 0.88
# It: 130, Lossb: 1.374e-02, Lossv: 8.119e+02, Time: 0.88
# It: 140, Lossb: 3.642e-02, Lossv: 8.054e+02, Time: 0.89
# It: 150, Lossb: 7.440e-02, Lossv: 8.014e+02, Time: 0.89
# It: 160, Lossb: 1.695e-02, Lossv: 7.964e+02, Time: 0.88
# It: 170, Lossb: 3.571e-02, Lossv: 7.910e+02, Time: 0.91
# It: 180, Lossb: 9.523e-02, Lossv: 7.803e+02, Time: 0.89
# It: 190, Lossb: 2.767e-02, Lossv: 7.503e+02, Time: 1.12
# It: 200, Lossb: 9.593e-03, Lossv: 7.104e+02, Time: 0.95
# It: 210, Lossb: 1.142e-04, Lossv: 6.836e+02, Time: 0.94
# It: 220, Lossb: 3.035e-02, Lossv: 6.625e+02, Time: 0.93
# It: 230, Lossb: 3.458e-02, Lossv: 6.443e+02, Time: 0.92
# It: 240, Lossb: 5.876e-02, Lossv: 6.273e+02, Time: 0.90
# It: 250, Lossb: 2.218e-02, Lossv: 6.123e+02, Time: 0.95
# It: 260, Lossb: 2.116e-03, Lossv: 6.035e+02, Time: 0.94
# It: 270, Lossb: 2.847e-02, Lossv: 5.979e+02, Time: 0.94
# It: 280, Lossb: 4.131e-02, Lossv: 5.910e+02, Time: 0.89
# It: 290, Lossb: 4.485e-02, Lossv: 5.829e+02, Time: 0.87
# It: 300, Lossb: 4.808e-02, Lossv: 5.718e+02, Time: 0.87
# It: 310, Lossb: 6.809e-02, Lossv: 5.554e+02, Time: 0.92
# It: 320, Lossb: 1.058e-01, Lossv: 5.314e+02, Time: 0.90
# It: 330, Lossb: 1.406e-01, Lossv: 5.006e+02, Time: 0.89
# It: 340, Lossb: 1.480e-01, Lossv: 4.685e+02, Time: 0.89
# It: 350, Lossb: 6.971e-02, Lossv: 4.374e+02, Time: 0.96
# It: 360, Lossb: 1.823e-02, Lossv: 4.071e+02, Time: 0.88
# It: 370, Lossb: 4.370e-01, Lossv: 3.755e+02, Time: 0.90
# It: 380, Lossb: 7.862e-01, Lossv: 3.383e+02, Time: 0.90
# It: 390, Lossb: 5.312e-01, Lossv: 2.933e+02, Time: 0.96
# It: 400, Lossb: 6.634e-02, Lossv: 2.445e+02, Time: 0.92
# It: 410, Lossb: 7.088e-02, Lossv: 2.023e+02, Time: 1.04
# It: 420, Lossb: 3.952e-01, Lossv: 1.713e+02, Time: 0.97
# It: 430, Lossb: 4.966e-01, Lossv: 1.436e+02, Time: 0.92
# It: 440, Lossb: 3.532e-01, Lossv: 1.152e+02, Time: 0.86
# It: 450, Lossb: 1.432e-01, Lossv: 8.732e+01, Time: 0.84
# It: 460, Lossb: 2.436e-02, Lossv: 6.321e+01, Time: 0.85
# It: 470, Lossb: 1.616e-02, Lossv: 4.531e+01, Time: 0.90
# It: 480, Lossb: 5.509e-02, Lossv: 3.236e+01, Time: 0.95
# It: 490, Lossb: 5.774e-02, Lossv: 2.433e+01, Time: 0.93
# It: 500, Lossb: 2.623e-02, Lossv: 1.950e+01, Time: 1.01
# It: 510, Lossb: 3.280e-03, Lossv: 1.647e+01, Time: 1.04
# It: 520, Lossb: 1.733e-03, Lossv: 1.422e+01, Time: 0.91
# It: 530, Lossb: 1.183e-02, Lossv: 1.225e+01, Time: 0.95
# It: 540, Lossb: 2.667e-02, Lossv: 1.050e+01, Time: 1.05
# It: 550, Lossb: 4.127e-02, Lossv: 8.971e+00, Time: 1.06
# It: 560, Lossb: 5.014e-02, Lossv: 7.653e+00, Time: 0.97
# It: 570, Lossb: 5.263e-02, Lossv: 6.535e+00, Time: 0.95
# It: 580, Lossb: 5.049e-02, Lossv: 5.608e+00, Time: 1.03
# It: 590, Lossb: 4.641e-02, Lossv: 4.852e+00, Time: 0.90
# It: 600, Lossb: 4.146e-02, Lossv: 4.240e+00, Time: 0.92
# It: 610, Lossb: 3.639e-02, Lossv: 3.746e+00, Time: 0.89
# It: 620, Lossb: 3.195e-02, Lossv: 3.347e+00, Time: 0.92
# It: 630, Lossb: 2.832e-02, Lossv: 3.038e+00, Time: 0.96
# It: 640, Lossb: 2.524e-02, Lossv: 2.741e+00, Time: 0.94
# It: 650, Lossb: 2.232e-02, Lossv: 2.512e+00, Time: 0.92
# It: 660, Lossb: 1.944e-02, Lossv: 2.310e+00, Time: 0.97
# It: 670, Lossb: 1.671e-02, Lossv: 2.137e+00, Time: 0.92
# It: 680, Lossb: 1.418e-02, Lossv: 1.984e+00, Time: 0.94
# It: 690, Lossb: 1.193e-02, Lossv: 1.847e+00, Time: 0.91
# It: 700, Lossb: 9.996e-03, Lossv: 1.724e+00, Time: 0.95
# It: 710, Lossb: 8.409e-03, Lossv: 1.613e+00, Time: 0.94
# It: 720, Lossb: 7.150e-03, Lossv: 1.511e+00, Time: 0.93
# It: 730, Lossb: 6.188e-03, Lossv: 1.418e+00, Time: 0.95
# It: 740, Lossb: 5.480e-03, Lossv: 1.333e+00, Time: 0.93
# It: 750, Lossb: 4.981e-03, Lossv: 1.255e+00, Time: 0.91
# It: 760, Lossb: 4.647e-03, Lossv: 1.214e+00, Time: 1.02
# It: 770, Lossb: 4.439e-03, Lossv: 1.136e+00, Time: 0.95
# It: 780, Lossb: 4.312e-03, Lossv: 1.060e+00, Time: 0.92
# It: 790, Lossb: 4.243e-03, Lossv: 1.003e+00, Time: 0.92
# It: 800, Lossb: 4.195e-03, Lossv: 9.533e-01, Time: 0.90
# It: 810, Lossb: 4.147e-03, Lossv: 9.065e-01, Time: 0.92
# It: 820, Lossb: 4.086e-03, Lossv: 8.644e-01, Time: 0.98
# It: 830, Lossb: 3.998e-03, Lossv: 8.255e-01, Time: 0.98
# It: 840, Lossb: 3.885e-03, Lossv: 7.897e-01, Time: 1.10
# It: 850, Lossb: 3.747e-03, Lossv: 7.568e-01, Time: 1.05
# It: 860, Lossb: 3.589e-03, Lossv: 7.264e-01, Time: 1.04
# It: 870, Lossb: 3.419e-03, Lossv: 6.982e-01, Time: 1.11
# It: 880, Lossb: 3.239e-03, Lossv: 6.722e-01, Time: 0.94
# It: 890, Lossb: 3.056e-03, Lossv: 6.481e-01, Time: 1.08
# It: 900, Lossb: 2.872e-03, Lossv: 6.258e-01, Time: 0.99
# It: 910, Lossb: 2.689e-03, Lossv: 6.092e-01, Time: 0.97
# It: 920, Lossb: 2.511e-03, Lossv: 5.962e-01, Time: 1.03
# It: 930, Lossb: 2.335e-03, Lossv: 5.804e-01, Time: 0.98
# It: 940, Lossb: 2.166e-03, Lossv: 5.523e-01, Time: 1.01
# It: 950, Lossb: 2.006e-03, Lossv: 5.351e-01, Time: 1.00
# It: 960, Lossb: 1.853e-03, Lossv: 5.207e-01, Time: 1.03
# It: 970, Lossb: 1.712e-03, Lossv: 5.061e-01, Time: 1.06
# It: 980, Lossb: 1.580e-03, Lossv: 4.929e-01, Time: 1.04
# It: 990, Lossb: 1.458e-03, Lossv: 4.802e-01, Time: 1.17
# It: 1000, Lossb: 1.345e-03, Lossv: 4.682e-01, Time: 1.03
# It: 1010, Lossb: 1.241e-03, Lossv: 4.568e-01, Time: 0.95
# It: 1020, Lossb: 1.146e-03, Lossv: 4.458e-01, Time: 0.94
# It: 1030, Lossb: 1.059e-03, Lossv: 4.353e-01, Time: 0.96
# It: 1040, Lossb: 9.796e-04, Lossv: 4.252e-01, Time: 0.93
# It: 1050, Lossb: 9.072e-04, Lossv: 4.155e-01, Time: 1.00
# It: 1060, Lossb: 8.412e-04, Lossv: 4.061e-01, Time: 1.05
# It: 1070, Lossb: 7.808e-04, Lossv: 3.971e-01, Time: 1.10
# It: 1080, Lossb: 7.255e-04, Lossv: 3.888e-01, Time: 1.06
# It: 1090, Lossb: 6.751e-04, Lossv: 4.359e-01, Time: 1.05
# It: 1100, Lossb: 6.298e-04, Lossv: 3.824e-01, Time: 1.02
# It: 1110, Lossb: 5.869e-04, Lossv: 3.718e-01, Time: 1.01
# It: 1120, Lossb: 5.462e-04, Lossv: 3.584e-01, Time: 1.08
# It: 1130, Lossb: 5.109e-04, Lossv: 3.485e-01, Time: 1.13
# It: 1140, Lossb: 4.780e-04, Lossv: 3.408e-01, Time: 1.09
# It: 1150, Lossb: 4.475e-04, Lossv: 3.338e-01, Time: 1.07
# It: 1160, Lossb: 4.190e-04, Lossv: 3.267e-01, Time: 0.95
# It: 1170, Lossb: 3.928e-04, Lossv: 3.199e-01, Time: 1.01
# It: 1180, Lossb: 3.684e-04, Lossv: 3.132e-01, Time: 0.97
# It: 1190, Lossb: 3.460e-04, Lossv: 3.067e-01, Time: 0.94
# It: 1200, Lossb: 3.251e-04, Lossv: 3.004e-01, Time: 0.99
# It: 1210, Lossb: 3.057e-04, Lossv: 2.942e-01, Time: 1.05
# It: 1220, Lossb: 2.878e-04, Lossv: 2.882e-01, Time: 0.99
# It: 1230, Lossb: 2.710e-04, Lossv: 2.823e-01, Time: 0.96
# It: 1240, Lossb: 2.554e-04, Lossv: 2.765e-01, Time: 1.07
# It: 1250, Lossb: 2.408e-04, Lossv: 2.709e-01, Time: 1.00
# It: 1260, Lossb: 2.273e-04, Lossv: 2.654e-01, Time: 0.96
# It: 1270, Lossb: 2.147e-04, Lossv: 2.601e-01, Time: 0.97
# It: 1280, Lossb: 2.028e-04, Lossv: 2.555e-01, Time: 1.10
# It: 1290, Lossb: 1.919e-04, Lossv: 3.227e-01, Time: 1.11
# It: 1300, Lossb: 1.817e-04, Lossv: 2.477e-01, Time: 1.06
# It: 1310, Lossb: 1.724e-04, Lossv: 2.444e-01, Time: 1.02
# It: 1320, Lossb: 1.618e-04, Lossv: 2.377e-01, Time: 1.07
# It: 1330, Lossb: 1.547e-04, Lossv: 2.317e-01, Time: 1.14
# It: 1340, Lossb: 1.466e-04, Lossv: 2.263e-01, Time: 1.02
# It: 1350, Lossb: 1.391e-04, Lossv: 2.216e-01, Time: 0.95
# It: 1360, Lossb: 1.320e-04, Lossv: 2.173e-01, Time: 1.03
# It: 1370, Lossb: 1.255e-04, Lossv: 2.132e-01, Time: 0.99
# It: 1380, Lossb: 1.195e-04, Lossv: 2.091e-01, Time: 0.96
# It: 1390, Lossb: 1.137e-04, Lossv: 2.051e-01, Time: 1.21
# It: 1400, Lossb: 1.083e-04, Lossv: 2.013e-01, Time: 1.07
# It: 1410, Lossb: 1.033e-04, Lossv: 1.975e-01, Time: 0.96
# It: 1420, Lossb: 9.860e-05, Lossv: 1.939e-01, Time: 0.93
# It: 1430, Lossb: 9.418e-05, Lossv: 1.904e-01, Time: 0.95
# It: 1440, Lossb: 8.999e-05, Lossv: 1.869e-01, Time: 0.99
# It: 1450, Lossb: 8.600e-05, Lossv: 1.836e-01, Time: 1.00
# It: 1460, Lossb: 8.229e-05, Lossv: 1.803e-01, Time: 0.95
# It: 1470, Lossb: 7.878e-05, Lossv: 1.772e-01, Time: 0.91
# It: 1480, Lossb: 7.548e-05, Lossv: 1.741e-01, Time: 0.94
# It: 1490, Lossb: 7.234e-05, Lossv: 1.712e-01, Time: 0.93
# It: 1500, Lossb: 6.938e-05, Lossv: 1.683e-01, Time: 0.97
# It: 1510, Lossb: 6.652e-05, Lossv: 1.665e-01, Time: 0.88
# It: 1520, Lossb: 6.406e-05, Lossv: 2.684e-01, Time: 0.93
# It: 1530, Lossb: 6.046e-05, Lossv: 1.727e-01, Time: 0.93
# It: 1540, Lossb: 5.779e-05, Lossv: 1.634e-01, Time: 0.92
# It: 1550, Lossb: 5.610e-05, Lossv: 1.582e-01, Time: 0.92
# It: 1560, Lossb: 5.450e-05, Lossv: 1.540e-01, Time: 0.97
# It: 1570, Lossb: 5.269e-05, Lossv: 1.509e-01, Time: 0.99
# It: 1580, Lossb: 5.025e-05, Lossv: 1.483e-01, Time: 0.93
# It: 1590, Lossb: 4.843e-05, Lossv: 1.460e-01, Time: 0.95
# It: 1600, Lossb: 4.670e-05, Lossv: 1.439e-01, Time: 0.91
# It: 1610, Lossb: 4.496e-05, Lossv: 1.418e-01, Time: 0.91
# It: 1620, Lossb: 4.328e-05, Lossv: 1.398e-01, Time: 0.92
# It: 1630, Lossb: 4.166e-05, Lossv: 1.379e-01, Time: 0.90
# It: 1640, Lossb: 4.009e-05, Lossv: 1.360e-01, Time: 0.92
# It: 1650, Lossb: 3.860e-05, Lossv: 1.342e-01, Time: 0.95
# It: 1660, Lossb: 3.713e-05, Lossv: 1.324e-01, Time: 1.25
# It: 1670, Lossb: 3.574e-05, Lossv: 1.307e-01, Time: 1.01
# It: 1680, Lossb: 3.438e-05, Lossv: 1.290e-01, Time: 1.03
# It: 1690, Lossb: 3.307e-05, Lossv: 1.274e-01, Time: 0.81
# It: 1700, Lossb: 3.182e-05, Lossv: 1.258e-01, Time: 0.89
# It: 1710, Lossb: 3.059e-05, Lossv: 1.242e-01, Time: 0.80
# It: 1720, Lossb: 2.943e-05, Lossv: 1.228e-01, Time: 0.80
# It: 1730, Lossb: 2.829e-05, Lossv: 1.213e-01, Time: 0.80
# It: 1740, Lossb: 2.720e-05, Lossv: 1.199e-01, Time: 0.89
# It: 1750, Lossb: 2.614e-05, Lossv: 1.185e-01, Time: 0.79
# It: 1760, Lossb: 2.513e-05, Lossv: 1.171e-01, Time: 0.88
# It: 1770, Lossb: 2.411e-05, Lossv: 1.160e-01, Time: 0.86
# It: 1780, Lossb: 2.299e-05, Lossv: 1.299e-01, Time: 0.91
# It: 1790, Lossb: 2.322e-05, Lossv: 1.209e-01, Time: 0.96
# It: 1800, Lossb: 2.094e-05, Lossv: 1.159e-01, Time: 0.87
# It: 1810, Lossb: 1.981e-05, Lossv: 1.153e-01, Time: 0.92
# It: 1820, Lossb: 1.965e-05, Lossv: 1.114e-01, Time: 0.95
# It: 1830, Lossb: 1.906e-05, Lossv: 1.087e-01, Time: 0.93
# It: 1840, Lossb: 1.819e-05, Lossv: 1.075e-01, Time: 1.03
# It: 1850, Lossb: 1.762e-05, Lossv: 1.064e-01, Time: 1.00
# It: 1860, Lossb: 1.692e-05, Lossv: 1.052e-01, Time: 0.90
# It: 1870, Lossb: 1.624e-05, Lossv: 1.042e-01, Time: 0.95
# It: 1880, Lossb: 1.565e-05, Lossv: 1.032e-01, Time: 0.87
# It: 1890, Lossb: 1.506e-05, Lossv: 1.021e-01, Time: 0.87
# It: 1900, Lossb: 1.449e-05, Lossv: 1.011e-01, Time: 0.96
# It: 1910, Lossb: 1.396e-05, Lossv: 1.001e-01, Time: 0.94
# It: 1920, Lossb: 1.345e-05, Lossv: 9.918e-02, Time: 0.86
# It: 1930, Lossb: 1.295e-05, Lossv: 9.822e-02, Time: 0.92
# It: 1940, Lossb: 1.250e-05, Lossv: 9.728e-02, Time: 0.92
# It: 1950, Lossb: 1.205e-05, Lossv: 9.636e-02, Time: 0.87
# It: 1960, Lossb: 1.162e-05, Lossv: 9.544e-02, Time: 0.92
# It: 1970, Lossb: 1.125e-05, Lossv: 9.454e-02, Time: 0.88
# It: 1980, Lossb: 1.086e-05, Lossv: 9.365e-02, Time: 1.03
# It: 1990, Lossb: 1.053e-05, Lossv: 9.279e-02, Time: 0.93
# It: 2000, Lossb: 1.046e-05, Lossv: 9.370e-02, Time: 0.94
# It: 2010, Lossb: 1.378e-05, Lossv: 1.733e-01, Time: 0.94
# It: 2020, Lossb: 6.279e-06, Lossv: 9.318e-02, Time: 0.86
# It: 2030, Lossb: 7.518e-06, Lossv: 9.151e-02, Time: 0.89
# It: 2040, Lossb: 9.733e-06, Lossv: 9.044e-02, Time: 0.86
# It: 2050, Lossb: 9.986e-06, Lossv: 8.872e-02, Time: 0.87
# It: 2060, Lossb: 9.162e-06, Lossv: 8.710e-02, Time: 0.91
# It: 2070, Lossb: 8.203e-06, Lossv: 8.613e-02, Time: 0.88
# It: 2080, Lossb: 7.680e-06, Lossv: 8.537e-02, Time: 0.95
# It: 2090, Lossb: 7.748e-06, Lossv: 8.454e-02, Time: 0.93
# It: 2100, Lossb: 7.740e-06, Lossv: 8.376e-02, Time: 0.84
# It: 2110, Lossb: 7.355e-06, Lossv: 8.299e-02, Time: 0.81
# It: 2120, Lossb: 7.235e-06, Lossv: 8.222e-02, Time: 0.86
# It: 2130, Lossb: 7.084e-06, Lossv: 8.147e-02, Time: 0.87
# It: 2140, Lossb: 6.923e-06, Lossv: 8.071e-02, Time: 1.15
# It: 2150, Lossb: 6.764e-06, Lossv: 7.997e-02, Time: 0.85
# It: 2160, Lossb: 6.630e-06, Lossv: 7.923e-02, Time: 0.93
# It: 2170, Lossb: 6.503e-06, Lossv: 7.850e-02, Time: 0.88
# It: 2180, Lossb: 6.392e-06, Lossv: 7.777e-02, Time: 0.90
# It: 2190, Lossb: 6.335e-06, Lossv: 7.705e-02, Time: 0.95
# It: 2200, Lossb: 6.841e-06, Lossv: 7.653e-02, Time: 0.89
# It: 2210, Lossb: 1.188e-05, Lossv: 8.726e-02, Time: 1.02
# It: 2220, Lossb: 5.942e-06, Lossv: 1.100e-01, Time: 0.93
# It: 2230, Lossb: 3.640e-06, Lossv: 8.166e-02, Time: 0.90
# It: 2240, Lossb: 5.313e-06, Lossv: 7.361e-02, Time: 0.81
# It: 2250, Lossb: 6.240e-06, Lossv: 7.368e-02, Time: 0.79
# It: 2260, Lossb: 5.841e-06, Lossv: 7.277e-02, Time: 0.79
# It: 2270, Lossb: 5.570e-06, Lossv: 7.170e-02, Time: 0.81
# It: 2280, Lossb: 5.226e-06, Lossv: 7.092e-02, Time: 0.79
# It: 2290, Lossb: 5.423e-06, Lossv: 7.019e-02, Time: 0.78
# It: 2300, Lossb: 5.301e-06, Lossv: 6.950e-02, Time: 0.89
# It: 2310, Lossb: 5.172e-06, Lossv: 6.885e-02, Time: 0.92
# It: 2320, Lossb: 5.186e-06, Lossv: 6.820e-02, Time: 0.95
# It: 2330, Lossb: 5.112e-06, Lossv: 6.755e-02, Time: 0.92
# It: 2340, Lossb: 5.112e-06, Lossv: 6.695e-02, Time: 0.84
# It: 2350, Lossb: 5.243e-06, Lossv: 6.729e-02, Time: 0.87
# It: 2360, Lossb: 7.335e-06, Lossv: 1.056e-01, Time: 0.93
# It: 2370, Lossb: 4.545e-06, Lossv: 8.187e-02, Time: 0.92
# It: 2380, Lossb: 6.605e-06, Lossv: 6.922e-02, Time: 0.82
# It: 2390, Lossb: 4.369e-06, Lossv: 6.430e-02, Time: 0.86
# It: 2400, Lossb: 3.943e-06, Lossv: 6.414e-02, Time: 0.92
# It: 2410, Lossb: 5.042e-06, Lossv: 6.279e-02, Time: 0.89
# It: 2420, Lossb: 4.836e-06, Lossv: 6.202e-02, Time: 1.00
# It: 2430, Lossb: 4.520e-06, Lossv: 6.140e-02, Time: 0.88
# It: 2440, Lossb: 4.606e-06, Lossv: 6.080e-02, Time: 0.81
# It: 2450, Lossb: 4.548e-06, Lossv: 6.022e-02, Time: 0.95
# It: 2460, Lossb: 4.469e-06, Lossv: 5.965e-02, Time: 1.07
# It: 2470, Lossb: 4.472e-06, Lossv: 5.907e-02, Time: 0.94
# It: 2480, Lossb: 4.435e-06, Lossv: 5.851e-02, Time: 0.95
# It: 2490, Lossb: 4.377e-06, Lossv: 5.795e-02, Time: 1.09
# It: 2500, Lossb: 4.361e-06, Lossv: 5.739e-02, Time: 0.87
# It: 2510, Lossb: 4.414e-06, Lossv: 5.691e-02, Time: 0.89
# It: 2520, Lossb: 5.244e-06, Lossv: 6.090e-02, Time: 1.08
# It: 2530, Lossb: 9.122e-06, Lossv: 1.106e-01, Time: 0.97
# It: 2540, Lossb: 4.319e-06, Lossv: 5.831e-02, Time: 0.92
# It: 2550, Lossb: 3.279e-06, Lossv: 5.842e-02, Time: 0.85
# It: 2560, Lossb: 3.450e-06, Lossv: 5.655e-02, Time: 0.85
# It: 2570, Lossb: 4.196e-06, Lossv: 5.367e-02, Time: 0.87
# It: 2580, Lossb: 4.354e-06, Lossv: 5.351e-02, Time: 1.02
# It: 2590, Lossb: 3.986e-06, Lossv: 5.266e-02, Time: 0.95
# It: 2600, Lossb: 3.809e-06, Lossv: 5.220e-02, Time: 0.86
# It: 2610, Lossb: 3.938e-06, Lossv: 5.168e-02, Time: 0.83
# It: 2620, Lossb: 3.842e-06, Lossv: 5.118e-02, Time: 0.81
# It: 2630, Lossb: 3.825e-06, Lossv: 5.070e-02, Time: 0.86
# It: 2640, Lossb: 3.788e-06, Lossv: 5.022e-02, Time: 0.86
# It: 2650, Lossb: 3.729e-06, Lossv: 4.975e-02, Time: 0.95
# It: 2660, Lossb: 3.688e-06, Lossv: 4.929e-02, Time: 0.99
# It: 2670, Lossb: 3.644e-06, Lossv: 4.883e-02, Time: 1.07
# It: 2680, Lossb: 3.592e-06, Lossv: 4.838e-02, Time: 0.92
# It: 2690, Lossb: 3.548e-06, Lossv: 4.793e-02, Time: 0.93
# It: 2700, Lossb: 3.499e-06, Lossv: 4.749e-02, Time: 0.87
# It: 2710, Lossb: 3.409e-06, Lossv: 4.705e-02, Time: 0.86
# It: 2720, Lossb: 3.089e-06, Lossv: 4.682e-02, Time: 1.04
# It: 2730, Lossb: 1.114e-06, Lossv: 6.508e-02, Time: 1.03
# It: 2740, Lossb: 4.729e-06, Lossv: 5.417e-02, Time: 0.86
# It: 2750, Lossb: 3.625e-06, Lossv: 6.187e-02, Time: 0.84
# It: 2760, Lossb: 3.530e-06, Lossv: 4.592e-02, Time: 1.02
# It: 2770, Lossb: 3.222e-06, Lossv: 4.517e-02, Time: 1.01
# It: 2780, Lossb: 3.030e-06, Lossv: 4.491e-02, Time: 0.87
# It: 2790, Lossb: 3.110e-06, Lossv: 4.376e-02, Time: 0.88
# It: 2800, Lossb: 3.064e-06, Lossv: 4.346e-02, Time: 0.95
# It: 2810, Lossb: 2.995e-06, Lossv: 4.298e-02, Time: 0.94
# It: 2820, Lossb: 2.946e-06, Lossv: 4.261e-02, Time: 0.84
# It: 2830, Lossb: 2.925e-06, Lossv: 4.222e-02, Time: 0.84
# It: 2840, Lossb: 2.870e-06, Lossv: 4.185e-02, Time: 0.93
# It: 2850, Lossb: 2.818e-06, Lossv: 4.149e-02, Time: 0.96
# It: 2860, Lossb: 2.763e-06, Lossv: 4.113e-02, Time: 0.87
# It: 2870, Lossb: 2.712e-06, Lossv: 4.077e-02, Time: 0.85
# It: 2880, Lossb: 2.663e-06, Lossv: 4.042e-02, Time: 0.81
# It: 2890, Lossb: 2.586e-06, Lossv: 4.007e-02, Time: 0.84
# It: 2900, Lossb: 2.326e-06, Lossv: 3.984e-02, Time: 0.94
# It: 2910, Lossb: 4.771e-07, Lossv: 5.508e-02, Time: 0.88
# It: 2920, Lossb: 3.827e-06, Lossv: 5.134e-02, Time: 0.85
# It: 2930, Lossb: 3.703e-06, Lossv: 4.404e-02, Time: 0.82
# It: 2940, Lossb: 3.334e-06, Lossv: 4.065e-02, Time: 0.79
# It: 2950, Lossb: 2.915e-06, Lossv: 3.905e-02, Time: 0.79
# It: 2960, Lossb: 2.399e-06, Lossv: 3.778e-02, Time: 0.79
# It: 2970, Lossb: 2.210e-06, Lossv: 3.749e-02, Time: 0.83
# It: 2980, Lossb: 2.142e-06, Lossv: 3.760e-02, Time: 0.87
# It: 2990, Lossb: 2.181e-06, Lossv: 5.020e-02, Time: 0.87
# It: 3000, Lossb: 2.088e-06, Lossv: 3.810e-02, Time: 0.94
# It: 3010, Lossb: 2.109e-06, Lossv: 3.790e-02, Time: 1.01
# It: 3020, Lossb: 2.310e-06, Lossv: 3.867e-02, Time: 0.95
# It: 3030, Lossb: 1.781e-06, Lossv: 3.656e-02, Time: 0.98
# It: 3040, Lossb: 2.200e-06, Lossv: 3.554e-02, Time: 0.90
# It: 3050, Lossb: 1.846e-06, Lossv: 3.510e-02, Time: 0.89
# It: 3060, Lossb: 2.017e-06, Lossv: 3.479e-02, Time: 0.88
# It: 3070, Lossb: 1.813e-06, Lossv: 3.450e-02, Time: 0.88
# It: 3080, Lossb: 1.891e-06, Lossv: 3.420e-02, Time: 0.93
# It: 3090, Lossb: 1.823e-06, Lossv: 3.391e-02, Time: 1.07
# It: 3100, Lossb: 1.758e-06, Lossv: 3.364e-02, Time: 0.91
# It: 3110, Lossb: 1.707e-06, Lossv: 3.337e-02, Time: 0.88
# It: 3120, Lossb: 1.615e-06, Lossv: 3.314e-02, Time: 0.93
# It: 3130, Lossb: 1.223e-06, Lossv: 3.444e-02, Time: 0.92
# It: 3140, Lossb: 6.642e-07, Lossv: 8.474e-02, Time: 0.88
# It: 3150, Lossb: 2.565e-06, Lossv: 5.460e-02, Time: 0.88
# It: 3160, Lossb: 1.706e-06, Lossv: 3.436e-02, Time: 0.89
# It: 3170, Lossb: 1.533e-06, Lossv: 3.360e-02, Time: 1.03
# It: 3180, Lossb: 1.728e-06, Lossv: 3.225e-02, Time: 0.98
# It: 3190, Lossb: 1.361e-06, Lossv: 3.139e-02, Time: 0.97
# It: 3200, Lossb: 1.553e-06, Lossv: 3.117e-02, Time: 0.90
# It: 3210, Lossb: 1.370e-06, Lossv: 3.082e-02, Time: 0.97
# It: 3220, Lossb: 1.457e-06, Lossv: 3.054e-02, Time: 0.97
# It: 3230, Lossb: 1.382e-06, Lossv: 3.029e-02, Time: 0.96
# It: 3240, Lossb: 1.359e-06, Lossv: 3.005e-02, Time: 0.99
# It: 3250, Lossb: 1.344e-06, Lossv: 2.981e-02, Time: 1.02
# It: 3260, Lossb: 1.333e-06, Lossv: 2.957e-02, Time: 1.09
# It: 3270, Lossb: 1.352e-06, Lossv: 2.935e-02, Time: 0.97
# It: 3280, Lossb: 1.684e-06, Lossv: 2.982e-02, Time: 0.97
# It: 3290, Lossb: 3.929e-06, Lossv: 4.578e-02, Time: 0.96
# It: 3300, Lossb: 9.929e-07, Lossv: 4.485e-02, Time: 0.96
# It: 3310, Lossb: 8.719e-07, Lossv: 2.952e-02, Time: 0.97
# It: 3320, Lossb: 1.532e-06, Lossv: 2.954e-02, Time: 0.97
# It: 3330, Lossb: 1.366e-06, Lossv: 2.899e-02, Time: 0.94
# It: 3340, Lossb: 1.081e-06, Lossv: 2.786e-02, Time: 0.92
# It: 3350, Lossb: 1.193e-06, Lossv: 2.774e-02, Time: 0.92
# It: 3360, Lossb: 1.077e-06, Lossv: 2.793e-02, Time: 0.90
# It: 3370, Lossb: 1.044e-06, Lossv: 3.142e-02, Time: 0.96
# It: 3380, Lossb: 9.785e-07, Lossv: 4.596e-02, Time: 0.97
# It: 3390, Lossb: 1.161e-06, Lossv: 3.044e-02, Time: 0.99
# It: 3400, Lossb: 1.327e-06, Lossv: 2.712e-02, Time: 0.92
# It: 3410, Lossb: 8.187e-07, Lossv: 2.675e-02, Time: 0.96
# It: 3420, Lossb: 1.000e-06, Lossv: 2.620e-02, Time: 1.03
# It: 3430, Lossb: 1.199e-06, Lossv: 2.607e-02, Time: 0.92
# It: 3440, Lossb: 1.260e-06, Lossv: 2.610e-02, Time: 0.88
# It: 3450, Lossb: 1.576e-06, Lossv: 2.795e-02, Time: 0.97
# It: 3460, Lossb: 2.125e-06, Lossv: 4.299e-02, Time: 0.94
# It: 3470, Lossb: 1.098e-06, Lossv: 2.593e-02, Time: 0.90
# It: 3480, Lossb: 7.371e-07, Lossv: 2.546e-02, Time: 1.14
# It: 3490, Lossb: 1.060e-06, Lossv: 2.480e-02, Time: 1.01
# It: 3500, Lossb: 1.038e-06, Lossv: 2.462e-02, Time: 0.96
# It: 3510, Lossb: 9.724e-07, Lossv: 2.439e-02, Time: 0.95
# It: 3520, Lossb: 9.363e-07, Lossv: 2.424e-02, Time: 0.99
# It: 3530, Lossb: 1.159e-06, Lossv: 2.464e-02, Time: 0.96
# It: 3540, Lossb: 2.425e-06, Lossv: 3.826e-02, Time: 0.95
# It: 3550, Lossb: 4.031e-07, Lossv: 3.174e-02, Time: 0.95
# It: 3560, Lossb: 1.388e-06, Lossv: 2.586e-02, Time: 0.92
# It: 3570, Lossb: 9.578e-07, Lossv: 2.348e-02, Time: 0.88
# It: 3580, Lossb: 8.582e-07, Lossv: 2.331e-02, Time: 0.90
# It: 3590, Lossb: 1.104e-06, Lossv: 2.532e-02, Time: 0.96
# It: 3600, Lossb: 1.664e-06, Lossv: 5.106e-02, Time: 0.94
# It: 3610, Lossb: 8.167e-07, Lossv: 2.927e-02, Time: 1.06
# It: 3620, Lossb: 9.477e-07, Lossv: 2.547e-02, Time: 0.97
# It: 3630, Lossb: 7.952e-07, Lossv: 2.352e-02, Time: 0.97
# It: 3640, Lossb: 1.010e-06, Lossv: 2.235e-02, Time: 0.92
# It: 3650, Lossb: 6.802e-07, Lossv: 2.188e-02, Time: 0.86
# It: 3660, Lossb: 6.933e-07, Lossv: 2.178e-02, Time: 0.98
# It: 3670, Lossb: 4.535e-07, Lossv: 2.355e-02, Time: 0.86
# It: 3680, Lossb: 1.260e-07, Lossv: 2.973e-02, Time: 0.98
# It: 3690, Lossb: 1.155e-06, Lossv: 2.658e-02, Time: 0.87
# It: 3700, Lossb: 4.607e-07, Lossv: 2.433e-02, Time: 0.85
# It: 3710, Lossb: 8.461e-07, Lossv: 2.268e-02, Time: 0.81
# It: 3720, Lossb: 5.594e-07, Lossv: 2.268e-02, Time: 0.94
# It: 3730, Lossb: 5.337e-07, Lossv: 2.678e-02, Time: 0.97
# It: 3740, Lossb: 3.540e-07, Lossv: 2.747e-02, Time: 0.85
# It: 3750, Lossb: 6.268e-07, Lossv: 2.140e-02, Time: 0.87
# It: 3760, Lossb: 1.049e-06, Lossv: 2.069e-02, Time: 0.92
# It: 3770, Lossb: 9.185e-07, Lossv: 2.086e-02, Time: 0.84
# It: 3780, Lossb: 1.589e-06, Lossv: 2.484e-02, Time: 0.90
# It: 3790, Lossb: 1.308e-06, Lossv: 3.047e-02, Time: 0.90
# It: 3800, Lossb: 1.625e-06, Lossv: 2.395e-02, Time: 0.89
# It: 3810, Lossb: 3.533e-07, Lossv: 2.217e-02, Time: 0.99
# It: 3820, Lossb: 6.520e-07, Lossv: 2.054e-02, Time: 0.92
# It: 3830, Lossb: 1.006e-06, Lossv: 1.977e-02, Time: 0.97
# It: 3840, Lossb: 1.242e-07, Lossv: 2.023e-02, Time: 1.09
# It: 3850, Lossb: 1.069e-07, Lossv: 2.924e-02, Time: 0.98
# It: 3860, Lossb: 8.585e-07, Lossv: 2.258e-02, Time: 0.92
# It: 3870, Lossb: 5.051e-07, Lossv: 2.025e-02, Time: 0.87
# It: 3880, Lossb: 4.750e-07, Lossv: 2.005e-02, Time: 0.93
# It: 3890, Lossb: 6.146e-07, Lossv: 2.644e-02, Time: 1.01
# It: 3900, Lossb: 8.911e-08, Lossv: 2.656e-02, Time: 0.97
# It: 3910, Lossb: 1.134e-06, Lossv: 2.065e-02, Time: 0.92
# It: 3920, Lossb: 1.216e-06, Lossv: 1.849e-02, Time: 1.05
# It: 3930, Lossb: 3.230e-07, Lossv: 1.801e-02, Time: 1.01
# It: 3940, Lossb: 4.106e-07, Lossv: 1.799e-02, Time: 1.04
# It: 3950, Lossb: 2.445e-07, Lossv: 1.987e-02, Time: 1.17
# It: 3960, Lossb: 7.233e-08, Lossv: 2.729e-02, Time: 1.04
# It: 3970, Lossb: 4.656e-07, Lossv: 3.509e-02, Time: 1.00
# It: 3980, Lossb: 6.115e-07, Lossv: 2.373e-02, Time: 1.09
# It: 3990, Lossb: 1.212e-06, Lossv: 1.945e-02, Time: 0.98
# It: 4000, Lossb: 4.632e-07, Lossv: 1.767e-02, Time: 0.98
# It: 4010, Lossb: 4.320e-07, Lossv: 1.706e-02, Time: 0.99
# It: 4020, Lossb: 2.071e-07, Lossv: 2.077e-02, Time: 1.04
# It: 4030, Lossb: 2.448e-08, Lossv: 1.967e-02, Time: 0.96
# It: 4040, Lossb: 1.015e-06, Lossv: 1.691e-02, Time: 1.00
# It: 4050, Lossb: 2.407e-07, Lossv: 1.647e-02, Time: 0.92
# It: 4060, Lossb: 6.180e-07, Lossv: 1.688e-02, Time: 0.96
# It: 4070, Lossb: 2.888e-07, Lossv: 2.710e-02, Time: 1.05
# It: 4080, Lossb: 2.500e-07, Lossv: 2.576e-02, Time: 1.02
# It: 4090, Lossb: 1.454e-06, Lossv: 1.749e-02, Time: 1.00
# It: 4100, Lossb: 3.462e-07, Lossv: 1.575e-02, Time: 0.98
# It: 4110, Lossb: 4.270e-07, Lossv: 1.557e-02, Time: 0.98
# It: 4120, Lossb: 7.668e-07, Lossv: 1.557e-02, Time: 1.05
# It: 4130, Lossb: 4.076e-07, Lossv: 1.541e-02, Time: 1.00
# It: 4140, Lossb: 4.906e-07, Lossv: 1.525e-02, Time: 0.99
# It: 4150, Lossb: 4.076e-07, Lossv: 1.520e-02, Time: 0.93
# It: 4160, Lossb: 8.177e-08, Lossv: 1.712e-02, Time: 0.90
# It: 4170, Lossb: 2.242e-07, Lossv: 2.993e-02, Time: 0.88
# It: 4180, Lossb: 1.165e-06, Lossv: 3.464e-02, Time: 0.93
# It: 4190, Lossb: 4.188e-07, Lossv: 1.609e-02, Time: 1.00
# It: 4200, Lossb: 4.107e-07, Lossv: 1.489e-02, Time: 0.91
# It: 4210, Lossb: 6.067e-07, Lossv: 1.550e-02, Time: 0.88
# It: 4220, Lossb: 2.731e-07, Lossv: 1.472e-02, Time: 0.88
# It: 4230, Lossb: 5.376e-07, Lossv: 1.451e-02, Time: 0.87
# It: 4240, Lossb: 3.226e-07, Lossv: 1.426e-02, Time: 0.89
# It: 4250, Lossb: 1.068e-07, Lossv: 1.474e-02, Time: 0.91
# It: 4260, Lossb: 4.050e-08, Lossv: 1.952e-02, Time: 0.95
# It: 4270, Lossb: 1.860e-06, Lossv: 1.696e-02, Time: 1.05
# It: 4280, Lossb: 1.229e-06, Lossv: 7.101e-02, Time: 0.96
# It: 4290, Lossb: 1.113e-06, Lossv: 3.447e-02, Time: 0.93
# It: 4300, Lossb: 4.504e-07, Lossv: 1.496e-02, Time: 1.01
# It: 4310, Lossb: 1.336e-07, Lossv: 1.622e-02, Time: 0.91
# It: 4320, Lossb: 6.500e-07, Lossv: 1.361e-02, Time: 0.90
# It: 4330, Lossb: 5.640e-07, Lossv: 1.405e-02, Time: 0.86
# It: 4340, Lossb: 1.123e-06, Lossv: 1.503e-02, Time: 0.86
# It: 4350, Lossb: 1.929e-06, Lossv: 2.041e-02, Time: 0.89
# It: 4360, Lossb: 1.442e-07, Lossv: 1.382e-02, Time: 0.90
# It: 4370, Lossb: 3.186e-07, Lossv: 1.312e-02, Time: 1.10
# It: 4380, Lossb: 5.896e-07, Lossv: 1.341e-02, Time: 0.93
# It: 4390, Lossb: 3.343e-07, Lossv: 1.289e-02, Time: 0.91
# It: 4400, Lossb: 2.429e-07, Lossv: 1.297e-02, Time: 0.92
# It: 4410, Lossb: 1.518e-07, Lossv: 1.320e-02, Time: 0.92
# It: 4420, Lossb: 2.617e-09, Lossv: 1.657e-02, Time: 0.89
# It: 4430, Lossb: 2.119e-08, Lossv: 1.808e-02, Time: 0.90
# It: 4440, Lossb: 7.836e-07, Lossv: 1.934e-02, Time: 0.86
# It: 4450, Lossb: 3.292e-08, Lossv: 1.664e-02, Time: 0.88
# It: 4460, Lossb: 3.639e-07, Lossv: 1.248e-02, Time: 0.89
# It: 4470, Lossb: 5.491e-07, Lossv: 1.257e-02, Time: 0.92
# It: 4480, Lossb: 4.815e-07, Lossv: 1.424e-02, Time: 0.92
# It: 4490, Lossb: 1.857e-06, Lossv: 3.074e-02, Time: 0.89
# It: 4500, Lossb: 2.886e-06, Lossv: 1.688e-02, Time: 0.90
# It: 4510, Lossb: 6.923e-09, Lossv: 1.354e-02, Time: 0.91
# It: 4520, Lossb: 4.444e-07, Lossv: 1.274e-02, Time: 0.88
# It: 4530, Lossb: 3.335e-07, Lossv: 1.235e-02, Time: 0.89
# It: 4540, Lossb: 1.220e-07, Lossv: 1.215e-02, Time: 0.90
# It: 4550, Lossb: 5.972e-08, Lossv: 1.923e-02, Time: 0.94
# It: 4560, Lossb: 5.031e-08, Lossv: 1.316e-02, Time: 0.92
# It: 4570, Lossb: 2.413e-07, Lossv: 1.782e-02, Time: 0.93
# It: 4580, Lossb: 4.554e-07, Lossv: 1.815e-02, Time: 0.96
# It: 4590, Lossb: 1.824e-07, Lossv: 1.224e-02, Time: 0.86
# It: 4600, Lossb: 4.597e-07, Lossv: 1.262e-02, Time: 0.85
# It: 4610, Lossb: 2.755e-07, Lossv: 1.131e-02, Time: 0.86
# It: 4620, Lossb: 2.126e-07, Lossv: 1.130e-02, Time: 0.86
# It: 4630, Lossb: 2.193e-07, Lossv: 1.194e-02, Time: 0.86
# It: 4640, Lossb: 2.058e-07, Lossv: 2.533e-02, Time: 0.85
# It: 4650, Lossb: 1.379e-07, Lossv: 1.999e-02, Time: 0.86
# It: 4660, Lossb: 8.756e-07, Lossv: 1.156e-02, Time: 0.85
# It: 4670, Lossb: 5.129e-08, Lossv: 1.137e-02, Time: 0.84
# It: 4680, Lossb: 3.595e-07, Lossv: 1.122e-02, Time: 0.85
# It: 4690, Lossb: 1.930e-07, Lossv: 1.097e-02, Time: 0.86
# It: 4700, Lossb: 2.333e-07, Lossv: 1.076e-02, Time: 0.86
# It: 4710, Lossb: 2.488e-07, Lossv: 1.076e-02, Time: 0.91
# It: 4720, Lossb: 1.369e-07, Lossv: 1.067e-02, Time: 0.90
# It: 4730, Lossb: 3.118e-08, Lossv: 1.121e-02, Time: 0.88
# It: 4740, Lossb: 3.237e-07, Lossv: 2.175e-02, Time: 0.87
# It: 4750, Lossb: 1.110e-06, Lossv: 2.477e-02, Time: 0.94
# It: 4760, Lossb: 5.552e-08, Lossv: 1.351e-02, Time: 0.92
# It: 4770, Lossb: 9.372e-07, Lossv: 1.305e-02, Time: 0.92
# It: 4780, Lossb: 3.717e-08, Lossv: 1.203e-02, Time: 0.90
# It: 4790, Lossb: 4.419e-07, Lossv: 1.085e-02, Time: 0.88
# It: 4800, Lossb: 1.272e-07, Lossv: 1.018e-02, Time: 0.90
# It: 4810, Lossb: 9.024e-08, Lossv: 1.028e-02, Time: 1.01
# It: 4820, Lossb: 1.310e-08, Lossv: 1.092e-02, Time: 0.96
# It: 4830, Lossb: 1.936e-07, Lossv: 1.563e-02, Time: 0.93
# It: 4840, Lossb: 6.822e-07, Lossv: 1.323e-02, Time: 0.89
# It: 4850, Lossb: 2.747e-07, Lossv: 3.735e-02, Time: 0.89
# It: 4860, Lossb: 1.814e-07, Lossv: 1.945e-02, Time: 0.88
# It: 4870, Lossb: 9.571e-07, Lossv: 1.353e-02, Time: 0.88
# It: 4880, Lossb: 1.282e-07, Lossv: 1.084e-02, Time: 0.87
# It: 4890, Lossb: 6.598e-08, Lossv: 1.029e-02, Time: 0.85
# It: 4900, Lossb: 1.259e-07, Lossv: 9.670e-03, Time: 0.88
# It: 4910, Lossb: 1.919e-07, Lossv: 9.636e-03, Time: 0.89
# It: 4920, Lossb: 2.538e-07, Lossv: 9.792e-03, Time: 0.87
# It: 4930, Lossb: 1.024e-06, Lossv: 1.413e-02, Time: 0.86
# It: 4940, Lossb: 9.099e-07, Lossv: 1.619e-02, Time: 0.85
# It: 4950, Lossb: 4.536e-07, Lossv: 1.868e-02, Time: 0.86
# It: 4960, Lossb: 2.697e-08, Lossv: 1.009e-02, Time: 0.87
# It: 4970, Lossb: 3.427e-07, Lossv: 1.136e-02, Time: 0.86
# It: 4980, Lossb: 2.306e-08, Lossv: 9.983e-03, Time: 0.86
# It: 4990, Lossb: 2.458e-07, Lossv: 9.304e-03, Time: 0.97
# It: 5000, Lossb: 9.334e-08, Lossv: 9.189e-03, Time: 0.88

# %%
font = 24
#all loss
fig, ax = plt.subplots()
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off') 
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss \,\, values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
iteration = [total_record[i][0] for i in range(len(total_record))]
loss_his  = [total_record[i][1] for i in range(len(total_record))]
plt.plot(iteration, loss_his,'green',label="loss")
plt.legend(loc="upper right")
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# plt.savefig('loss.pdf')
#++++++++++++++++++++++++++++
#partial loss
fig, ax = plt.subplots()
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off')
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss \,\, values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
iteration = [total_record[i][0] for i in range(len(total_record))]
loss_his  = [total_record[i][1] for i in range(len(total_record))]
loss_b  = [total_record[i][2] for i in range(len(total_record))]
loss_v  = [total_record[i][3] for i in range(len(total_record))]
plt.plot(iteration, loss_his,'green',label="loss")
plt.plot(iteration, loss_b,'blue',label="boundary_loss")
plt.plot(iteration, loss_v, 'violet',label="variational_loss")
plt.legend(loc="upper right")
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()

# %%
x_test=tf.convert_to_tensor(np.linspace(-1,1,100),tf.float32)
y_test=tf.convert_to_tensor(params.u_exact(x_test))

plt.plot(x_test,y_test, '.', label="data")
plt.plot(x_test, model(x_test), label='Trained predictions')
plt.title('After training')
plt.legend();

# %%
x_test=tf.convert_to_tensor(np.linspace(-1,1,100),tf.float32)
y_test=tf.convert_to_tensor(params.u_exact(x_test))


u_pred=model(x_test)
y_test=tf.expand_dims(y_test,axis=1)

fig = plt.figure(0)
gridspec.GridSpec(3,1)


# plt.savefig('Train-Quad-pnts.pdf')    
#++++++++++++++++++++++++++++

font = 24
#all loss
fig, ax = plt.subplots()
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off') 
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss \,\, values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
iteration = [total_record[i][0] for i in range(len(total_record))]
loss_his  = [total_record[i][1] for i in range(len(total_record))]
plt.plot(iteration, loss_his,'green',label="loss")
plt.legend(loc="upper right")
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# plt.savefig('loss.pdf')
#++++++++++++++++++++++++++++
#partial loss
fig, ax = plt.subplots()
plt.tick_params(axis='y', which='both', labelleft='on', labelright='off')
plt.xlabel('$iteration$', fontsize = font)
plt.ylabel('$loss \,\, values$', fontsize = font)
plt.yscale('log')
plt.grid(True)
iteration = [total_record[i][0] for i in range(len(total_record))]
loss_his  = [total_record[i][1] for i in range(len(total_record))]
loss_b  = [total_record[i][2] for i in range(len(total_record))]
loss_v  = [total_record[i][3] for i in range(len(total_record))]
plt.plot(iteration, loss_his,'green',label="loss")
plt.plot(iteration, loss_b,'blue',label="boundary_loss")
plt.plot(iteration, loss_v, 'violet',label="variational_loss")
plt.legend(loc="upper right")
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()


pnt_skip = 25
fig, ax = plt.subplots()
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=8)

plt.xlabel('$x$', fontsize = font)
plt.ylabel('$u$', fontsize = font)
plt.axhline(0, linewidth=0.8, linestyle='-', color='gray')
for xc in params.grid:
    plt.axvline(x=xc, linewidth=2, ls = '--')
plt.plot(x_test, y_test, linewidth=1, color='r', label=''.join(['$exact$']))
plt.plot(x_test, u_pred, 'k*', label='$VPINN$')
plt.tick_params( labelsize = 20)
legend = plt.legend(shadow=True, loc='upper left', fontsize=18, ncol = 1)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# plt.savefig('prediction.pdf')
#++++++++++++++++++++++++++++

fig, ax = plt.subplots()
plt.locator_params(axis='x', nbins=6)
plt.locator_params(axis='y', nbins=8)
plt.xlabel('$x$', fontsize = font)
plt.ylabel('point-wise error', fontsize = font)
plt.yscale('log')
plt.axhline(0, linewidth=0.8, linestyle='-', color='gray')
for xc in params.grid:
    plt.axvline(x=xc, linewidth=2, ls = '--')
plt.plot(x_test, abs(y_test - u_pred), 'k')
plt.tick_params( labelsize = 20)
fig.set_size_inches(w=11,h=5.5)
plt.show()
# Out:
# /tmp/ipykernel_18056/878080555.py:79: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.axvline(x=xc, linewidth=2, ls = '--')
