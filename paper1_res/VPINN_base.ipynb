# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from pyDOE import lhs

import sys
sys.path.insert(1, '/kaggle/input/quadrule')

from GaussJacobiQuadRule_V3 import Jacobi, DJacobi, GaussLobattoJacobiWeights, GaussJacobiWeights
import time
import os


#notes:
#remove all persistent==true can slow down the code
#maybe is not the best use to save in memory all the traslated elem elements,just save all the test fuction and the derivatives of the test functions
#two different inits,implemented
#maybe use diff quad rules,for istance quadpy
#

# %% [markdown]
# ![](poisson.png)

# %% [markdown]
# ![](poisson_example.png)

# %%
class VPINN(tf.keras.Model):

    def __init__(self, pb, params,seed,NN):

        super().__init__()

        # accept parameters
        self.pb = pb
        self.params = params
        self.SEED=seed

        # generate all precomp stuff
        self.generate_boundary_points()
        self.generate_inner_points()
        self.generate_quadrature_points()
        self.construct_RHS()

        # add the neural network to the class if given at initialisation
        if NN:
            self.set_NN(NN)
        else: 
            self.NN=self.initialize_NN()
            self.vars = self.NN.trainable_variables
            self.optimizer = tf.keras.optimizers.Adam(learning_rate=self.params['LR'])

    def set_NN(self, NN, LR):
        np.random.seed(self.SEED)
        tf.random.set_seed(self.SEED)
        # initialise the NN
        self.NN = NN

        # take trainable vars
        self.vars = self.NN.trainable_variables

        # set optimiser
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=LR)

    def initialize_NN(self):

        NN = tf.keras.Sequential()
        NN.add(tf.keras.layers.InputLayer(self.params['NN_struct'][0],dtype=tf.float64))
        # NN.add(tf.keras.layers.Lambda(lambda x: 2. * (x + 1) / (2) - 1.))

        for width in self.params['NN_struct'][1:-1]:
            NN.add(tf.keras.layers.Dense(width,
                                            activation=tf.math.sin,
                                            use_bias=True,
                                            kernel_initializer=tf.keras.initializers.GlorotUniform(self.SEED),
                                            bias_initializer='zeros',dtype=tf.float64))
        NN.add(tf.keras.layers.Dense(self.params['NN_struct'][-1], activation='linear',dtype=tf.float64,kernel_initializer=tf.keras.initializers.GlorotUniform(self.SEED)))

        return NN


    def eval_NN(self, x):
        x = tf.convert_to_tensor(x, dtype=tf.float64)        

        with tf.GradientTape() as second_order:
            second_order.watch(x)
            with tf.GradientTape() as first_order:
                first_order.watch(x)
                u = self.NN(x)
            d1xu = first_order.gradient(u, x)
        d2xu = second_order.gradient(d1xu, x)

        del first_order
        del second_order

        return u, d1xu, d2xu

    def boundary_loss(self):
    ## NOTE:impose boundary or same structure for ICs
        u_bound_NN = self.eval_NN(self.boundary_points)[0]
        return tf.reduce_mean(tf.square(u_bound_NN - self.boundary_sol))

    def variational_loss(self):
        #TODO: general organisation
        varloss_total = 0.0
        N = self.params['n_elements']
        for el in range(N):
                
            n_test = self.params['n_test'][el]

            F_ext_element = self.F_ext_total[el]
            jacobian = self.J[el]
            x_quad_element = self.x_quad_total[el]
            v_quad_element = self.v_quad_total[el]
            dv_quad_element = self.dv_quad_total[el]
            dv_boundary_element = self.dv_boundary_total[el]
            d2v_quad_element = self.d2v_quad_total[el]


            u_NN_quad_el, d1xu_NN_quad_el, d2xu_NN_quad_el = self.eval_NN(x_quad_element)
            # dv_boundary_element, _ = self.pb.dtest_func(n_test, np.array([-1, 1]))

            if self.params['var_form'] == 0:
                u_NN_el = tf.stack([-jacobian*tf.reduce_sum(self.w_quad*d2xu_NN_quad_el*v_quad_element[i]) \
                                    for i in range(n_test)])




            elif self.params['var_form'] == 1:
                u_NN_el = tf.stack([tf.reduce_sum(self.w_quad*d1xu_NN_quad_el*dv_quad_element[i]) \
                                    for i in range(n_test)])   #it seems it this way that the test functions of the elem are scaled by the the half of the interval size,so when they are sclaed by the jacobian it cancels
                


            elif self.params['var_form'] == 2:
                u_NN_bound_el, _, _  = self.eval_NN(np.array([x_quad_element[0], x_quad_element[-1]]))
                u_NN_el = tf.stack([-1/jacobian*tf.reduce_sum(self.w_quad*u_NN_quad_el*d2v_quad_element[i]) \
                                    +1/jacobian*tf.reduce_sum(u_NN_bound_el*np.array([-dv_boundary_element[i][0], dv_boundary_element[i][-1]]))  \
                                    for i in range(n_test)])
            

            res_NN_element = u_NN_el - F_ext_element
            loss_element = tf.reduce_mean(tf.square(res_NN_element))
            varloss_total = varloss_total + loss_element*self.params['tau']


        return varloss_total

    @tf.function
    def loss_total(self):
        loss_0 = 0.0
        loss_b = self.boundary_loss()
        loss_v = self.variational_loss()
        loss_tot = loss_0 + loss_b + loss_v
        return loss_tot, loss_b, loss_v

    def loss_gradient(self):
        with tf.GradientTape() as loss_grad:
            #TODO: why is this commented?
            # loss_grad.watch(self.vars)
            loss_tot, loss_b, loss_v = self.loss_total()
        gradient = loss_grad.gradient(loss_tot, self.vars)
        return loss_tot, loss_b, loss_v, gradient

    @tf.function
    def gradient_descent(self):
        loss_tot, loss_b, loss_v, gradient = self.loss_gradient()
        self.optimizer.apply_gradients(zip(gradient, self.vars))
        return loss_tot, loss_b, loss_v

    def train(self, opt_iter):

        history = []

        start_time = time.time()
        for i in range(opt_iter):

            loss_tot, loss_b, loss_v = self.gradient_descent()

            if i % 10 == 0:
                history.append([i, loss_tot, loss_b, loss_v])


            if i % 100 == 0:
                elapsed = time.time() - start_time
                str_print = 'It: %d, Lossb: %.3e, Lossv: %.3e, Losstot:, %.3e, Time: %.2f'
                print(str_print % (i, loss_b, loss_v, loss_tot, elapsed))
                start_time = time.time()

        history = np.array(history)
        self.iterations = history[:,0]
        self.loss_tot = history[:,1]
        self.loss_b = history[:,2]
        self.loss_v = history[:,3]

        return self.loss_tot

    def get_domain_info(self):

        a = self.params['domain'][0]
        b = self.params['domain'][1]

        scale = b - a
        mid = (a + b)*0.5

        return a, b, scale, mid

    def generate_boundary_points(self):
        # Boundary points
        a, b, scale, mid = self.get_domain_info()

        self.boundary_points = np.asarray([a,b], dtype=np.float64)[:,None]
        self.boundary_sol = self.pb.u_exact(self.boundary_points)


    def generate_inner_points(self):
        _, _, scale, mid = self.get_domain_info()

        self.X_f_train = np.array(scale*(lhs(1, self.params['n_bound']) - 0.5) + mid).flatten()
        self.f_train = np.asarray(self.pb.f_exact(self.X_f_train))
        # self.f_train = ff[:, None]

    def generate_quadrature_points(self):
        [self.x_quad, self.w_quad] = GaussLobattoJacobiWeights(self.params['n_quad'], 0, 0)



    def construct_RHS(self):
        #TODO: check are the convert to tensors are needed
        N = self.params['n_elements']
        lower_bound, upper_bound, _, _ = self.get_domain_info()
        dx = (upper_bound - lower_bound)/N
        self.grid_x = np.asarray([lower_bound + i*dx for i in range(N+1)])
        n_test_funcs = self.params['n_test']

        self.U_ext_total = []
        self.F_ext_total = []
        self.J = []
        self.x_quad_total = []
        self.v_quad_total = []
        self.dv_quad_total = []
        self.dv_boundary_total = []
        self.d2v_quad_total = []

        for el_x in range(N):
            Ntest_element = n_test_funcs[el_x]

            a = self.grid_x[el_x]
            b = self.grid_x[el_x+1]

            jacobian = (b - a)/2
            x_quad_element = a + jacobian*(self.x_quad+1)

            v_quad_element = self.pb.test_func(Ntest_element, self.x_quad)        
            dv_quad_element, d2v_quad_element = self.pb.dtest_func(Ntest_element, self.x_quad)
            dv_boundary_element, _ = self.pb.dtest_func(Ntest_element, np.array([a, b]))

            u_quad_element = self.pb.u_exact(x_quad_element)
            f_quad_element = self.pb.f_exact(x_quad_element)

            U_ext_element = np.asarray([jacobian*np.sum(self.w_quad*v_quad_element[r]*u_quad_element)
                for r in range(Ntest_element)])

            F_ext_element = np.asarray([jacobian*np.sum(self.w_quad*v_quad_element[r]*f_quad_element)
                for r in range(Ntest_element)])


            self.U_ext_total.append(U_ext_element)
            self.F_ext_total.append(F_ext_element)
            self.J.append(jacobian)
            self.x_quad_total.append(x_quad_element)
            self.v_quad_total.append(v_quad_element)
            self.dv_quad_total.append(dv_quad_element)
            self.dv_boundary_total.append(dv_boundary_element)
            self.d2v_quad_total.append(d2v_quad_element)

            
        self.F_ext_total = tf.convert_to_tensor(self.F_ext_total, tf.float64)

    def generate_test_points(self):
        lower_bound, upper_bound, _, _ = self.get_domain_info()

        delta_test = self.params['delta_test']
        x_test = np.arange(lower_bound, upper_bound + delta_test, delta_test)
        data_temp = np.asarray([[x_test[i], self.pb.u_exact(x_test[i])]
                                 for i in range(len(x_test))])
    
        x_test = data_temp.flatten()[0::2]
        exact = data_temp.flatten()[1::2]
        return x_test[:, None], exact[:, None], len(x_test)
    

    def plot_loss_history(self, PLOT='SHOW'):

        font = 24
        fig, ax = plt.subplots()
        plt.tick_params(axis='y', which='both', labelleft='on', labelright='off') 
        plt.xlabel('$iteration$', fontsize = font)
        plt.ylabel('$loss \,\, values$', fontsize = font)
        plt.yscale('log')
        plt.grid(True)
        plt.plot(self.iterations, self.loss_tot,'green',label="loss")
        plt.legend(loc="upper right")
        plt.tick_params( labelsize = 20)
        fig.set_size_inches(w=11,h=5.5)
        plt.show()
        
        fig, ax = plt.subplots()
        plt.tick_params(axis='y', which='both', labelleft='on', labelright='off')
        plt.xlabel('$iteration$', fontsize = font)
        plt.ylabel('$loss \,\, values$', fontsize = font)
        plt.yscale('log')
        plt.grid(True)
        plt.plot(self.iterations, self.loss_tot,'green',label="loss")
        plt.plot(self.iterations, self.loss_b,'blue',label="boundary_loss")
        plt.plot(self.iterations, self.loss_v, 'violet',label="variational_loss")
        plt.legend(loc="upper right")
        plt.tick_params( labelsize = 20)
        fig.set_size_inches(w=11,h=5.5)
        plt.show()

        if PLOT == 'save':
            plt.savefig('VPINN_loss_history.pdf')
        else:
            plt.show()
        

    def plot_predict(self, PLOT='SHOW'):

        x, sol, n_points = self.generate_test_points()
        prediction = self.eval_NN(x)[0]
        
        pnt_skip = 25
        fig, ax = plt.subplots()
        plt.locator_params(axis='x', nbins=6)
        plt.locator_params(axis='y', nbins=8)

        plt.xlabel('$x$', fontsize = 24)
        plt.ylabel('$u$', fontsize = 24)
        plt.axhline(0, linewidth=0.8, linestyle='-', color='gray')
        for xc in self.grid_x:
            plt.axvline(x=xc, linewidth=2, ls = '--')
        plt.plot(x, sol, linewidth=1, color='r', label=''.join(['$exact$']))
        plt.plot(x, prediction, 'k*', label='$VPINN$')
        plt.tick_params( labelsize = 20)
        legend = plt.legend(shadow=True, loc='upper left', fontsize=18, ncol = 1)
        fig.set_size_inches(w=11,h=5.5)
        plt.show()

        if PLOT == 'save':
            plt.savefig('Exact.png')
        else:
            plt.show()
        
        
    def plot_pointwise_error(self, PLOT='SHOW'):

        x, sol, n_points = self.generate_test_points()

        prediction = self.eval_NN(x)[0]

        fig, ax = plt.subplots()
        plt.locator_params(axis='x', nbins=6)
        plt.locator_params(axis='y', nbins=8)
        plt.xlabel('$x$', fontsize = 24)
        plt.ylabel('point-wise error', fontsize = 24)
        plt.yscale('log')
        plt.axhline(0, linewidth=0.8, linestyle='-', color='gray')
        for xc in self.grid_x:
            plt.axvline(x=xc, linewidth=2, ls = '--')
        plt.plot(x, abs(sol - prediction), 'k')
        plt.tick_params( labelsize = 20)
        fig.set_size_inches(w=11,h=5.5)
        plt.show()

        if PLOT == 'save':
            plt.savefig('Pointwise_Error.png')
        else:
            plt.show()

# %%
class PROBDEF:

    def __init__(self, omega: tuple, r: int):
        self.omega = omega
        self.r = r

    def u_exact(self, x):
        utemp = 0.1*np.sin(self.omega*x) + np.tanh(self.r*x)
        return utemp

    def f_exact(self, x):
        A =  0.1*(self.omega**2)*np.sin(self.omega*x)
        B = (2*self.r**2)*(np.tanh(self.r*x))
        B /= (np.cosh(self.r*x)); B /= (np.cosh(self.r*x))
        return A + B

    @staticmethod
    def test_func_core(n, x):
        test = Jacobi(n+1, 0, 0, x) - Jacobi(n-1, 0, 0, x)
        return test

    def test_func(self, n_test, x):
        test_total = [self.test_func_core(n, x) for n in range(1, n_test+1)]
        return np.asarray(test_total)

    def dtest_func(self, n_test, x):
        n = 1
        d1test_total = [((n+2)/2)*Jacobi(n, 1, 1, x)]
        d2test_total = [((n+2)*(n+3)/(2*2))*Jacobi(n-1, 2, 2, x)]
        for n in range(2, n_test+1):
            if n == 2:
                d1test = ((n+2)/2)*Jacobi(n, 1, 1, x) - ((n)/2)*Jacobi(n-2, 1, 1, x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1, 2, 2, x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)
            elif n > 2:
                d1test = ((n+2)/2)*Jacobi(n, 1, 1, x) - ((n)/2)*Jacobi(n-2, 1, 1, x)
                d2test = ((n+2)*(n+3)/(2*2))*Jacobi(n-1, 2, 2, x) - ((n)*(n+1)/(2*2))*Jacobi(n-3, 2, 2, x)
                d1test_total.append(d1test)
                d2test_total.append(d2test)
            else:
                raise ValueError("Please check the value for 'n_test'")
        return np.asarray(d1test_total), np.asarray(d2test_total)
    
    
'''
Hyper-parameters: 
    scheme     = is either 'PINNs' or 'VPINNs'
    Net_layer  = the structure of fully connected network
    var_form   = the form of the variational formulation used in VPINNs
                    0, 1, 2: no, once, twice integration-by-parts
    N_el_x, N_el_y     = number of elements in x and y direction
    N_test_x, N_test_y = number of test functions in x and y direction
    N_quad     = number of quadrature points in each direction in each element
    N_bound    = number of boundary points in the boundary loss
    N_residual = number of residual points in PINNs
'''
# Out:
# "\nHyper-parameters: \n    scheme     = is either 'PINNs' or 'VPINNs'\n    Net_layer  = the structure of fully connected network\n    var_form   = the form of the variational formulation used in VPINNs\n                    0, 1, 2: no, once, twice integration-by-parts\n    N_el_x, N_el_y     = number of elements in x and y direction\n    N_test_x, N_test_y = number of test functions in x and y direction\n    N_quad     = number of quadrature points in each direction in each element\n    N_bound    = number of boundary points in the boundary loss\n    N_residual = number of residual points in PINNs\n"

# %%
pb = PROBDEF((4*np.pi), 5)
N_tests = 60
N_elements = 1
params = {'scheme': 'VPINNs',
            'NN_struct': [1] + [5] * 1 + [1],
            'var_form': 1,
            'n_elements': N_elements,
            'n_test': N_elements*[N_tests],
            'n_quad': 100,
            'n_bound': 50,
            'n_residual': 100,
            'domain': (-1, 1),
            'Opt_Niter': 15000 + 1,
            'delta_test': 0.01,
            'LR': 0.001,
            'tau': 5.0}
print(params)
# Out:
# {'scheme': 'VPINNs', 'NN_struct': [1, 5, 1], 'var_form': 1, 'n_elements': 1, 'n_test': [60], 'n_quad': 100, 'n_bound': 50, 'n_residual': 100, 'domain': (-1, 1), 'Opt_Niter': 15001, 'delta_test': 0.01, 'LR': 0.001, 'tau': 5.0}

# %%
PLOT = 'show'
#only one hidden layer

# incrasing number of elem
import random

n=[random.randint(1,100) for i in range(0,5)]
print(n)

for elem in n:

   # params['n_elements']=10
   # params['n_test']=params['n_elements']*[N_tests]
   # os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

    model = VPINN(pb,params,elem
                  ,None)
    print("SEED : ",elem)
    model.plot_predict(PLOT)

    loss_his = model.train(params['Opt_Niter'])

    model.plot_predict(PLOT)
    model.plot_loss_history(PLOT)    
    model.plot_pointwise_error(PLOT)
# Out:
# [99, 57, 26, 16, 29]
# /home/mariano/Documenti/test/base/lib/python3.9/site-packages/scipy/special/_orthogonal.py:133: RuntimeWarning: invalid value encountered in multiply
#   np.poly1d.__init__(self, poly.coeffs * float(kn))
# SEED :  99
# It: 0, Lossb: 6.407e-01, Lossv: 1.523e+01, Losstot:, 1.587e+01, Time: 1.02
# It: 100, Lossb: 2.059e-01, Lossv: 1.534e+01, Losstot:, 1.555e+01, Time: 0.05
# It: 200, Lossb: 9.418e-02, Lossv: 1.526e+01, Losstot:, 1.535e+01, Time: 0.09
# It: 300, Lossb: 6.435e-02, Lossv: 1.510e+01, Losstot:, 1.516e+01, Time: 0.04
# It: 400, Lossb: 5.951e-02, Lossv: 1.485e+01, Losstot:, 1.491e+01, Time: 0.06
# It: 500, Lossb: 6.156e-02, Lossv: 1.451e+01, Losstot:, 1.457e+01, Time: 0.05
# It: 600, Lossb: 5.937e-02, Lossv: 1.414e+01, Losstot:, 1.420e+01, Time: 0.05
# It: 700, Lossb: 4.165e-02, Lossv: 1.384e+01, Losstot:, 1.388e+01, Time: 0.04
# It: 800, Lossb: 1.154e-02, Lossv: 1.366e+01, Losstot:, 1.367e+01, Time: 0.05
# It: 900, Lossb: 2.617e-04, Lossv: 1.358e+01, Losstot:, 1.358e+01, Time: 0.06
# It: 1000, Lossb: 8.678e-04, Lossv: 1.354e+01, Losstot:, 1.354e+01, Time: 0.05
# It: 1100, Lossb: 2.183e-03, Lossv: 1.351e+01, Losstot:, 1.352e+01, Time: 0.05
# It: 1200, Lossb: 2.320e-03, Lossv: 1.348e+01, Losstot:, 1.349e+01, Time: 0.04
# It: 1300, Lossb: 3.245e-03, Lossv: 1.345e+01, Losstot:, 1.345e+01, Time: 0.05
# It: 1400, Lossb: 5.313e-03, Lossv: 1.341e+01, Losstot:, 1.341e+01, Time: 0.05
# It: 1500, Lossb: 7.901e-03, Lossv: 1.336e+01, Losstot:, 1.337e+01, Time: 0.05
# It: 1600, Lossb: 9.319e-03, Lossv: 1.331e+01, Losstot:, 1.332e+01, Time: 0.04
# It: 1700, Lossb: 8.597e-03, Lossv: 1.325e+01, Losstot:, 1.326e+01, Time: 0.04
# It: 1800, Lossb: 6.844e-03, Lossv: 1.318e+01, Losstot:, 1.318e+01, Time: 0.04
# It: 1900, Lossb: 5.278e-03, Lossv: 1.309e+01, Losstot:, 1.309e+01, Time: 0.05
# It: 2000, Lossb: 4.139e-03, Lossv: 1.297e+01, Losstot:, 1.298e+01, Time: 0.04
# It: 2100, Lossb: 3.446e-03, Lossv: 1.284e+01, Losstot:, 1.285e+01, Time: 0.04
# It: 2200, Lossb: 3.150e-03, Lossv: 1.269e+01, Losstot:, 1.269e+01, Time: 0.04
# It: 2300, Lossb: 3.043e-03, Lossv: 1.251e+01, Losstot:, 1.252e+01, Time: 0.05
# It: 2400, Lossb: 2.957e-03, Lossv: 1.232e+01, Losstot:, 1.233e+01, Time: 0.05
# It: 2500, Lossb: 2.830e-03, Lossv: 1.212e+01, Losstot:, 1.212e+01, Time: 0.05
# It: 2600, Lossb: 2.645e-03, Lossv: 1.190e+01, Losstot:, 1.190e+01, Time: 0.05
# It: 2700, Lossb: 2.392e-03, Lossv: 1.169e+01, Losstot:, 1.169e+01, Time: 0.05
# It: 2800, Lossb: 2.071e-03, Lossv: 1.148e+01, Losstot:, 1.148e+01, Time: 0.05
# It: 2900, Lossb: 1.703e-03, Lossv: 1.128e+01, Losstot:, 1.128e+01, Time: 0.05
# It: 3000, Lossb: 1.323e-03, Lossv: 1.111e+01, Losstot:, 1.111e+01, Time: 0.05
# It: 3100, Lossb: 9.690e-04, Lossv: 1.097e+01, Losstot:, 1.097e+01, Time: 0.05
# It: 3200, Lossb: 6.678e-04, Lossv: 1.085e+01, Losstot:, 1.085e+01, Time: 0.05
# It: 3300, Lossb: 4.328e-04, Lossv: 1.077e+01, Losstot:, 1.077e+01, Time: 0.05
# It: 3400, Lossb: 2.631e-04, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.05
# It: 3500, Lossb: 1.490e-04, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.05
# It: 3600, Lossb: 7.735e-05, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.05
# It: 3700, Lossb: 3.565e-05, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.04
# It: 3800, Lossb: 1.354e-05, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.05
# It: 3900, Lossb: 3.438e-06, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.06
# It: 4000, Lossb: 1.775e-07, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.05
# It: 4100, Lossb: 4.733e-07, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4200, Lossb: 2.360e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4300, Lossb: 4.747e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 4400, Lossb: 7.091e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4500, Lossb: 9.173e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4600, Lossb: 1.096e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4700, Lossb: 1.252e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4800, Lossb: 1.398e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4900, Lossb: 1.558e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 5000, Lossb: 1.771e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 5100, Lossb: 2.113e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 5200, Lossb: 2.683e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5300, Lossb: 2.776e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5400, Lossb: 8.469e-06, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.05
# It: 5500, Lossb: 2.665e-06, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.04
# It: 5600, Lossb: 1.597e-06, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 5700, Lossb: 1.059e-06, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 5800, Lossb: 7.450e-07, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.05
# It: 5900, Lossb: 5.453e-07, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.05
# It: 6000, Lossb: 4.095e-07, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.05
# It: 6100, Lossb: 3.115e-07, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.04
# It: 6200, Lossb: 2.368e-07, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.04
# It: 6300, Lossb: 1.765e-07, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.04
# It: 6400, Lossb: 1.255e-07, Lossv: 1.052e+01, Losstot:, 1.052e+01, Time: 0.05
# It: 6500, Lossb: 8.125e-08, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.04
# It: 6600, Lossb: 4.349e-08, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.04
# It: 6700, Lossb: 1.453e-08, Lossv: 1.050e+01, Losstot:, 1.050e+01, Time: 0.04
# It: 6800, Lossb: 2.662e-10, Lossv: 1.049e+01, Losstot:, 1.049e+01, Time: 0.05
# It: 6900, Lossb: 1.208e-08, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.04
# It: 7000, Lossb: 7.051e-08, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.04
# It: 7100, Lossb: 2.124e-07, Lossv: 1.047e+01, Losstot:, 1.047e+01, Time: 0.05
# It: 7200, Lossb: 5.041e-07, Lossv: 1.046e+01, Losstot:, 1.046e+01, Time: 0.04
# It: 7300, Lossb: 1.061e-06, Lossv: 1.045e+01, Losstot:, 1.045e+01, Time: 0.05
# It: 7400, Lossb: 2.024e-06, Lossv: 1.045e+01, Losstot:, 1.045e+01, Time: 0.05
# It: 7500, Lossb: 3.199e-06, Lossv: 1.044e+01, Losstot:, 1.044e+01, Time: 0.05
# It: 7600, Lossb: 3.463e-06, Lossv: 1.042e+01, Losstot:, 1.042e+01, Time: 0.05
# It: 7700, Lossb: 2.832e-06, Lossv: 1.041e+01, Losstot:, 1.041e+01, Time: 0.05
# It: 7800, Lossb: 2.423e-06, Lossv: 1.039e+01, Losstot:, 1.039e+01, Time: 0.04
# It: 7900, Lossb: 2.358e-06, Lossv: 1.037e+01, Losstot:, 1.037e+01, Time: 0.05
# It: 8000, Lossb: 2.566e-06, Lossv: 1.035e+01, Losstot:, 1.035e+01, Time: 0.05
# It: 8100, Lossb: 3.017e-06, Lossv: 1.033e+01, Losstot:, 1.033e+01, Time: 0.04
# It: 8200, Lossb: 3.687e-06, Lossv: 1.031e+01, Losstot:, 1.031e+01, Time: 0.04
# It: 8300, Lossb: 4.562e-06, Lossv: 1.028e+01, Losstot:, 1.028e+01, Time: 0.04
# It: 8400, Lossb: 5.639e-06, Lossv: 1.024e+01, Losstot:, 1.024e+01, Time: 0.05
# It: 8500, Lossb: 6.927e-06, Lossv: 1.020e+01, Losstot:, 1.020e+01, Time: 0.04
# It: 8600, Lossb: 8.445e-06, Lossv: 1.016e+01, Losstot:, 1.016e+01, Time: 0.05
# It: 8700, Lossb: 1.020e-05, Lossv: 1.010e+01, Losstot:, 1.010e+01, Time: 0.05
# It: 8800, Lossb: 1.222e-05, Lossv: 1.004e+01, Losstot:, 1.004e+01, Time: 0.09
# It: 8900, Lossb: 1.453e-05, Lossv: 9.959e+00, Losstot:, 9.959e+00, Time: 0.05
# It: 9000, Lossb: 1.715e-05, Lossv: 9.867e+00, Losstot:, 9.867e+00, Time: 0.05
# It: 9100, Lossb: 2.013e-05, Lossv: 9.758e+00, Losstot:, 9.758e+00, Time: 0.05
# It: 9200, Lossb: 2.372e-05, Lossv: 9.627e+00, Losstot:, 9.627e+00, Time: 0.04
# It: 9300, Lossb: 2.717e-05, Lossv: 9.471e+00, Losstot:, 9.471e+00, Time: 0.10
# It: 9400, Lossb: 3.195e-05, Lossv: 9.284e+00, Losstot:, 9.284e+00, Time: 0.05
# It: 9500, Lossb: 3.692e-05, Lossv: 9.061e+00, Losstot:, 9.061e+00, Time: 0.04
# It: 9600, Lossb: 4.159e-05, Lossv: 8.796e+00, Losstot:, 8.796e+00, Time: 0.04
# It: 9700, Lossb: 4.755e-05, Lossv: 8.484e+00, Losstot:, 8.484e+00, Time: 0.04
# It: 9800, Lossb: 5.230e-05, Lossv: 8.120e+00, Losstot:, 8.120e+00, Time: 0.05
# It: 9900, Lossb: 5.716e-05, Lossv: 7.702e+00, Losstot:, 7.702e+00, Time: 0.05
# It: 10000, Lossb: 6.052e-05, Lossv: 7.231e+00, Losstot:, 7.231e+00, Time: 0.05
# It: 10100, Lossb: 6.283e-05, Lossv: 6.712e+00, Losstot:, 6.712e+00, Time: 0.05
# It: 10200, Lossb: 6.155e-05, Lossv: 6.155e+00, Losstot:, 6.155e+00, Time: 0.05
# It: 10300, Lossb: 5.642e-05, Lossv: 5.576e+00, Losstot:, 5.577e+00, Time: 0.05
# It: 10400, Lossb: 4.986e-05, Lossv: 4.994e+00, Losstot:, 4.995e+00, Time: 0.07
# It: 10500, Lossb: 4.108e-05, Lossv: 4.429e+00, Losstot:, 4.429e+00, Time: 0.07
# It: 10600, Lossb: 3.140e-05, Lossv: 3.899e+00, Losstot:, 3.899e+00, Time: 0.05
# It: 10700, Lossb: 2.259e-05, Lossv: 3.418e+00, Losstot:, 3.418e+00, Time: 0.05
# It: 10800, Lossb: 1.406e-05, Lossv: 2.994e+00, Losstot:, 2.994e+00, Time: 0.05
# It: 10900, Lossb: 7.702e-06, Lossv: 2.631e+00, Losstot:, 2.631e+00, Time: 0.04
# It: 11000, Lossb: 9.438e-06, Lossv: 2.326e+00, Losstot:, 2.326e+00, Time: 0.04
# It: 11100, Lossb: 9.145e-07, Lossv: 2.076e+00, Losstot:, 2.076e+00, Time: 0.04
# It: 11200, Lossb: 6.477e-08, Lossv: 1.873e+00, Losstot:, 1.873e+00, Time: 0.05
# It: 11300, Lossb: 2.376e-07, Lossv: 1.712e+00, Losstot:, 1.712e+00, Time: 0.04
# It: 11400, Lossb: 1.375e-06, Lossv: 1.585e+00, Losstot:, 1.585e+00, Time: 0.05
# It: 11500, Lossb: 3.347e-06, Lossv: 1.486e+00, Losstot:, 1.486e+00, Time: 0.05
# It: 11600, Lossb: 3.002e-06, Lossv: 1.365e+00, Losstot:, 1.365e+00, Time: 0.06
# It: 11700, Lossb: 1.439e-06, Lossv: 1.200e+00, Losstot:, 1.200e+00, Time: 0.05
# It: 11800, Lossb: 7.959e-07, Lossv: 1.061e+00, Losstot:, 1.061e+00, Time: 0.05
# It: 11900, Lossb: 7.283e-07, Lossv: 9.312e-01, Losstot:, 9.312e-01, Time: 0.05
# It: 12000, Lossb: 7.227e-07, Lossv: 8.112e-01, Losstot:, 8.112e-01, Time: 0.05
# It: 12100, Lossb: 7.058e-07, Lossv: 7.017e-01, Losstot:, 7.017e-01, Time: 0.08
# It: 12200, Lossb: 8.855e-07, Lossv: 6.033e-01, Losstot:, 6.033e-01, Time: 0.06
# It: 12300, Lossb: 5.231e-07, Lossv: 5.160e-01, Losstot:, 5.160e-01, Time: 0.04
# It: 12400, Lossb: 6.130e-07, Lossv: 4.397e-01, Losstot:, 4.397e-01, Time: 0.05
# It: 12500, Lossb: 6.513e-07, Lossv: 3.740e-01, Losstot:, 3.740e-01, Time: 0.05
# It: 12600, Lossb: 4.645e-07, Lossv: 3.186e-01, Losstot:, 3.186e-01, Time: 0.05
# It: 12700, Lossb: 3.747e-07, Lossv: 2.725e-01, Losstot:, 2.725e-01, Time: 0.05
# It: 12800, Lossb: 3.945e-07, Lossv: 2.351e-01, Losstot:, 2.351e-01, Time: 0.05
# It: 12900, Lossb: 2.394e-07, Lossv: 2.052e-01, Losstot:, 2.052e-01, Time: 0.05
# It: 13000, Lossb: 1.349e-07, Lossv: 1.819e-01, Losstot:, 1.819e-01, Time: 0.05
# It: 13100, Lossb: 1.087e-07, Lossv: 1.642e-01, Losstot:, 1.642e-01, Time: 0.04
# It: 13200, Lossb: 3.994e-08, Lossv: 1.510e-01, Losstot:, 1.510e-01, Time: 0.05
# It: 13300, Lossb: 2.135e-07, Lossv: 1.415e-01, Losstot:, 1.415e-01, Time: 0.05
# It: 13400, Lossb: 1.196e-07, Lossv: 1.347e-01, Losstot:, 1.347e-01, Time: 0.05
# It: 13500, Lossb: 1.792e-09, Lossv: 1.301e-01, Losstot:, 1.301e-01, Time: 0.04
# It: 13600, Lossb: 5.092e-09, Lossv: 1.270e-01, Losstot:, 1.270e-01, Time: 0.05
# It: 13700, Lossb: 9.399e-08, Lossv: 1.250e-01, Losstot:, 1.250e-01, Time: 0.05
# It: 13800, Lossb: 2.813e-08, Lossv: 1.237e-01, Losstot:, 1.237e-01, Time: 0.04
# It: 13900, Lossb: 3.933e-08, Lossv: 1.230e-01, Losstot:, 1.230e-01, Time: 0.05
# It: 14000, Lossb: 6.073e-07, Lossv: 1.225e-01, Losstot:, 1.225e-01, Time: 0.05
# It: 14100, Lossb: 1.775e-07, Lossv: 1.222e-01, Losstot:, 1.222e-01, Time: 0.05
# It: 14200, Lossb: 6.870e-08, Lossv: 1.221e-01, Losstot:, 1.221e-01, Time: 0.04
# It: 14300, Lossb: 8.493e-08, Lossv: 1.220e-01, Losstot:, 1.220e-01, Time: 0.05
# It: 14400, Lossb: 9.850e-08, Lossv: 1.219e-01, Losstot:, 1.219e-01, Time: 0.05
# It: 14500, Lossb: 7.075e-07, Lossv: 1.219e-01, Losstot:, 1.219e-01, Time: 0.05
# It: 14600, Lossb: 1.078e-07, Lossv: 1.218e-01, Losstot:, 1.218e-01, Time: 0.05
# It: 14700, Lossb: 1.635e-07, Lossv: 1.218e-01, Losstot:, 1.218e-01, Time: 0.05
# It: 14800, Lossb: 1.232e-07, Lossv: 1.217e-01, Losstot:, 1.217e-01, Time: 0.05
# It: 14900, Lossb: 9.009e-09, Lossv: 1.216e-01, Losstot:, 1.216e-01, Time: 0.06
# It: 15000, Lossb: 1.125e-07, Lossv: 1.215e-01, Losstot:, 1.215e-01, Time: 0.06
# /tmp/ipykernel_13952/4199310399.py:344: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.axvline(x=xc, linewidth=2, ls = '--')
# SEED :  57
# It: 0, Lossb: 1.189e+00, Lossv: 1.505e+01, Losstot:, 1.624e+01, Time: 0.72
# It: 100, Lossb: 4.450e-01, Lossv: 1.526e+01, Losstot:, 1.571e+01, Time: 0.05
# It: 200, Lossb: 1.882e-01, Lossv: 1.532e+01, Losstot:, 1.551e+01, Time: 0.04
# It: 300, Lossb: 1.222e-01, Lossv: 1.524e+01, Losstot:, 1.536e+01, Time: 0.05
# It: 400, Lossb: 1.024e-01, Lossv: 1.505e+01, Losstot:, 1.515e+01, Time: 0.04
# It: 500, Lossb: 1.000e-01, Lossv: 1.479e+01, Losstot:, 1.489e+01, Time: 0.08
# It: 600, Lossb: 1.079e-01, Lossv: 1.448e+01, Losstot:, 1.459e+01, Time: 0.05
# It: 700, Lossb: 1.106e-01, Lossv: 1.417e+01, Losstot:, 1.428e+01, Time: 0.05
# It: 800, Lossb: 8.776e-02, Lossv: 1.392e+01, Losstot:, 1.401e+01, Time: 0.04
# It: 900, Lossb: 3.928e-02, Lossv: 1.374e+01, Losstot:, 1.378e+01, Time: 0.05
# It: 1000, Lossb: 5.632e-03, Lossv: 1.363e+01, Losstot:, 1.364e+01, Time: 0.05
# It: 1100, Lossb: 9.571e-05, Lossv: 1.358e+01, Losstot:, 1.358e+01, Time: 0.04
# It: 1200, Lossb: 1.579e-03, Lossv: 1.354e+01, Losstot:, 1.354e+01, Time: 0.05
# It: 1300, Lossb: 3.480e-03, Lossv: 1.349e+01, Losstot:, 1.350e+01, Time: 0.04
# It: 1400, Lossb: 7.298e-03, Lossv: 1.344e+01, Losstot:, 1.345e+01, Time: 0.05
# It: 1500, Lossb: 1.395e-02, Lossv: 1.339e+01, Losstot:, 1.340e+01, Time: 0.05
# It: 1600, Lossb: 2.082e-02, Lossv: 1.333e+01, Losstot:, 1.335e+01, Time: 0.05
# It: 1700, Lossb: 2.086e-02, Lossv: 1.326e+01, Losstot:, 1.328e+01, Time: 0.04
# It: 1800, Lossb: 1.490e-02, Lossv: 1.317e+01, Losstot:, 1.318e+01, Time: 0.05
# It: 1900, Lossb: 1.162e-02, Lossv: 1.305e+01, Losstot:, 1.306e+01, Time: 0.05
# It: 2000, Lossb: 1.057e-02, Lossv: 1.290e+01, Losstot:, 1.291e+01, Time: 0.06
# It: 2100, Lossb: 9.676e-03, Lossv: 1.272e+01, Losstot:, 1.273e+01, Time: 0.04
# It: 2200, Lossb: 8.690e-03, Lossv: 1.252e+01, Losstot:, 1.253e+01, Time: 0.04
# It: 2300, Lossb: 7.838e-03, Lossv: 1.230e+01, Losstot:, 1.230e+01, Time: 0.04
# It: 2400, Lossb: 7.290e-03, Lossv: 1.205e+01, Losstot:, 1.206e+01, Time: 0.05
# It: 2500, Lossb: 7.153e-03, Lossv: 1.179e+01, Losstot:, 1.179e+01, Time: 0.04
# It: 2600, Lossb: 7.611e-03, Lossv: 1.149e+01, Losstot:, 1.150e+01, Time: 0.04
# It: 2700, Lossb: 8.211e-03, Lossv: 1.116e+01, Losstot:, 1.117e+01, Time: 0.04
# It: 2800, Lossb: 5.268e-03, Lossv: 1.085e+01, Losstot:, 1.086e+01, Time: 0.04
# It: 2900, Lossb: 1.248e-03, Lossv: 1.069e+01, Losstot:, 1.069e+01, Time: 0.04
# It: 3000, Lossb: 8.554e-05, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.04
# It: 3100, Lossb: 8.975e-07, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.05
# It: 3200, Lossb: 1.496e-05, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 3300, Lossb: 2.121e-05, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 3400, Lossb: 2.309e-05, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 3500, Lossb: 2.393e-05, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 3600, Lossb: 2.462e-05, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.05
# It: 3700, Lossb: 2.535e-05, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 3800, Lossb: 2.618e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 3900, Lossb: 2.711e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4000, Lossb: 2.816e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4100, Lossb: 2.933e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4200, Lossb: 3.059e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4300, Lossb: 3.191e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4400, Lossb: 3.315e-05, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4500, Lossb: 3.409e-05, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.05
# It: 4600, Lossb: 3.430e-05, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.04
# It: 4700, Lossb: 3.323e-05, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.05
# It: 4800, Lossb: 3.037e-05, Lossv: 1.062e+01, Losstot:, 1.062e+01, Time: 0.04
# It: 4900, Lossb: 2.574e-05, Lossv: 1.062e+01, Losstot:, 1.062e+01, Time: 0.04
# It: 5000, Lossb: 2.017e-05, Lossv: 1.062e+01, Losstot:, 1.062e+01, Time: 0.05
# It: 5100, Lossb: 1.488e-05, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.04
# It: 5200, Lossb: 1.065e-05, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.04
# It: 5300, Lossb: 7.617e-06, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.04
# It: 5400, Lossb: 5.562e-06, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.04
# It: 5500, Lossb: 4.208e-06, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.05
# It: 5600, Lossb: 3.321e-06, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.04
# It: 5700, Lossb: 2.733e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5800, Lossb: 2.330e-06, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.04
# It: 5900, Lossb: 2.037e-06, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.04
# It: 6000, Lossb: 1.796e-06, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 6100, Lossb: 1.570e-06, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.04
# It: 6200, Lossb: 1.327e-06, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.05
# It: 6300, Lossb: 1.052e-06, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.05
# It: 6400, Lossb: 7.407e-07, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.04
# It: 6500, Lossb: 4.162e-07, Lossv: 1.052e+01, Losstot:, 1.052e+01, Time: 0.05
# It: 6600, Lossb: 1.345e-07, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.04
# It: 6700, Lossb: 1.897e-10, Lossv: 1.050e+01, Losstot:, 1.050e+01, Time: 0.04
# It: 6800, Lossb: 1.813e-07, Lossv: 1.049e+01, Losstot:, 1.049e+01, Time: 0.04
# It: 6900, Lossb: 9.266e-07, Lossv: 1.049e+01, Losstot:, 1.049e+01, Time: 0.04
# It: 7000, Lossb: 2.588e-06, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.05
# It: 7100, Lossb: 5.659e-06, Lossv: 1.047e+01, Losstot:, 1.047e+01, Time: 0.04
# It: 7200, Lossb: 1.083e-05, Lossv: 1.046e+01, Losstot:, 1.046e+01, Time: 0.04
# It: 7300, Lossb: 1.901e-05, Lossv: 1.044e+01, Losstot:, 1.044e+01, Time: 0.05
# It: 7400, Lossb: 3.125e-05, Lossv: 1.043e+01, Losstot:, 1.043e+01, Time: 0.04
# It: 7500, Lossb: 4.778e-05, Lossv: 1.042e+01, Losstot:, 1.042e+01, Time: 0.05
# It: 7600, Lossb: 6.408e-05, Lossv: 1.040e+01, Losstot:, 1.040e+01, Time: 0.04
# It: 7700, Lossb: 6.536e-05, Lossv: 1.038e+01, Losstot:, 1.038e+01, Time: 0.08
# It: 7800, Lossb: 4.640e-05, Lossv: 1.035e+01, Losstot:, 1.035e+01, Time: 0.04
# It: 7900, Lossb: 3.327e-05, Lossv: 1.033e+01, Losstot:, 1.033e+01, Time: 0.05
# It: 8000, Lossb: 3.376e-05, Lossv: 1.029e+01, Losstot:, 1.029e+01, Time: 0.05
# It: 8100, Lossb: 3.892e-05, Lossv: 1.026e+01, Losstot:, 1.026e+01, Time: 0.04
# It: 8200, Lossb: 4.577e-05, Lossv: 1.021e+01, Losstot:, 1.021e+01, Time: 0.05
# It: 8300, Lossb: 5.402e-05, Lossv: 1.016e+01, Losstot:, 1.016e+01, Time: 0.05
# It: 8400, Lossb: 6.359e-05, Lossv: 1.010e+01, Losstot:, 1.010e+01, Time: 0.05
# It: 8500, Lossb: 7.450e-05, Lossv: 1.002e+01, Losstot:, 1.002e+01, Time: 0.04
# It: 8600, Lossb: 8.688e-05, Lossv: 9.928e+00, Losstot:, 9.929e+00, Time: 0.04
# It: 8700, Lossb: 1.011e-04, Lossv: 9.819e+00, Losstot:, 9.819e+00, Time: 0.04
# It: 8800, Lossb: 1.175e-04, Lossv: 9.687e+00, Losstot:, 9.687e+00, Time: 0.04
# It: 8900, Lossb: 1.348e-04, Lossv: 9.527e+00, Losstot:, 9.527e+00, Time: 0.05
# It: 9000, Lossb: 1.592e-04, Lossv: 9.334e+00, Losstot:, 9.334e+00, Time: 0.05
# It: 9100, Lossb: 1.851e-04, Lossv: 9.103e+00, Losstot:, 9.103e+00, Time: 0.04
# It: 9200, Lossb: 2.137e-04, Lossv: 8.826e+00, Losstot:, 8.827e+00, Time: 0.04
# It: 9300, Lossb: 2.447e-04, Lossv: 8.499e+00, Losstot:, 8.500e+00, Time: 0.04
# It: 9400, Lossb: 2.730e-04, Lossv: 8.118e+00, Losstot:, 8.118e+00, Time: 0.05
# It: 9500, Lossb: 2.978e-04, Lossv: 7.680e+00, Losstot:, 7.681e+00, Time: 0.04
# It: 9600, Lossb: 3.117e-04, Lossv: 7.191e+00, Losstot:, 7.191e+00, Time: 0.04
# It: 9700, Lossb: 3.099e-04, Lossv: 6.660e+00, Losstot:, 6.660e+00, Time: 0.04
# It: 9800, Lossb: 2.897e-04, Lossv: 6.103e+00, Losstot:, 6.103e+00, Time: 0.04
# It: 9900, Lossb: 2.493e-04, Lossv: 5.540e+00, Losstot:, 5.541e+00, Time: 0.05
# It: 10000, Lossb: 1.970e-04, Lossv: 4.996e+00, Losstot:, 4.996e+00, Time: 0.04
# It: 10100, Lossb: 1.391e-04, Lossv: 4.488e+00, Losstot:, 4.488e+00, Time: 0.04
# It: 10200, Lossb: 8.551e-05, Lossv: 4.032e+00, Losstot:, 4.032e+00, Time: 0.04
# It: 10300, Lossb: 4.429e-05, Lossv: 3.636e+00, Losstot:, 3.636e+00, Time: 0.04
# It: 10400, Lossb: 1.699e-05, Lossv: 3.299e+00, Losstot:, 3.299e+00, Time: 0.05
# It: 10500, Lossb: 2.577e-06, Lossv: 3.018e+00, Losstot:, 3.018e+00, Time: 0.04
# It: 10600, Lossb: 4.148e-07, Lossv: 2.787e+00, Losstot:, 2.787e+00, Time: 0.04
# It: 10700, Lossb: 1.098e-05, Lossv: 2.599e+00, Losstot:, 2.599e+00, Time: 0.05
# It: 10800, Lossb: 1.875e-05, Lossv: 2.444e+00, Losstot:, 2.444e+00, Time: 0.04
# It: 10900, Lossb: 2.497e-05, Lossv: 2.287e+00, Losstot:, 2.287e+00, Time: 0.04
# It: 11000, Lossb: 1.587e-05, Lossv: 2.088e+00, Losstot:, 2.088e+00, Time: 0.05
# It: 11100, Lossb: 9.218e-06, Lossv: 1.885e+00, Losstot:, 1.885e+00, Time: 0.04
# It: 11200, Lossb: 6.025e-06, Lossv: 1.686e+00, Losstot:, 1.686e+00, Time: 0.04
# It: 11300, Lossb: 5.343e-06, Lossv: 1.493e+00, Losstot:, 1.493e+00, Time: 0.04
# It: 11400, Lossb: 5.216e-06, Lossv: 1.307e+00, Losstot:, 1.307e+00, Time: 0.05
# It: 11500, Lossb: 5.686e-06, Lossv: 1.133e+00, Losstot:, 1.133e+00, Time: 0.04
# It: 11600, Lossb: 5.355e-06, Lossv: 9.711e-01, Losstot:, 9.711e-01, Time: 0.04
# It: 11700, Lossb: 5.361e-06, Lossv: 8.245e-01, Losstot:, 8.245e-01, Time: 0.05
# It: 11800, Lossb: 5.474e-06, Lossv: 6.941e-01, Losstot:, 6.941e-01, Time: 0.04
# It: 11900, Lossb: 4.715e-06, Lossv: 5.805e-01, Losstot:, 5.805e-01, Time: 0.05
# It: 12000, Lossb: 4.313e-06, Lossv: 4.839e-01, Losstot:, 4.839e-01, Time: 0.05
# It: 12100, Lossb: 3.339e-06, Lossv: 4.037e-01, Losstot:, 4.037e-01, Time: 0.04
# It: 12200, Lossb: 2.561e-06, Lossv: 3.389e-01, Losstot:, 3.389e-01, Time: 0.04
# It: 12300, Lossb: 1.632e-06, Lossv: 2.879e-01, Losstot:, 2.879e-01, Time: 0.04
# It: 12400, Lossb: 1.129e-06, Lossv: 2.490e-01, Losstot:, 2.490e-01, Time: 0.05
# It: 12500, Lossb: 6.200e-07, Lossv: 2.201e-01, Losstot:, 2.201e-01, Time: 0.04
# It: 12600, Lossb: 3.194e-07, Lossv: 1.994e-01, Losstot:, 1.994e-01, Time: 0.05
# It: 12700, Lossb: 7.806e-08, Lossv: 1.849e-01, Losstot:, 1.849e-01, Time: 0.04
# It: 12800, Lossb: 3.508e-09, Lossv: 1.752e-01, Losstot:, 1.752e-01, Time: 0.05
# It: 12900, Lossb: 4.224e-08, Lossv: 1.688e-01, Losstot:, 1.688e-01, Time: 0.04
# It: 13000, Lossb: 8.399e-08, Lossv: 1.648e-01, Losstot:, 1.648e-01, Time: 0.04
# It: 13100, Lossb: 2.123e-07, Lossv: 1.623e-01, Losstot:, 1.623e-01, Time: 0.04
# It: 13200, Lossb: 1.562e-09, Lossv: 1.608e-01, Losstot:, 1.608e-01, Time: 0.04
# It: 13300, Lossb: 3.675e-07, Lossv: 1.598e-01, Losstot:, 1.598e-01, Time: 0.04
# It: 13400, Lossb: 4.437e-07, Lossv: 1.593e-01, Losstot:, 1.593e-01, Time: 0.05
# It: 13500, Lossb: 5.024e-07, Lossv: 1.589e-01, Losstot:, 1.589e-01, Time: 0.04
# It: 13600, Lossb: 5.356e-07, Lossv: 1.587e-01, Losstot:, 1.587e-01, Time: 0.04
# It: 13700, Lossb: 5.626e-07, Lossv: 1.584e-01, Losstot:, 1.584e-01, Time: 0.05
# It: 13800, Lossb: 5.726e-07, Lossv: 1.582e-01, Losstot:, 1.582e-01, Time: 0.04
# It: 13900, Lossb: 1.749e-06, Lossv: 1.580e-01, Losstot:, 1.580e-01, Time: 0.05
# It: 14000, Lossb: 5.835e-07, Lossv: 1.578e-01, Losstot:, 1.578e-01, Time: 0.04
# It: 14100, Lossb: 5.280e-07, Lossv: 1.576e-01, Losstot:, 1.576e-01, Time: 0.04
# It: 14200, Lossb: 4.982e-07, Lossv: 1.573e-01, Losstot:, 1.573e-01, Time: 0.04
# It: 14300, Lossb: 4.681e-07, Lossv: 1.570e-01, Losstot:, 1.570e-01, Time: 0.04
# It: 14400, Lossb: 4.174e-06, Lossv: 1.567e-01, Losstot:, 1.567e-01, Time: 0.05
# It: 14500, Lossb: 3.607e-07, Lossv: 1.562e-01, Losstot:, 1.562e-01, Time: 0.05
# It: 14600, Lossb: 2.896e-07, Lossv: 1.557e-01, Losstot:, 1.557e-01, Time: 0.04
# It: 14700, Lossb: 2.528e-07, Lossv: 1.551e-01, Losstot:, 1.551e-01, Time: 0.04
# It: 14800, Lossb: 2.054e-07, Lossv: 1.544e-01, Losstot:, 1.544e-01, Time: 0.04
# It: 14900, Lossb: 1.485e-07, Lossv: 1.535e-01, Losstot:, 1.535e-01, Time: 0.05
# It: 15000, Lossb: 1.140e-07, Lossv: 1.524e-01, Losstot:, 1.524e-01, Time: 0.05
# SEED :  26
# It: 0, Lossb: 1.498e-01, Lossv: 1.541e+01, Losstot:, 1.556e+01, Time: 0.72
# It: 100, Lossb: 3.049e-02, Lossv: 1.537e+01, Losstot:, 1.541e+01, Time: 0.05
# It: 200, Lossb: 2.735e-02, Lossv: 1.523e+01, Losstot:, 1.525e+01, Time: 0.04
# It: 300, Lossb: 3.512e-02, Lossv: 1.498e+01, Losstot:, 1.502e+01, Time: 0.04
# It: 400, Lossb: 5.167e-02, Lossv: 1.465e+01, Losstot:, 1.470e+01, Time: 0.04
# It: 500, Lossb: 7.780e-02, Lossv: 1.431e+01, Losstot:, 1.439e+01, Time: 0.05
# It: 600, Lossb: 8.939e-02, Lossv: 1.403e+01, Losstot:, 1.412e+01, Time: 0.04
# It: 700, Lossb: 6.452e-02, Lossv: 1.384e+01, Losstot:, 1.390e+01, Time: 0.04
# It: 800, Lossb: 2.002e-02, Lossv: 1.371e+01, Losstot:, 1.373e+01, Time: 0.04
# It: 900, Lossb: 9.912e-04, Lossv: 1.364e+01, Losstot:, 1.365e+01, Time: 0.04
# It: 1000, Lossb: 3.899e-04, Lossv: 1.361e+01, Losstot:, 1.361e+01, Time: 0.05
# It: 1100, Lossb: 1.531e-03, Lossv: 1.359e+01, Losstot:, 1.359e+01, Time: 0.05
# It: 1200, Lossb: 2.510e-03, Lossv: 1.356e+01, Losstot:, 1.356e+01, Time: 0.04
# It: 1300, Lossb: 3.904e-03, Lossv: 1.353e+01, Losstot:, 1.354e+01, Time: 0.04
# It: 1400, Lossb: 6.495e-03, Lossv: 1.350e+01, Losstot:, 1.351e+01, Time: 0.04
# It: 1500, Lossb: 1.121e-02, Lossv: 1.347e+01, Losstot:, 1.348e+01, Time: 0.04
# It: 1600, Lossb: 1.809e-02, Lossv: 1.344e+01, Losstot:, 1.346e+01, Time: 0.05
# It: 1700, Lossb: 2.177e-02, Lossv: 1.340e+01, Losstot:, 1.343e+01, Time: 0.04
# It: 1800, Lossb: 1.192e-02, Lossv: 1.336e+01, Losstot:, 1.337e+01, Time: 0.04
# It: 1900, Lossb: 4.663e-03, Lossv: 1.330e+01, Losstot:, 1.330e+01, Time: 0.05
# It: 2000, Lossb: 3.549e-03, Lossv: 1.322e+01, Losstot:, 1.322e+01, Time: 0.05
# It: 2100, Lossb: 3.507e-03, Lossv: 1.312e+01, Losstot:, 1.312e+01, Time: 0.04
# It: 2200, Lossb: 3.684e-03, Lossv: 1.301e+01, Losstot:, 1.301e+01, Time: 0.04
# It: 2300, Lossb: 3.925e-03, Lossv: 1.287e+01, Losstot:, 1.288e+01, Time: 0.04
# It: 2400, Lossb: 4.107e-03, Lossv: 1.272e+01, Losstot:, 1.272e+01, Time: 0.04
# It: 2500, Lossb: 4.104e-03, Lossv: 1.255e+01, Losstot:, 1.255e+01, Time: 0.04
# It: 2600, Lossb: 3.824e-03, Lossv: 1.236e+01, Losstot:, 1.236e+01, Time: 0.08
# It: 2700, Lossb: 3.336e-03, Lossv: 1.215e+01, Losstot:, 1.215e+01, Time: 0.05
# It: 2800, Lossb: 2.851e-03, Lossv: 1.193e+01, Losstot:, 1.193e+01, Time: 0.05
# It: 2900, Lossb: 2.441e-03, Lossv: 1.171e+01, Losstot:, 1.171e+01, Time: 0.05
# It: 3000, Lossb: 2.039e-03, Lossv: 1.150e+01, Losstot:, 1.150e+01, Time: 0.04
# It: 3100, Lossb: 1.599e-03, Lossv: 1.130e+01, Losstot:, 1.130e+01, Time: 0.04
# It: 3200, Lossb: 1.158e-03, Lossv: 1.112e+01, Losstot:, 1.112e+01, Time: 0.04
# It: 3300, Lossb: 7.824e-04, Lossv: 1.097e+01, Losstot:, 1.098e+01, Time: 0.05
# It: 3400, Lossb: 5.051e-04, Lossv: 1.086e+01, Losstot:, 1.086e+01, Time: 0.05
# It: 3500, Lossb: 3.134e-04, Lossv: 1.077e+01, Losstot:, 1.077e+01, Time: 0.05
# It: 3600, Lossb: 1.853e-04, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.04
# It: 3700, Lossb: 1.029e-04, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.04
# It: 3800, Lossb: 5.271e-05, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.05
# It: 3900, Lossb: 2.400e-05, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.05
# It: 4000, Lossb: 8.990e-06, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.04
# It: 4100, Lossb: 2.228e-06, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.04
# It: 4200, Lossb: 1.012e-07, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.04
# It: 4300, Lossb: 3.527e-07, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 4400, Lossb: 1.660e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4500, Lossb: 3.291e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 4600, Lossb: 4.884e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 4700, Lossb: 6.293e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 4800, Lossb: 7.484e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 4900, Lossb: 8.485e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 5000, Lossb: 9.346e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 5100, Lossb: 1.013e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5200, Lossb: 1.089e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5300, Lossb: 1.169e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5400, Lossb: 1.260e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5500, Lossb: 1.369e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5600, Lossb: 1.460e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5700, Lossb: 1.018e-05, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5800, Lossb: 1.287e-06, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.05
# It: 5900, Lossb: 5.385e-07, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.05
# It: 6000, Lossb: 3.259e-07, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 6100, Lossb: 2.635e-07, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.05
# It: 6200, Lossb: 1.607e-07, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.04
# It: 6300, Lossb: 1.223e-07, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.07
# It: 6400, Lossb: 9.220e-08, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.05
# It: 6500, Lossb: 7.074e-08, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.04
# It: 6600, Lossb: 5.286e-08, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.04
# It: 6700, Lossb: 3.778e-08, Lossv: 1.052e+01, Losstot:, 1.052e+01, Time: 0.05
# It: 6800, Lossb: 2.411e-08, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.05
# It: 6900, Lossb: 1.248e-08, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.04
# It: 7000, Lossb: 9.576e-09, Lossv: 1.050e+01, Losstot:, 1.050e+01, Time: 0.04
# It: 7100, Lossb: 2.537e-12, Lossv: 1.049e+01, Losstot:, 1.049e+01, Time: 0.04
# It: 7200, Lossb: 4.698e-09, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.04
# It: 7300, Lossb: 2.261e-08, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.04
# It: 7400, Lossb: 6.019e-08, Lossv: 1.047e+01, Losstot:, 1.047e+01, Time: 0.05
# It: 7500, Lossb: 1.218e-07, Lossv: 1.046e+01, Losstot:, 1.046e+01, Time: 0.04
# It: 7600, Lossb: 2.156e-07, Lossv: 1.046e+01, Losstot:, 1.046e+01, Time: 0.04
# It: 7700, Lossb: 3.752e-07, Lossv: 1.045e+01, Losstot:, 1.045e+01, Time: 0.04
# It: 7800, Lossb: 5.908e-07, Lossv: 1.044e+01, Losstot:, 1.044e+01, Time: 0.04
# It: 7900, Lossb: 9.551e-07, Lossv: 1.043e+01, Losstot:, 1.043e+01, Time: 0.04
# It: 8000, Lossb: 1.211e-06, Lossv: 1.041e+01, Losstot:, 1.041e+01, Time: 0.04
# It: 8100, Lossb: 1.399e-06, Lossv: 1.039e+01, Losstot:, 1.039e+01, Time: 0.05
# It: 8200, Lossb: 1.613e-06, Lossv: 1.038e+01, Losstot:, 1.038e+01, Time: 0.05
# It: 8300, Lossb: 1.852e-06, Lossv: 1.036e+01, Losstot:, 1.036e+01, Time: 0.05
# It: 8400, Lossb: 2.141e-06, Lossv: 1.033e+01, Losstot:, 1.033e+01, Time: 0.05
# It: 8500, Lossb: 2.483e-06, Lossv: 1.031e+01, Losstot:, 1.031e+01, Time: 0.05
# It: 8600, Lossb: 3.390e-06, Lossv: 1.027e+01, Losstot:, 1.027e+01, Time: 0.04
# It: 8700, Lossb: 3.468e-06, Lossv: 1.024e+01, Losstot:, 1.024e+01, Time: 0.04
# It: 8800, Lossb: 4.282e-06, Lossv: 1.020e+01, Losstot:, 1.020e+01, Time: 0.05
# It: 8900, Lossb: 4.807e-06, Lossv: 1.015e+01, Losstot:, 1.015e+01, Time: 0.05
# It: 9000, Lossb: 5.527e-06, Lossv: 1.009e+01, Losstot:, 1.009e+01, Time: 0.05
# It: 9100, Lossb: 6.535e-06, Lossv: 1.002e+01, Losstot:, 1.002e+01, Time: 0.05
# It: 9200, Lossb: 7.616e-06, Lossv: 9.943e+00, Losstot:, 9.943e+00, Time: 0.05
# It: 9300, Lossb: 8.780e-06, Lossv: 9.847e+00, Losstot:, 9.847e+00, Time: 0.05
# It: 9400, Lossb: 1.023e-05, Lossv: 9.732e+00, Losstot:, 9.732e+00, Time: 0.04
# It: 9500, Lossb: 1.174e-05, Lossv: 9.595e+00, Losstot:, 9.595e+00, Time: 0.04
# It: 9600, Lossb: 1.402e-05, Lossv: 9.431e+00, Losstot:, 9.431e+00, Time: 0.05
# It: 9700, Lossb: 1.577e-05, Lossv: 9.236e+00, Losstot:, 9.236e+00, Time: 0.04
# It: 9800, Lossb: 1.813e-05, Lossv: 9.003e+00, Losstot:, 9.003e+00, Time: 0.05
# It: 9900, Lossb: 2.164e-05, Lossv: 8.727e+00, Losstot:, 8.727e+00, Time: 0.04
# It: 10000, Lossb: 2.348e-05, Lossv: 8.402e+00, Losstot:, 8.402e+00, Time: 0.04
# It: 10100, Lossb: 2.859e-05, Lossv: 8.025e+00, Losstot:, 8.025e+00, Time: 0.05
# It: 10200, Lossb: 2.960e-05, Lossv: 7.594e+00, Losstot:, 7.594e+00, Time: 0.04
# It: 10300, Lossb: 3.669e-05, Lossv: 7.110e+00, Losstot:, 7.110e+00, Time: 0.05
# It: 10400, Lossb: 3.110e-05, Lossv: 6.581e+00, Losstot:, 6.581e+00, Time: 0.05
# It: 10500, Lossb: 3.052e-05, Lossv: 6.017e+00, Losstot:, 6.017e+00, Time: 0.04
# It: 10600, Lossb: 2.926e-05, Lossv: 5.436e+00, Losstot:, 5.436e+00, Time: 0.04
# It: 10700, Lossb: 2.467e-05, Lossv: 4.856e+00, Losstot:, 4.856e+00, Time: 0.04
# It: 10800, Lossb: 2.122e-05, Lossv: 4.298e+00, Losstot:, 4.298e+00, Time: 0.05
# It: 10900, Lossb: 1.252e-05, Lossv: 3.779e+00, Losstot:, 3.779e+00, Time: 0.05
# It: 11000, Lossb: 1.043e-05, Lossv: 3.311e+00, Losstot:, 3.311e+00, Time: 0.04
# It: 11100, Lossb: 6.851e-06, Lossv: 2.902e+00, Losstot:, 2.902e+00, Time: 0.04
# It: 11200, Lossb: 3.569e-06, Lossv: 2.553e+00, Losstot:, 2.553e+00, Time: 0.04
# It: 11300, Lossb: 1.520e-06, Lossv: 2.262e+00, Losstot:, 2.262e+00, Time: 0.05
# It: 11400, Lossb: 4.378e-07, Lossv: 2.024e+00, Losstot:, 2.024e+00, Time: 0.05
# It: 11500, Lossb: 5.080e-09, Lossv: 1.832e+00, Losstot:, 1.832e+00, Time: 0.04
# It: 11600, Lossb: 2.417e-07, Lossv: 1.680e+00, Losstot:, 1.680e+00, Time: 0.05
# It: 11700, Lossb: 1.231e-06, Lossv: 1.560e+00, Losstot:, 1.560e+00, Time: 0.04
# It: 11800, Lossb: 1.901e-06, Lossv: 1.467e+00, Losstot:, 1.467e+00, Time: 0.05
# It: 11900, Lossb: 5.612e-06, Lossv: 1.359e+00, Losstot:, 1.359e+00, Time: 0.05
# It: 12000, Lossb: 2.753e-06, Lossv: 1.185e+00, Losstot:, 1.185e+00, Time: 0.04
# It: 12100, Lossb: 9.040e-07, Lossv: 1.046e+00, Losstot:, 1.046e+00, Time: 0.05
# It: 12200, Lossb: 7.756e-07, Lossv: 9.164e-01, Losstot:, 9.164e-01, Time: 0.04
# It: 12300, Lossb: 6.912e-07, Lossv: 7.969e-01, Losstot:, 7.969e-01, Time: 0.05
# It: 12400, Lossb: 7.503e-07, Lossv: 6.882e-01, Losstot:, 6.882e-01, Time: 0.05
# It: 12500, Lossb: 5.880e-07, Lossv: 5.906e-01, Losstot:, 5.906e-01, Time: 0.05
# It: 12600, Lossb: 5.562e-07, Lossv: 5.043e-01, Losstot:, 5.043e-01, Time: 0.05
# It: 12700, Lossb: 4.751e-07, Lossv: 4.292e-01, Losstot:, 4.292e-01, Time: 0.05
# It: 12800, Lossb: 2.481e-07, Lossv: 3.648e-01, Losstot:, 3.648e-01, Time: 0.05
# It: 12900, Lossb: 3.372e-07, Lossv: 3.105e-01, Losstot:, 3.105e-01, Time: 0.05
# It: 13000, Lossb: 3.975e-07, Lossv: 2.658e-01, Losstot:, 2.658e-01, Time: 0.05
# It: 13100, Lossb: 2.044e-07, Lossv: 2.295e-01, Losstot:, 2.295e-01, Time: 0.04
# It: 13200, Lossb: 3.069e-07, Lossv: 2.008e-01, Losstot:, 2.008e-01, Time: 0.05
# It: 13300, Lossb: 8.866e-08, Lossv: 1.785e-01, Losstot:, 1.785e-01, Time: 0.05
# It: 13400, Lossb: 1.551e-08, Lossv: 1.616e-01, Losstot:, 1.616e-01, Time: 0.04
# It: 13500, Lossb: 3.352e-08, Lossv: 1.492e-01, Losstot:, 1.492e-01, Time: 0.04
# It: 13600, Lossb: 8.459e-09, Lossv: 1.403e-01, Losstot:, 1.403e-01, Time: 0.05
# It: 13700, Lossb: 3.927e-07, Lossv: 1.340e-01, Losstot:, 1.340e-01, Time: 0.04
# It: 13800, Lossb: 5.491e-10, Lossv: 1.297e-01, Losstot:, 1.297e-01, Time: 0.05
# It: 13900, Lossb: 5.981e-09, Lossv: 1.269e-01, Losstot:, 1.269e-01, Time: 0.05
# It: 14000, Lossb: 9.775e-09, Lossv: 1.251e-01, Losstot:, 1.251e-01, Time: 0.05
# It: 14100, Lossb: 1.493e-08, Lossv: 1.240e-01, Losstot:, 1.240e-01, Time: 0.04
# It: 14200, Lossb: 5.936e-08, Lossv: 1.233e-01, Losstot:, 1.233e-01, Time: 0.05
# It: 14300, Lossb: 5.573e-07, Lossv: 1.229e-01, Losstot:, 1.229e-01, Time: 0.05
# It: 14400, Lossb: 3.282e-07, Lossv: 1.226e-01, Losstot:, 1.226e-01, Time: 0.05
# It: 14500, Lossb: 5.805e-08, Lossv: 1.225e-01, Losstot:, 1.225e-01, Time: 0.04
# It: 14600, Lossb: 6.273e-08, Lossv: 1.224e-01, Losstot:, 1.224e-01, Time: 0.05
# It: 14700, Lossb: 6.927e-08, Lossv: 1.223e-01, Losstot:, 1.223e-01, Time: 0.04
# It: 14800, Lossb: 2.146e-08, Lossv: 1.223e-01, Losstot:, 1.223e-01, Time: 0.05
# It: 14900, Lossb: 7.273e-08, Lossv: 1.223e-01, Losstot:, 1.223e-01, Time: 0.06
# It: 15000, Lossb: 7.698e-08, Lossv: 1.222e-01, Losstot:, 1.222e-01, Time: 0.05
# SEED :  16
# It: 0, Lossb: 2.475e-01, Lossv: 1.529e+01, Losstot:, 1.554e+01, Time: 0.74
# It: 100, Lossb: 1.231e-01, Lossv: 1.519e+01, Losstot:, 1.531e+01, Time: 0.05
# It: 200, Lossb: 7.683e-02, Lossv: 1.503e+01, Losstot:, 1.511e+01, Time: 0.04
# It: 300, Lossb: 8.536e-02, Lossv: 1.480e+01, Losstot:, 1.489e+01, Time: 0.05
# It: 400, Lossb: 1.070e-01, Lossv: 1.454e+01, Losstot:, 1.465e+01, Time: 0.04
# It: 500, Lossb: 1.139e-01, Lossv: 1.428e+01, Losstot:, 1.440e+01, Time: 0.05
# It: 600, Lossb: 7.682e-02, Lossv: 1.403e+01, Losstot:, 1.411e+01, Time: 0.05
# It: 700, Lossb: 3.007e-02, Lossv: 1.382e+01, Losstot:, 1.385e+01, Time: 0.05
# It: 800, Lossb: 4.551e-03, Lossv: 1.372e+01, Losstot:, 1.372e+01, Time: 0.04
# It: 900, Lossb: 1.185e-04, Lossv: 1.367e+01, Losstot:, 1.367e+01, Time: 0.04
# It: 1000, Lossb: 2.738e-03, Lossv: 1.365e+01, Losstot:, 1.365e+01, Time: 0.06
# It: 1100, Lossb: 2.222e-03, Lossv: 1.363e+01, Losstot:, 1.363e+01, Time: 0.04
# It: 1200, Lossb: 2.400e-03, Lossv: 1.360e+01, Losstot:, 1.361e+01, Time: 0.04
# It: 1300, Lossb: 2.808e-03, Lossv: 1.358e+01, Losstot:, 1.358e+01, Time: 0.04
# It: 1400, Lossb: 3.208e-03, Lossv: 1.355e+01, Losstot:, 1.356e+01, Time: 0.04
# It: 1500, Lossb: 3.582e-03, Lossv: 1.352e+01, Losstot:, 1.352e+01, Time: 0.04
# It: 1600, Lossb: 4.319e-03, Lossv: 1.347e+01, Losstot:, 1.347e+01, Time: 0.05
# It: 1700, Lossb: 6.783e-03, Lossv: 1.340e+01, Losstot:, 1.340e+01, Time: 0.04
# It: 1800, Lossb: 1.187e-02, Lossv: 1.329e+01, Losstot:, 1.330e+01, Time: 0.04
# It: 1900, Lossb: 1.506e-02, Lossv: 1.314e+01, Losstot:, 1.316e+01, Time: 0.04
# It: 2000, Lossb: 1.513e-02, Lossv: 1.295e+01, Losstot:, 1.297e+01, Time: 0.05
# It: 2100, Lossb: 1.429e-02, Lossv: 1.269e+01, Losstot:, 1.271e+01, Time: 0.05
# It: 2200, Lossb: 1.520e-02, Lossv: 1.228e+01, Losstot:, 1.230e+01, Time: 0.04
# It: 2300, Lossb: 1.429e-02, Lossv: 1.170e+01, Losstot:, 1.172e+01, Time: 0.05
# It: 2400, Lossb: 8.911e-03, Lossv: 1.114e+01, Losstot:, 1.115e+01, Time: 0.04
# It: 2500, Lossb: 3.102e-03, Lossv: 1.082e+01, Losstot:, 1.082e+01, Time: 0.05
# It: 2600, Lossb: 4.757e-04, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.05
# It: 2700, Lossb: 1.416e-05, Lossv: 1.069e+01, Losstot:, 1.069e+01, Time: 0.05
# It: 2800, Lossb: 8.452e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 2900, Lossb: 2.290e-05, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 3000, Lossb: 2.522e-05, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.05
# It: 3100, Lossb: 2.158e-05, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 3200, Lossb: 1.614e-05, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 3300, Lossb: 1.139e-05, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.05
# It: 3400, Lossb: 8.153e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.05
# It: 3500, Lossb: 6.155e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.05
# It: 3600, Lossb: 4.925e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 3700, Lossb: 4.137e-06, Lossv: 1.067e+01, Losstot:, 1.067e+01, Time: 0.05
# It: 3800, Lossb: 3.597e-06, Lossv: 1.067e+01, Losstot:, 1.067e+01, Time: 0.05
# It: 3900, Lossb: 3.197e-06, Lossv: 1.067e+01, Losstot:, 1.067e+01, Time: 0.04
# It: 4000, Lossb: 2.875e-06, Lossv: 1.067e+01, Losstot:, 1.067e+01, Time: 0.05
# It: 4100, Lossb: 2.598e-06, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.04
# It: 4200, Lossb: 2.353e-06, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.04
# It: 4300, Lossb: 2.135e-06, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.04
# It: 4400, Lossb: 1.942e-06, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 4500, Lossb: 1.775e-06, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.04
# It: 4600, Lossb: 1.634e-06, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.05
# It: 4700, Lossb: 1.522e-06, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 4800, Lossb: 1.445e-06, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.04
# It: 4900, Lossb: 1.416e-06, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.05
# It: 5000, Lossb: 1.452e-06, Lossv: 1.062e+01, Losstot:, 1.062e+01, Time: 0.09
# It: 5100, Lossb: 1.577e-06, Lossv: 1.062e+01, Losstot:, 1.062e+01, Time: 0.04
# It: 5200, Lossb: 1.818e-06, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.04
# It: 5300, Lossb: 2.168e-06, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.05
# It: 5400, Lossb: 2.528e-06, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.04
# It: 5500, Lossb: 2.668e-06, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.05
# It: 5600, Lossb: 2.372e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.05
# It: 5700, Lossb: 1.647e-06, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 5800, Lossb: 7.595e-07, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.04
# It: 5900, Lossb: 1.031e-07, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 6000, Lossb: 1.226e-07, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.05
# It: 6100, Lossb: 1.220e-06, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.05
# It: 6200, Lossb: 3.566e-06, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.04
# It: 6300, Lossb: 6.423e-06, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.05
# It: 6400, Lossb: 8.612e-06, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.05
# It: 6500, Lossb: 9.681e-06, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.05
# It: 6600, Lossb: 9.978e-06, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.05
# It: 6700, Lossb: 9.301e-06, Lossv: 1.052e+01, Losstot:, 1.052e+01, Time: 0.05
# It: 6800, Lossb: 8.066e-06, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.04
# It: 6900, Lossb: 6.950e-06, Lossv: 1.050e+01, Losstot:, 1.050e+01, Time: 0.04
# It: 7000, Lossb: 6.904e-06, Lossv: 1.049e+01, Losstot:, 1.049e+01, Time: 0.05
# It: 7100, Lossb: 7.369e-06, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.04
# It: 7200, Lossb: 8.881e-06, Lossv: 1.047e+01, Losstot:, 1.047e+01, Time: 0.04
# It: 7300, Lossb: 1.171e-05, Lossv: 1.046e+01, Losstot:, 1.046e+01, Time: 0.04
# It: 7400, Lossb: 1.622e-05, Lossv: 1.044e+01, Losstot:, 1.044e+01, Time: 0.05
# It: 7500, Lossb: 2.162e-05, Lossv: 1.041e+01, Losstot:, 1.041e+01, Time: 0.05
# It: 7600, Lossb: 2.930e-05, Lossv: 1.039e+01, Losstot:, 1.039e+01, Time: 0.05
# It: 7700, Lossb: 3.834e-05, Lossv: 1.035e+01, Losstot:, 1.035e+01, Time: 0.04
# It: 7800, Lossb: 5.097e-05, Lossv: 1.031e+01, Losstot:, 1.031e+01, Time: 0.05
# It: 7900, Lossb: 6.942e-05, Lossv: 1.025e+01, Losstot:, 1.025e+01, Time: 0.04
# It: 8000, Lossb: 9.803e-05, Lossv: 1.016e+01, Losstot:, 1.016e+01, Time: 0.05
# It: 8100, Lossb: 1.433e-04, Lossv: 1.004e+01, Losstot:, 1.004e+01, Time: 0.04
# It: 8200, Lossb: 2.119e-04, Lossv: 9.863e+00, Losstot:, 9.864e+00, Time: 0.04
# It: 8300, Lossb: 3.146e-04, Lossv: 9.608e+00, Losstot:, 9.609e+00, Time: 0.04
# It: 8400, Lossb: 4.585e-04, Lossv: 9.242e+00, Losstot:, 9.243e+00, Time: 0.04
# It: 8500, Lossb: 6.348e-04, Lossv: 8.736e+00, Losstot:, 8.736e+00, Time: 0.05
# It: 8600, Lossb: 8.073e-04, Lossv: 8.073e+00, Losstot:, 8.074e+00, Time: 0.05
# It: 8700, Lossb: 9.056e-04, Lossv: 7.275e+00, Losstot:, 7.276e+00, Time: 0.04
# It: 8800, Lossb: 8.405e-04, Lossv: 6.410e+00, Losstot:, 6.411e+00, Time: 0.04
# It: 8900, Lossb: 6.167e-04, Lossv: 5.590e+00, Losstot:, 5.590e+00, Time: 0.05
# It: 9000, Lossb: 3.323e-04, Lossv: 4.914e+00, Losstot:, 4.914e+00, Time: 0.05
# It: 9100, Lossb: 1.138e-04, Lossv: 4.427e+00, Losstot:, 4.427e+00, Time: 0.05
# It: 9200, Lossb: 1.327e-05, Lossv: 4.112e+00, Losstot:, 4.112e+00, Time: 0.05
# It: 9300, Lossb: 3.735e-06, Lossv: 3.922e+00, Losstot:, 3.922e+00, Time: 0.05
# It: 9400, Lossb: 3.177e-05, Lossv: 3.795e+00, Losstot:, 3.795e+00, Time: 0.05
# It: 9500, Lossb: 7.663e-06, Lossv: 3.614e+00, Losstot:, 3.614e+00, Time: 0.05
# It: 9600, Lossb: 9.512e-06, Lossv: 3.428e+00, Losstot:, 3.428e+00, Time: 0.05
# It: 9700, Lossb: 1.056e-05, Lossv: 3.235e+00, Losstot:, 3.235e+00, Time: 0.04
# It: 9800, Lossb: 1.448e-05, Lossv: 3.037e+00, Losstot:, 3.037e+00, Time: 0.04
# It: 9900, Lossb: 1.818e-05, Lossv: 2.835e+00, Losstot:, 2.835e+00, Time: 0.04
# It: 10000, Lossb: 2.493e-05, Lossv: 2.629e+00, Losstot:, 2.629e+00, Time: 0.05
# It: 10100, Lossb: 3.189e-05, Lossv: 2.422e+00, Losstot:, 2.422e+00, Time: 0.04
# It: 10200, Lossb: 3.950e-05, Lossv: 2.214e+00, Losstot:, 2.215e+00, Time: 0.04
# It: 10300, Lossb: 4.735e-05, Lossv: 2.008e+00, Losstot:, 2.008e+00, Time: 0.04
# It: 10400, Lossb: 5.479e-05, Lossv: 1.804e+00, Losstot:, 1.804e+00, Time: 0.04
# It: 10500, Lossb: 6.157e-05, Lossv: 1.605e+00, Losstot:, 1.605e+00, Time: 0.05
# It: 10600, Lossb: 6.677e-05, Lossv: 1.414e+00, Losstot:, 1.414e+00, Time: 0.04
# It: 10700, Lossb: 6.984e-05, Lossv: 1.233e+00, Losstot:, 1.233e+00, Time: 0.04
# It: 10800, Lossb: 7.008e-05, Lossv: 1.065e+00, Losstot:, 1.065e+00, Time: 0.04
# It: 10900, Lossb: 6.696e-05, Lossv: 9.110e-01, Losstot:, 9.111e-01, Time: 0.04
# It: 11000, Lossb: 6.131e-05, Lossv: 7.747e-01, Losstot:, 7.748e-01, Time: 0.05
# It: 11100, Lossb: 5.280e-05, Lossv: 6.568e-01, Losstot:, 6.568e-01, Time: 0.04
# It: 11200, Lossb: 4.258e-05, Lossv: 5.581e-01, Losstot:, 5.581e-01, Time: 0.04
# It: 11300, Lossb: 3.218e-05, Lossv: 4.780e-01, Losstot:, 4.780e-01, Time: 0.05
# It: 11400, Lossb: 2.233e-05, Lossv: 4.153e-01, Losstot:, 4.153e-01, Time: 0.04
# It: 11500, Lossb: 1.387e-05, Lossv: 3.681e-01, Losstot:, 3.682e-01, Time: 0.05
# It: 11600, Lossb: 7.729e-06, Lossv: 3.340e-01, Losstot:, 3.340e-01, Time: 0.05
# It: 11700, Lossb: 3.501e-06, Lossv: 3.102e-01, Losstot:, 3.102e-01, Time: 0.04
# It: 11800, Lossb: 9.379e-07, Lossv: 2.943e-01, Losstot:, 2.943e-01, Time: 0.04
# It: 11900, Lossb: 1.139e-07, Lossv: 2.841e-01, Losstot:, 2.841e-01, Time: 0.04
# It: 12000, Lossb: 7.369e-08, Lossv: 2.777e-01, Losstot:, 2.777e-01, Time: 0.05
# It: 12100, Lossb: 4.004e-07, Lossv: 2.739e-01, Losstot:, 2.739e-01, Time: 0.04
# It: 12200, Lossb: 1.381e-06, Lossv: 2.717e-01, Losstot:, 2.717e-01, Time: 0.04
# It: 12300, Lossb: 2.254e-06, Lossv: 2.705e-01, Losstot:, 2.705e-01, Time: 0.04
# It: 12400, Lossb: 2.459e-06, Lossv: 2.698e-01, Losstot:, 2.698e-01, Time: 0.05
# It: 12500, Lossb: 3.830e-06, Lossv: 2.693e-01, Losstot:, 2.693e-01, Time: 0.05
# It: 12600, Lossb: 4.522e-06, Lossv: 2.690e-01, Losstot:, 2.690e-01, Time: 0.05
# It: 12700, Lossb: 1.018e-05, Lossv: 2.689e-01, Losstot:, 2.690e-01, Time: 0.05
# It: 12800, Lossb: 5.720e-06, Lossv: 2.686e-01, Losstot:, 2.686e-01, Time: 0.04
# It: 12900, Lossb: 6.336e-06, Lossv: 2.684e-01, Losstot:, 2.684e-01, Time: 0.04
# It: 13000, Lossb: 7.134e-06, Lossv: 2.682e-01, Losstot:, 2.682e-01, Time: 0.04
# It: 13100, Lossb: 8.140e-06, Lossv: 2.680e-01, Losstot:, 2.680e-01, Time: 0.05
# It: 13200, Lossb: 9.588e-06, Lossv: 2.676e-01, Losstot:, 2.676e-01, Time: 0.05
# It: 13300, Lossb: 1.206e-05, Lossv: 2.670e-01, Losstot:, 2.670e-01, Time: 0.04
# It: 13400, Lossb: 1.443e-05, Lossv: 2.658e-01, Losstot:, 2.659e-01, Time: 0.05
# It: 13500, Lossb: 1.739e-05, Lossv: 2.637e-01, Losstot:, 2.637e-01, Time: 0.05
# It: 13600, Lossb: 1.393e-05, Lossv: 2.600e-01, Losstot:, 2.600e-01, Time: 0.04
# It: 13700, Lossb: 1.560e-05, Lossv: 2.558e-01, Losstot:, 2.558e-01, Time: 0.04
# It: 13800, Lossb: 9.433e-06, Lossv: 2.525e-01, Losstot:, 2.525e-01, Time: 0.05
# It: 13900, Lossb: 1.278e-05, Lossv: 2.494e-01, Losstot:, 2.494e-01, Time: 0.04
# It: 14000, Lossb: 1.892e-05, Lossv: 2.466e-01, Losstot:, 2.466e-01, Time: 0.05
# It: 14100, Lossb: 2.707e-05, Lossv: 2.444e-01, Losstot:, 2.444e-01, Time: 0.04
# It: 14200, Lossb: 4.324e-05, Lossv: 2.431e-01, Losstot:, 2.432e-01, Time: 0.04
# It: 14300, Lossb: 5.615e-05, Lossv: 2.413e-01, Losstot:, 2.414e-01, Time: 0.04
# It: 14400, Lossb: 9.517e-05, Lossv: 2.406e-01, Losstot:, 2.407e-01, Time: 0.04
# It: 14500, Lossb: 9.536e-05, Lossv: 2.396e-01, Losstot:, 2.397e-01, Time: 0.05
# It: 14600, Lossb: 1.149e-04, Lossv: 2.392e-01, Losstot:, 2.393e-01, Time: 0.04
# It: 14700, Lossb: 1.350e-04, Lossv: 2.388e-01, Losstot:, 2.390e-01, Time: 0.04
# It: 14800, Lossb: 1.539e-04, Lossv: 2.386e-01, Losstot:, 2.387e-01, Time: 0.05
# It: 14900, Lossb: 1.701e-04, Lossv: 2.385e-01, Losstot:, 2.386e-01, Time: 0.04
# It: 15000, Lossb: 1.817e-04, Lossv: 2.384e-01, Losstot:, 2.385e-01, Time: 0.04
# SEED :  29
# It: 0, Lossb: 6.089e-02, Lossv: 1.553e+01, Losstot:, 1.559e+01, Time: 0.75
# It: 100, Lossb: 4.409e-04, Lossv: 1.542e+01, Losstot:, 1.542e+01, Time: 0.05
# It: 200, Lossb: 8.461e-03, Lossv: 1.531e+01, Losstot:, 1.531e+01, Time: 0.05
# It: 300, Lossb: 1.451e-02, Lossv: 1.514e+01, Losstot:, 1.515e+01, Time: 0.05
# It: 400, Lossb: 2.157e-02, Lossv: 1.489e+01, Losstot:, 1.491e+01, Time: 0.05
# It: 500, Lossb: 2.401e-02, Lossv: 1.458e+01, Losstot:, 1.460e+01, Time: 0.06
# It: 600, Lossb: 7.849e-03, Lossv: 1.423e+01, Losstot:, 1.424e+01, Time: 0.04
# It: 700, Lossb: 1.967e-03, Lossv: 1.394e+01, Losstot:, 1.394e+01, Time: 0.04
# It: 800, Lossb: 1.545e-04, Lossv: 1.378e+01, Losstot:, 1.378e+01, Time: 0.05
# It: 900, Lossb: 1.119e-04, Lossv: 1.372e+01, Losstot:, 1.372e+01, Time: 0.05
# It: 1000, Lossb: 5.326e-04, Lossv: 1.369e+01, Losstot:, 1.369e+01, Time: 0.05
# It: 1100, Lossb: 5.828e-04, Lossv: 1.368e+01, Losstot:, 1.368e+01, Time: 0.05
# It: 1200, Lossb: 1.037e-03, Lossv: 1.366e+01, Losstot:, 1.366e+01, Time: 0.04
# It: 1300, Lossb: 1.391e-03, Lossv: 1.363e+01, Losstot:, 1.363e+01, Time: 0.04
# It: 1400, Lossb: 2.509e-03, Lossv: 1.359e+01, Losstot:, 1.360e+01, Time: 0.04
# It: 1500, Lossb: 3.798e-03, Lossv: 1.355e+01, Losstot:, 1.355e+01, Time: 0.04
# It: 1600, Lossb: 4.114e-03, Lossv: 1.348e+01, Losstot:, 1.349e+01, Time: 0.05
# It: 1700, Lossb: 4.079e-03, Lossv: 1.339e+01, Losstot:, 1.340e+01, Time: 0.05
# It: 1800, Lossb: 4.466e-03, Lossv: 1.327e+01, Losstot:, 1.327e+01, Time: 0.05
# It: 1900, Lossb: 5.144e-03, Lossv: 1.308e+01, Losstot:, 1.309e+01, Time: 0.05
# It: 2000, Lossb: 6.084e-03, Lossv: 1.283e+01, Losstot:, 1.284e+01, Time: 0.05
# It: 2100, Lossb: 7.050e-03, Lossv: 1.249e+01, Losstot:, 1.249e+01, Time: 0.04
# It: 2200, Lossb: 7.446e-03, Lossv: 1.205e+01, Losstot:, 1.206e+01, Time: 0.05
# It: 2300, Lossb: 6.553e-03, Lossv: 1.157e+01, Losstot:, 1.158e+01, Time: 0.05
# It: 2400, Lossb: 4.293e-03, Lossv: 1.115e+01, Losstot:, 1.115e+01, Time: 0.04
# It: 2500, Lossb: 1.828e-03, Lossv: 1.087e+01, Losstot:, 1.087e+01, Time: 0.05
# It: 2600, Lossb: 4.299e-04, Lossv: 1.075e+01, Losstot:, 1.075e+01, Time: 0.04
# It: 2700, Lossb: 3.680e-05, Lossv: 1.072e+01, Losstot:, 1.072e+01, Time: 0.04
# It: 2800, Lossb: 1.280e-06, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.04
# It: 2900, Lossb: 1.580e-05, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.05
# It: 3000, Lossb: 2.444e-05, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.05
# It: 3100, Lossb: 2.688e-05, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.04
# It: 3200, Lossb: 2.696e-05, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.04
# It: 3300, Lossb: 2.605e-05, Lossv: 1.071e+01, Losstot:, 1.071e+01, Time: 0.05
# It: 3400, Lossb: 2.420e-05, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.04
# It: 3500, Lossb: 2.114e-05, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.04
# It: 3600, Lossb: 1.597e-05, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.05
# It: 3700, Lossb: 1.007e-05, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.04
# It: 3800, Lossb: 6.198e-06, Lossv: 1.070e+01, Losstot:, 1.070e+01, Time: 0.08
# It: 3900, Lossb: 4.343e-06, Lossv: 1.069e+01, Losstot:, 1.069e+01, Time: 0.05
# It: 4000, Lossb: 3.515e-06, Lossv: 1.069e+01, Losstot:, 1.069e+01, Time: 0.05
# It: 4100, Lossb: 3.188e-06, Lossv: 1.069e+01, Losstot:, 1.069e+01, Time: 0.05
# It: 4200, Lossb: 3.127e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.05
# It: 4300, Lossb: 3.191e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 4400, Lossb: 3.197e-06, Lossv: 1.068e+01, Losstot:, 1.068e+01, Time: 0.04
# It: 4500, Lossb: 3.017e-06, Lossv: 1.067e+01, Losstot:, 1.067e+01, Time: 0.04
# It: 4600, Lossb: 2.658e-06, Lossv: 1.067e+01, Losstot:, 1.067e+01, Time: 0.04
# It: 4700, Lossb: 2.232e-06, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.04
# It: 4800, Lossb: 1.840e-06, Lossv: 1.066e+01, Losstot:, 1.066e+01, Time: 0.05
# It: 4900, Lossb: 1.606e-06, Lossv: 1.065e+01, Losstot:, 1.065e+01, Time: 0.05
# It: 5000, Lossb: 1.407e-06, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 5100, Lossb: 1.243e-06, Lossv: 1.064e+01, Losstot:, 1.064e+01, Time: 0.04
# It: 5200, Lossb: 1.126e-06, Lossv: 1.063e+01, Losstot:, 1.063e+01, Time: 0.04
# It: 5300, Lossb: 9.088e-07, Lossv: 1.062e+01, Losstot:, 1.062e+01, Time: 0.04
# It: 5400, Lossb: 8.296e-07, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.04
# It: 5500, Lossb: 6.803e-07, Lossv: 1.061e+01, Losstot:, 1.061e+01, Time: 0.05
# It: 5600, Lossb: 4.464e-07, Lossv: 1.060e+01, Losstot:, 1.060e+01, Time: 0.04
# It: 5700, Lossb: 2.674e-07, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.04
# It: 5800, Lossb: 1.058e-07, Lossv: 1.059e+01, Losstot:, 1.059e+01, Time: 0.04
# It: 5900, Lossb: 3.921e-09, Lossv: 1.058e+01, Losstot:, 1.058e+01, Time: 0.04
# It: 6000, Lossb: 2.196e-07, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.04
# It: 6100, Lossb: 2.608e-07, Lossv: 1.057e+01, Losstot:, 1.057e+01, Time: 0.04
# It: 6200, Lossb: 6.323e-07, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 6300, Lossb: 9.625e-07, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.04
# It: 6400, Lossb: 1.161e-06, Lossv: 1.056e+01, Losstot:, 1.056e+01, Time: 0.05
# It: 6500, Lossb: 1.083e-06, Lossv: 1.055e+01, Losstot:, 1.055e+01, Time: 0.04
# It: 6600, Lossb: 7.686e-07, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.04
# It: 6700, Lossb: 5.881e-07, Lossv: 1.054e+01, Losstot:, 1.054e+01, Time: 0.04
# It: 6800, Lossb: 4.546e-07, Lossv: 1.053e+01, Losstot:, 1.053e+01, Time: 0.04
# It: 6900, Lossb: 4.384e-07, Lossv: 1.052e+01, Losstot:, 1.052e+01, Time: 0.04
# It: 7000, Lossb: 5.622e-07, Lossv: 1.051e+01, Losstot:, 1.051e+01, Time: 0.04
# It: 7100, Lossb: 8.799e-07, Lossv: 1.050e+01, Losstot:, 1.050e+01, Time: 0.04
# It: 7200, Lossb: 1.604e-06, Lossv: 1.048e+01, Losstot:, 1.048e+01, Time: 0.05
# It: 7300, Lossb: 2.647e-06, Lossv: 1.047e+01, Losstot:, 1.047e+01, Time: 0.04
# It: 7400, Lossb: 4.296e-06, Lossv: 1.045e+01, Losstot:, 1.045e+01, Time: 0.05
# It: 7500, Lossb: 6.517e-06, Lossv: 1.043e+01, Losstot:, 1.043e+01, Time: 0.04
# It: 7600, Lossb: 9.518e-06, Lossv: 1.041e+01, Losstot:, 1.041e+01, Time: 0.04
# It: 7700, Lossb: 1.403e-05, Lossv: 1.038e+01, Losstot:, 1.038e+01, Time: 0.04
# It: 7800, Lossb: 1.874e-05, Lossv: 1.034e+01, Losstot:, 1.034e+01, Time: 0.04
# It: 7900, Lossb: 2.774e-05, Lossv: 1.030e+01, Losstot:, 1.030e+01, Time: 0.04
# It: 8000, Lossb: 3.951e-05, Lossv: 1.024e+01, Losstot:, 1.024e+01, Time: 0.04
# It: 8100, Lossb: 5.636e-05, Lossv: 1.016e+01, Losstot:, 1.016e+01, Time: 0.04
# It: 8200, Lossb: 8.100e-05, Lossv: 1.005e+01, Losstot:, 1.005e+01, Time: 0.05
# It: 8300, Lossb: 1.194e-04, Lossv: 9.895e+00, Losstot:, 9.895e+00, Time: 0.04
# It: 8400, Lossb: 1.844e-04, Lossv: 9.673e+00, Losstot:, 9.673e+00, Time: 0.04
# It: 8500, Lossb: 2.516e-04, Lossv: 9.362e+00, Losstot:, 9.362e+00, Time: 0.04
# It: 8600, Lossb: 3.534e-04, Lossv: 8.932e+00, Losstot:, 8.932e+00, Time: 0.04
# It: 8700, Lossb: 4.651e-04, Lossv: 8.363e+00, Losstot:, 8.364e+00, Time: 0.05
# It: 8800, Lossb: 5.463e-04, Lossv: 7.658e+00, Losstot:, 7.659e+00, Time: 0.04
# It: 8900, Lossb: 5.885e-04, Lossv: 6.857e+00, Losstot:, 6.858e+00, Time: 0.05
# It: 9000, Lossb: 4.765e-04, Lossv: 6.042e+00, Losstot:, 6.042e+00, Time: 0.04
# It: 9100, Lossb: 3.105e-04, Lossv: 5.306e+00, Losstot:, 5.306e+00, Time: 0.04
# It: 9200, Lossb: 1.429e-04, Lossv: 4.726e+00, Losstot:, 4.726e+00, Time: 0.04
# It: 9300, Lossb: 3.770e-05, Lossv: 4.318e+00, Losstot:, 4.319e+00, Time: 0.04
# It: 9400, Lossb: 6.268e-07, Lossv: 4.057e+00, Losstot:, 4.057e+00, Time: 0.04
# It: 9500, Lossb: 1.222e-05, Lossv: 3.898e+00, Losstot:, 3.898e+00, Time: 0.04
# It: 9600, Lossb: 2.700e-06, Lossv: 3.743e+00, Losstot:, 3.743e+00, Time: 0.04
# It: 9700, Lossb: 1.459e-06, Lossv: 3.554e+00, Losstot:, 3.554e+00, Time: 0.04
# It: 9800, Lossb: 2.277e-06, Lossv: 3.359e+00, Losstot:, 3.359e+00, Time: 0.04
# It: 9900, Lossb: 3.333e-06, Lossv: 3.158e+00, Losstot:, 3.158e+00, Time: 0.05
# It: 10000, Lossb: 5.341e-06, Lossv: 2.954e+00, Losstot:, 2.954e+00, Time: 0.04
# It: 10100, Lossb: 8.352e-06, Lossv: 2.747e+00, Losstot:, 2.747e+00, Time: 0.04
# It: 10200, Lossb: 1.253e-05, Lossv: 2.539e+00, Losstot:, 2.539e+00, Time: 0.04
# It: 10300, Lossb: 1.737e-05, Lossv: 2.332e+00, Losstot:, 2.332e+00, Time: 0.04
# It: 10400, Lossb: 2.348e-05, Lossv: 2.126e+00, Losstot:, 2.126e+00, Time: 0.05
# It: 10500, Lossb: 3.104e-05, Lossv: 1.921e+00, Losstot:, 1.921e+00, Time: 0.04
# It: 10600, Lossb: 3.554e-05, Lossv: 1.725e+00, Losstot:, 1.725e+00, Time: 0.04
# It: 10700, Lossb: 4.063e-05, Lossv: 1.534e+00, Losstot:, 1.534e+00, Time: 0.04
# It: 10800, Lossb: 4.433e-05, Lossv: 1.351e+00, Losstot:, 1.351e+00, Time: 0.05
# It: 10900, Lossb: 5.913e-05, Lossv: 1.179e+00, Losstot:, 1.179e+00, Time: 0.05
# It: 11000, Lossb: 4.678e-05, Lossv: 1.022e+00, Losstot:, 1.022e+00, Time: 0.04
# It: 11100, Lossb: 4.456e-05, Lossv: 8.796e-01, Losstot:, 8.796e-01, Time: 0.04
# It: 11200, Lossb: 4.043e-05, Lossv: 7.524e-01, Losstot:, 7.524e-01, Time: 0.04
# It: 11300, Lossb: 3.407e-05, Lossv: 6.437e-01, Losstot:, 6.437e-01, Time: 0.05
# It: 11400, Lossb: 2.886e-05, Lossv: 5.530e-01, Losstot:, 5.531e-01, Time: 0.05
# It: 11500, Lossb: 2.177e-05, Lossv: 4.784e-01, Losstot:, 4.784e-01, Time: 0.05
# It: 11600, Lossb: 1.982e-05, Lossv: 4.195e-01, Losstot:, 4.196e-01, Time: 0.04
# It: 11700, Lossb: 1.144e-05, Lossv: 3.756e-01, Losstot:, 3.757e-01, Time: 0.04
# It: 11800, Lossb: 5.997e-06, Lossv: 3.423e-01, Losstot:, 3.423e-01, Time: 0.04
# It: 11900, Lossb: 3.671e-06, Lossv: 3.182e-01, Losstot:, 3.182e-01, Time: 0.04
# It: 12000, Lossb: 3.166e-06, Lossv: 3.025e-01, Losstot:, 3.025e-01, Time: 0.04
# It: 12100, Lossb: 2.903e-07, Lossv: 2.910e-01, Losstot:, 2.910e-01, Time: 0.05
# It: 12200, Lossb: 1.060e-09, Lossv: 2.836e-01, Losstot:, 2.836e-01, Time: 0.05
# It: 12300, Lossb: 4.936e-08, Lossv: 2.789e-01, Losstot:, 2.789e-01, Time: 0.04
# It: 12400, Lossb: 5.341e-07, Lossv: 2.761e-01, Losstot:, 2.761e-01, Time: 0.05
# It: 12500, Lossb: 1.050e-06, Lossv: 2.743e-01, Losstot:, 2.743e-01, Time: 0.05
# It: 12600, Lossb: 1.609e-06, Lossv: 2.731e-01, Losstot:, 2.731e-01, Time: 0.04
# It: 12700, Lossb: 3.240e-06, Lossv: 2.726e-01, Losstot:, 2.726e-01, Time: 0.04
# It: 12800, Lossb: 2.606e-06, Lossv: 2.720e-01, Losstot:, 2.720e-01, Time: 0.05
# It: 12900, Lossb: 3.059e-06, Lossv: 2.717e-01, Losstot:, 2.717e-01, Time: 0.05
# It: 13000, Lossb: 3.481e-06, Lossv: 2.715e-01, Losstot:, 2.715e-01, Time: 0.04
# It: 13100, Lossb: 4.653e-06, Lossv: 2.715e-01, Losstot:, 2.715e-01, Time: 0.04
# It: 13200, Lossb: 4.251e-06, Lossv: 2.711e-01, Losstot:, 2.711e-01, Time: 0.04
# It: 13300, Lossb: 4.681e-06, Lossv: 2.709e-01, Losstot:, 2.709e-01, Time: 0.05
# It: 13400, Lossb: 5.204e-06, Lossv: 2.707e-01, Losstot:, 2.707e-01, Time: 0.05
# It: 13500, Lossb: 1.081e-05, Lossv: 2.724e-01, Losstot:, 2.724e-01, Time: 0.05
# It: 13600, Lossb: 6.833e-06, Lossv: 2.702e-01, Losstot:, 2.702e-01, Time: 0.05
# It: 13700, Lossb: 8.379e-06, Lossv: 2.698e-01, Losstot:, 2.698e-01, Time: 0.04
# It: 13800, Lossb: 1.097e-05, Lossv: 2.690e-01, Losstot:, 2.690e-01, Time: 0.04
# It: 13900, Lossb: 1.270e-05, Lossv: 2.676e-01, Losstot:, 2.676e-01, Time: 0.04
# It: 14000, Lossb: 1.356e-05, Lossv: 2.653e-01, Losstot:, 2.653e-01, Time: 0.04
# It: 14100, Lossb: 1.024e-05, Lossv: 2.618e-01, Losstot:, 2.618e-01, Time: 0.04
# It: 14200, Lossb: 1.717e-06, Lossv: 2.582e-01, Losstot:, 2.582e-01, Time: 0.05
# It: 14300, Lossb: 7.436e-06, Lossv: 2.554e-01, Losstot:, 2.555e-01, Time: 0.04
# It: 14400, Lossb: 8.452e-06, Lossv: 2.526e-01, Losstot:, 2.526e-01, Time: 0.04
# It: 14500, Lossb: 1.158e-05, Lossv: 2.500e-01, Losstot:, 2.500e-01, Time: 0.04
# It: 14600, Lossb: 1.840e-05, Lossv: 2.480e-01, Losstot:, 2.480e-01, Time: 0.04
# It: 14700, Lossb: 2.246e-05, Lossv: 2.461e-01, Losstot:, 2.461e-01, Time: 0.04
# It: 14800, Lossb: 3.101e-05, Lossv: 2.446e-01, Losstot:, 2.447e-01, Time: 0.05
# It: 14900, Lossb: 4.148e-05, Lossv: 2.432e-01, Losstot:, 2.432e-01, Time: 0.05
# It: 15000, Lossb: 5.420e-05, Lossv: 2.422e-01, Losstot:, 2.423e-01, Time: 0.04

# %%
print(params['NN_struct'][0])
input=tf.constant([[1.0],[2.0]],dtype=tf.float64)
print(input)

#the input must be a tensor of two dims(col)
#if you inherit from tf.keras model and you init like you did you can view the structure of the the net if you type:
print(model.NN(input))
# Out:
# 1
# tf.Tensor(
# [[1.]
#  [2.]], shape=(2, 1), dtype=float64)
# tf.Tensor(
# [[ 0.99263527]
#  [-3.56774831]], shape=(2, 1), dtype=float64)
